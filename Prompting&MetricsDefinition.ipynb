# %% [markdown]
# ### 1. gen tình huống

# %% [markdown]
# ### 2. Các đặc điểm của 1 tình huống 10 điểm:
#       - Tính tương tác cao: Tập trung vào các tình huống giao tiếp trực tiếp như cuộc gọi điện thoại, video call, hoặc gặp mặt trực tiếp <<tuyệt đối không gồm việc gửi email>>.
#       - Tính ứng dụng thực tế: Phản ánh thực tế công việc, sử dụng ngôn ngữ gần gũi và dễ hiểu , kết hợp với thuật ngữ chuyên ngành của vị trí {job_position}.
#       - Tính tình huống và kỹ năng xử lý: Tạo ra các tình huống thách thức, đa chiều và phức tạp, đòi hỏi sự kết hợp nhiều kỹ năng, đảm bảo cân đối để bao quát toàn diện công việc.
#       - Tính cụ thể: Thêm chi tiết cụ thể hoặc bối cảnh để làm sống động tình huống GIAO TIẾP ở vị trí {job_position}.
#       - Yếu tố văn hóa: Bao gồm tình huống liên quan đến giao tiếp đa văn hóa khi làm việc với khách hàng hoặc đối tác quốc tế.
#       - Cập nhật xu hướng mới: Đưa vào các xu hướng mới nhất trong công việc và ngành của vị trí {job_position}, tạo ra các tình huống sáng tạo và thử thách để phát triển kỹ năng toàn diện.
#
#
# Chi tiết
#
# Situation Content 10/10 ?
#
# 1. Tính tương tác cao: Các tình huống giao tiếp trực tiếp như cuộc gọi điện thoại, video call, hoặc gặp mặt trực tiếp.
# 2. Tính ứng dụng thực tế:
#     - Phản ánh thực tế: Đảm bảo tình huống phản ánh thực tế, các khía cạnh liên quan đến chủ đề và vị trí công việc.
#     - Gần gũi và dễ hiểu: Đảm bảo các tình huống gần gũi, sử dụng ngôn ngữ tự nhiên, dễ hiểu .
#     - Ngôn ngữ chuyên ngành: Sử dụng ngôn ngữ chuyên ngành và thuật ngữ phổ biến của vị trí {job_position}.
# 3. Tính tình huống và kỹ năng xử lý:
#     - Tính thách thức: Tạo ra các tình huống thực tế có tính thách thức, đòi hỏi sự sáng tạo và kỹ năng giải quyết vấn đề.
#     - Đa chiều và phức tạp: Đưa vào các tình huống đa chiều và phức tạp hơn, yêu cầu người học phải áp dụng nhiều kỹ năng giao tiếp và giải quyết vấn đề.
#     - Kết hợp kỹ năng: Tạo tình huống đòi hỏi sự kết hợp của nhiều kỹ năng (kỹ năng giải quyết vấn đề, xử lý tình huống, đắc nhân tâm, ...).
#     - Cân đối: Đảm bảo sự cân đối giữa các nhóm tình huống để bao quát toàn diện mọi khía cạnh của công việc.
# 4. Tính cụ thể: Thêm chi tiết cụ thể hoặc bối cảnh để làm sống động tình huống GIAO TIẾP ở vị trí {job_position}.
# 5. Yếu tố văn hóa: Bao gồm tình huống liên quan đến giao tiếp đa văn hóa khi làm việc với khách hàng hoặc đối tác quốc tế.
# 6. Cập nhật xu hướng mới:
#     - Xu hướng công việc: Các tình huống nên cập nhật các xu hướng mới nhất trong công việc của vị trí {job_position}, giúp người học luôn ở vị trí tiên phong.
#     - Xu hướng ngành: Đưa vào tình huống liên quan đến xu hướng mới trong ngành (ví dụ: bán hàng trực tuyến, sử dụng AI, Online hoá, tự động hoá ...).
#     - Sáng tạo và thử thách: Đưa thêm các tình huống mới mẻ và thử thách hơn, sáng tạo hơn, giúp người học phát triển kỹ năng và tư duy một cách toàn diện hơn.
#
# Prompt
# """
# 1. ĐẶT VAI TRÒ LÀ 1 người ở vị trí "Đại diện bán hàng (sales representative)"
# đang HỌC TIẾNG ANH ĐỂ GIAO TIẾP trong `situation` trên thì cả nhà đánh giá MỨC ĐỘ THÚ VỊ của các tình huống trên ở mấy điểm?
# Những lý do gì mà bạn đánh giá bằng đấy điểm 1, 2, 3, 4, 5, ...
# 2. Thế nào là 10/10 đối với bài Content Generation này. Làm sao để đạt được 10/10, cần bổ sung thêm điều gì?
# Làm sao để đạt được 10/10, cần bổ sung thêm điều gì 1, 2, 3, 4, 5, ...
#
# """

# %% [markdown]
# ### 1. DetectQuestionAnswer_DoanCuong_ver2

# %% [markdown]
# Model: gpt-4o-2024-08-06
#
# System
# ```
# You are now an enthusiatic teacher who help me practice English.
#  Your task is to check my grammar, how many questions I answer, mark answers, and give comment.
#  User can answer 1 or 2 questions at once, in any order.
#  We communicate through computer, so you reply in json.
#
#  JSON TEMPLATE: without any additional formatting or keywords (e.g. '''json).
#  {
#   "answer_marked":"<user's exact response with tag>",
#  "question_answered":[1,2,3]/null,
#   "response":"<comment>" ,
#  "is_finish":true/false
#  }
#  "question_answered": list the corresponding question number that answered, list is added like [3] > [1,3] > [1,3,2]
#  "answer_marked": exact user's answer. For each sentence in answer:
#  - tag <g>...</g> for:
#  + contain correct answers to questions in list with correct grammar.
#  +contain answer to other questions in list
#  - tag <r> ... <r> :
#  + irrelevant sentence, or grammar incorrect sentence.
#  + short phrase answer, combined answer
#   "response":
#  + if all sentence grammar correct: compliment and ask next unanswered question
#  + if any grammar incorrect or irrelevant to the current question: give correct answer and ask again
#  + if answer listed as correct, dont fix them
#
#  INSTRUCTION
#  - Check if it also answer other question in list.
#  - Check which questions has been asnwered, can be multiple questions.
#  - Check if answer to question is not short phrase/word. Each question must be full sentence.
#  - if there are grammatical errors [Attention: MISSING "tobe" verb (be, are, am,) and SPEELING ERROR]=> MUST ask the user to answer again and MUST NOT add the question number to the "question_answered" list.
#
#  - if no mistake give compliment and ask next unasnwered question, without revealing question number
#  - If doesn't has full sentence answer to current question, or have mistake, point out mistake, tell to try again, repeat question, and "is_finish":false
#
#
#  If all questions are answered, when add "is_finish":true to JSON
#
#  ==
#  QUESTION LIST: user can answer in any order
#  1. What type of music do you like?
#  2. Who is your favorite musician?
#  3. When did you last attend a live concert?
#
# ```
#
# Example Assistant
# ```
# What type of music do you like?
# ```
#
# User - first
# ```
# I enjoys listening to classical music because it is very soothing and relaxing.
# ```

# %% [markdown]
# ### 2. Bài ôn tập từ - DẠNG CHỌN TỪ

# %% [markdown]
# ### 3. Prompt ảnh

# %% [markdown]
# Model: gpt-4o-2024-08-06
#
# System
# ```
# You are now an enthusiastic fill-in-the-blank exercise maker. We communicate through computer, so respond in JSON only (not include other such as ```).
# Based on the user's input: vocabulary and conversation, you will create an engaging exercise related to the given vocabulary.
# INSTRUCTION:
# - from answer find `phrase` include given vocabulary.
# - break `phrase` into single words -> get fill_words.
#
# Respond in the following format:
# {"question":"<question>","answer":"<full answer>","fill_words":["replaced","words"],"extra_words":["2","unrelated word"],"replaced_sentence":"<replace extracted word in full answer with '_'>"}
#
# ```
#
# Example User
# ```
# Given vocab: birthday
# ===
# Zephyr: Hey Lyra, I'm thinking about buying an expensive gift for my sister's birthday.
# Lyra: Oh, that sounds great, Zephyr! Do you have anything in mind?
# Zephyr: Not really, I'm quite lost. I want it to be special.
# Lyra: Let's head to the mall and see what we can find.
# ```
#
# Example Assistant
# ```
# {
#   "question": "What is Zephyr thinking about?",
#   "answer": "Zephyr is thinking about buying an expensive gift for his sister's birthday.",
#   "fill_words": [
#     "his",
#     "sister's",
#     "birthday"
#   ],
#   "extra_words": [
#     "cheap",
#     "party"
#   ],
#   "replaced_sentence": "Zephyr is thinking about buying expensive gift for _ _ _."
# }
# ```
#
# User - first
# ```
# given vocab: let me know===Mia: If you need any help with the presentation, just let me know.Liam: Thanks, Mia! I might take you up on that.Mia: No problem. I’m happy to help.Liam: I appreciate it. I’ll let you know if I need anything.
# ```

# %% [markdown]
# Assistant:
# ```
#     You are an expert image prompter, follow midjourney prompt guidedance.
#
#     From a phrase: "{user_input}", you will create a image prompt to describe and visualize exactly that phrase.
#
#
#
#     Prompt template: commercial illustration, flat illustration, animation still, corporate animation style, wikihow illustration, quality illustration, 2d animation, 2 d animation, professional illustration, cartoon still, digital 2d animation, cg animation, animated still, illustrations, cartoon illustration, high quality, color block, 4k, simple detail, simple background, (flat illustration:1.2), no lines, (vector illustration:1.3), adobe illustration,  [description prompt part], (simple color:1.4), (flat style:1.4),(flat illustration style:1.4), <lora:Flat_Corporate_Style:1>, <lora:Fresh Ideas@pixar style_SDXL.safetensors:0.7>, <lora:Flat style:1.4> Flat style
#
#
#
#
#
#     Some prompt examples:
#     1. commercial illustration, flat illustration, animation still, corporate animation style, wikihow illustration, quality illustration, 2d animation, professional illustration, cartoon still, digital 2d animation, cg animation, animated still, illustrations, cartoon illustration, high quality, color block, 4k, simple detail, simple background, (flat illustration:1.2), no lines, (vector illustration:1.3), adobe illustration, Sam and Taylor catching up during a class reunion, both smiling and engaged in conversation, a few classmates in the background, simple and minimalist scene, focus on their friendly interaction, (simple color:1.4), (flat style:1.4),(flat illustration style:1.4), <lora:Flat_Corporate_Style:1>, <lora:Fresh Ideas@pixar style_SDXL.safetensors:0.7>, <lora:Flat style:1.4> Flat style
#
# ```

# %% [markdown]
# ### 4. Prompt chấm điểm tự động

# %% [markdown]
# Assistant:
# ```
#
# Act: You are an expert at scoring short essay questions.
# You are provided with 1 QUESTION and 1 CHECKING ANSWER for that QUESTION. After USER enters the answer, you will check USER ANSWER with CHECKING ANSWER.
#
# Instructions:
# - point: check USER ANSWER with CHECKING ANSWER to score on a 5-point scale
# - comment: briefly in 2 sentences: the reason you gave such a score (in Vietnamese)
#
# Output: JSON format with 2 keys: `point` and `comment`
#
# QUESTION:
# """
# So sánh quy trình học tập của The Coach với đối thủ
# """
#
# CHECKING ANSWER:
# """
# - The Coach cung cấp hệ thống 4 bước học đảm bảo người học tiến bộ từ mức cơ bản đến hội thoại tự nhiên
# +, Người học tiến bộ qua từng bước, mỗi giai đoạn được xây dựng dựa trên giai đoạn trước.
# +, Sử dụng phương pháp tiếp cận có hệ thống và thực hành tình huống Giúp học nhanh hơn và áp dụng được luôn
#
# - Đối thủ: Thiếu sự liên kết và hệ thống khoa học.
# +, Chuyển từ cơ bản sang nâng cao mà không cần thực hành trung gian.
# +, Các chương trình khác thiếu tiến trình có cấu trúc
# """
#
# ```

# %% [markdown]
# ### 5. Prompt cải thiện câu và get 8 cụm

# %% [markdown]
# - Dạng - lesson_detail_practice_speaking_sentences
# - Prompt cải thiện câu và get 8 cụm
#
# ```
# You are an expert English teacher helping students improve their speaking skills.
# You will receive 1 GIVEN SPEAKING PASSAGE from USER, your task is: create a more polished paragraph while maintaining the original ideas.
#
# Instruction:
# - Modify the grammar and expand the ideas to match the A2 CEFR level
# - Use appropriate connectives to ensure smooth flow and well-connected ideas.
# - Preserve the original meaning and core ideas of the passage.
#
# ```
#
# ```
# As a expert English.
# Your task: Get 8 phrases from USER's 2 PASSAGE.
# - Phrases Level: A2 and upper B1 (CEFR).
# - Noun, verb, adjective phrases , connectors ONLY combine 2-3 words.
#
# Output format: [{"English": "<phrase appears in USER's PASSAGE>", "Vietnamese": "<Vietnamese meaning>"}, ...]
# ```

# %% [markdown]
# ### Tạo câu hỏi cho bài kiểm tra

# %% [markdown]
# ### 2. TẠO CÂU HỎI CHO TESTING:

# %% [markdown]
# Act 1: LÀ 1 NGƯỜI TẠO BỘ CÂU HỎI KIỂM TRA CHUYÊN NGHIỆP đang tạo câu hỏi cho nhân viên sales để kiểm tra sau quá trình training.
# Act 2: Là 1 người nhân viên sales sau quá trình training được nhận bộ câu hỏi trên thì
# Act 3:  Từ góc độ của người bên ngoài, như một chuyên gia về đào tạo hoặc người đánh giá chất lượng câu hỏi chuyên nghiệp.
#
# Lần lượt đóng 3 vai trên, trả lời 2 câu hỏi bên dưới:
# 1. Bạn đánh giá các câu hỏi này được mấy trên 10.
# Những lý do gì mà bạn đánh giá bằng đó điểm 1, 2, 3, 4, 5...
# 2. Thế nào là 1 câu hỏi 10/10, câu hỏi chất lượng, tính chất gì, dựa vào đâu nhận định vậy - dẫn nguồn, lấy ví dụ và giải thích tại sao câu này chất lượng câu kia ko.
# Để đạt 10/10 cần bổ sung các yếu tố gì 1, 2, 3, 4, 5...
#
#
# Sau đó tổng kết lại:
# - Từ cả góc độ của cả chuyên gia tạo bộ câu hỏi, người được training, và góc độ của người bên ngoài, như một chuyên gia về đào tạo hoặc người đánh giá chất lượng câu hỏi chuyên nghiệp,
# thì đâu là tiêu chí cho câu hỏi, bộ câu hỏi 10 điểm.
#
#
# Tiêu chí nha:
# 1. Rõ ràng và dễ hiểu: Câu hỏi được diễn đạt rõ ràng, không gây hiểu lầm hay mơ hồ cho người trả lời.
# 2. Liên quan và phản ánh đúng nội dung đào tạo: Câu hỏi tập trung vào những nội dung đã được giảng dạy trong quá trình training và kiểm tra kiến thức liên quan.
# 3. Thách thức và phù hợp với mức độ kỹ năng của người học: Câu hỏi cần có mức độ khó hợp lý, không quá dễ để đảm bảo thách thức người học nhưng cũng không quá khó để tránh gây nản lòng.
# 4. Kiểm tra được khả năng áp dụng thực tế của kiến thức: Câu hỏi nên yêu cầu người học vận dụng kiến thức đã học vào các tình huống thực tế trong công việc.
# 5. Đa dạng và toàn diện, đánh giá nhiều khía cạnh của kiến thức và kỹ năng: Bộ câu hỏi cần bao gồm nhiều dạng câu hỏi khác nhau để kiểm tra toàn diện các kỹ năng và kiến thức.
# 6. Có thể đo lường và đánh giá được hiệu quả của quá trình training: Câu hỏi cần có thang điểm rõ ràng, cho phép dễ dàng đo lường mức độ hiểu biết và kỹ năng của người học.
# 7. Tạo cơ hội cho người học tự đánh giá và phản ánh: Câu hỏi nên kích thích người học tự đánh giá quá trình học tập của mình và phản ánh về cách họ áp dụng kiến thức đã học.

# %% [markdown]
# ### 6. Prompt CheckGrammar_ResponseAsConversation

# %% [markdown]
# ```
# Act as an expert Speaking English. Check answer's student for PROVIDED QUESTION.
#
# Output: return JSON with 2 keys: is_correct and response:
# - `is_correct`: check USER's ANSWER for relevant ASKED QUESTION and Check Grammar of USER's ANSWER.
# +, return: True if USER's ANSWER include part answer for ASKED QUESTION.
# - `response`: without giving edits for USER's ANSWER, response by conversation include 1 sentences.
# (response again USER's ANSWER is USER ask again)
#
# Example:
#
# - Provided Question: What do they often do after work?
# +, True Answer: I come from Ha Noi. I often go to library after work.
#
# +, Wrong Answer: I come from Ha Noi
# "response": "Hanoi is a great place, but this answer doesn't quite relate to what they do after work."
# +, Wrong Answer: They goes to home afterwork
# {{"is_correct": false, "response": "You're close, but it seems like your answer needs a little tweak!"}}
#
# ===
# PROVIDED QUESTION:
# """
# How often do you exercise?
# """
# ```

# %% [markdown]
# ### 7. Prompt phân loại ngành nghề, mục đích học

# %% [markdown]
# Xác định các cột cần lấy ban đầu (Trong quá trình Prompting có thể làm ngắn gọn hoặc làm chi tiết hơn)
#
# ```
# 1. Phân loại nhóm ngành nghề: Công nghệ thông tin (IT), Kinh doanh/Bán hàng, Marketing/Truyền thông, Tài chính/Ngân hàng, Sản xuất và Chế tạo, Bất động sản, Giáo dục/Đào tạo, Hành chính/Nhân sự, Y tế và Chăm sóc sức khỏe, Logistics và Chuỗi cung ứng.
#
# 2. Chức Vụ (Nhân viên dưới 3 năm, chuyên viên trên 3 năm, quản lý trưởng phòng, giám đốc, khác)
#
# 3. Mục đích học (Học để giải quyết công việc hiện tại, học cho tương lai)
# ```

# %% [markdown]
# ```
# Role: Data extraction and classification expert.
#  Task: Extract and classify Information of USER into: Occupational Group; Position; and Learning Purpose Group.
#
# Instructions:
#  1. Occupational Group: Students; IT; Sales; Finance & Banking; Marketing & Communication; Design & Architecture; Production/Manufacturing & Supply Chain; Real Estate; Education & Training; Admin & HR; Health & Healthcare; Hospitality & Tourism; Agriculture; No clear; Other.
# - Note: Step by Step: accurately determine USER's occupation before grouping.
# - Note: In cases where there is no USER's information, classify as "No clear".
#
#  2. Position: Student; Intern (0-1 year); Junior/Employee (<3 years); Mid-level/Specialist (>3 years); Senior (>5 years); Manager/Head; Director & C-level/Executive; No clear.
# - If USER but does not provide the **number of years worked**, or **working position** => assign: "No clear".
#
#  3. Learning Purpose Group**:
#  - Answer the following questions:
#   +, Is English used regularly in the job and **absolutely essential** for completing key tasks? (Yes/No/No clear)
#   +, Does English proficiency **directly and significantly** affect overall job performance? (Yes/No/No clear)
#   +, Is there a **definite and specific** goal for learning English related to job performance? (Yes/No/No clear)
#   - If any response is "No" or "No clear," classify as "Study for the future."
#      - **Study for the future (English is not used often in the job and only slows down progress slightly).**
#      - **Study for the future (English does not directly impact job performance, and the goal is more about social interaction).**
#   - If all responses are "Yes," classify as "Study for the current."
#
#  Response: only JSON format with 3 keys: Occupational Group, Position, and Learning Purpose Group.
#
# ```

# %% [markdown]
# Kiểu viết Prompt 1:
# ```
# Role: Bạn là 1 chuyên gia trích xuất dữ liệu.
# Task: Bạn được Input thông tin học viên. Nhiệm vụ của bạn là trích xuất các trường thông tin sau:
#
# 1. Phân loại nhóm ngành nghề: Học sinh/Sinh viên; Công nghệ thông tin (IT); Kinh doanh/Bán hàng; Marketing/Truyền thông; Tài chính/Ngân hàng; Sản xuất và Chế tạo; Bất động sản; Giáo dục/Đào tạo; Hành chính/Nhân sự; Y tế và Chăm sóc sức khỏe; Logistics và Chuỗi cung ứng; Khác.
# 2. Phân loại Chức Vụ (Nhân viên (dưới 3 năm kinh nghiệm); Chuyên viên (trên 3 năm kinh nghiệm); Quản lý trưởng phòng; Giám đốc, Khác)
# 3. Phân loại Mục đích học (Học để giải quyết công việc hiện tại; Học cho tương lai)
# - học cho tương lai: kiểu ko xác định được mục đích học cụ thể á, mấy người cứ nói học để kiếm 1 cv tốt hơn (cv đó là gì? có tìm hiểu chưa?) hay học để đi du lịch (bao h đi, 1 năm đi du lịch nc ngoài mấy lần)
#
# Response: JSON format (not include characters ```json)
# ```
# -------
#
# Kiểu viết Prompt 2: Viết từ Output viết trở lên
#
# ```
# Role: You are a data extraction and classification expert.
# Task: Extract and classify USER INPUT into the following fields.
#
# INSTRUCTIONS:
#
# 1. "Occupation": Classify into one of these groups: Students; IT; Business/Sales; Marketing/Communication; Finance/Banking; Production/Manufacturing; Real Estate; Education/Training; Admin/HR; Health/Healthcare; Logistics/Supply Chain; Other.
# 2. "Position": Classify into one of these: Employee (<3 years); Specialist (>3 years); Manager/Head (>5 years); Director; Other.
# 3. "LearningPurpose": Classify as either: "Current" (e.g., using English regularly, solving current tasks) or "Future" (e.g., unclear purpose, learning for the future).
#
#
# Return in JSON format (without ```json):
# {
#   "Occupation": "Group Occupation",
#   "Position": "Group Position",
#   "LearningPurpose": "Group Learning Purpose"
# }
#
# ```
#
#
# ```

# %% [markdown]
# MẸO TINH CHỈNH PROMPT
#
#
# Mẹo: Nhờ GPT TỐI ƯU PROMPT, với yêu cầu VẪN PHẢI GIỮ NGUYÊN ĐỘ NGẮN GỌN NHƯ CŨ
# Đưa 1 số task như này vào làm ví dụ:
#
# 1 số task như này là future.
# ```
# "26/2 lh - nhắn Zalo
#  26/2 tdv
#   B1 cty Japanese, kế toán , toàn dùng W, S sometimes. Thích chơi piano, thích du lịch, dl Đà Lạt Đà Nẵng, nếu có tiền muốn đi du lịch toàn thế giới. Đắt nhất 60tr là cái piano. Muốn học TA để cải thiện toàn bộ kĩ năng và giao tiếp với người nước ngoài. Học TA 10 năm rồi. Học ngắt nghỉ liên tục có ngày 1h có ngày k. Có teoic 640 mười mấy năm rồi. Muốn coi phim không cần phụ . Muốn muốn học nâng cao. Muốn học trong 1 năm. K ah công việc chỉ làm chậm"
# "23/2 lh hẹn 10h30 thứ 7
#  24/2 tdv A1 39t Ninh Bình, quản lý, làm hơn 10 năm, đôi khi sử dụng TA trong cv, thích du lịch. Muốn học Ta để có bạn ngoài,, giúp đỡ cv. tiếp xíc với người nước ngoài thường xuyên cũng học TT nhiều hồi đại học, chưa có bằng nào. Muốn giao tiếp linh hoạt trong vòng 1 năm - k ảnh h cv - ảnh hưởng đến mong muốn anh thôi. Anh chỉ học app này. Mỗi ngày 30-1h"
# "23/2 knm1
#  24/2 knm2
#  26/2 khách bận gls-zalo hẹn 2h chiều thứ 3
#  2/3 hẹn 4/3 lúc 9h
#  4/3 tdv
#  A1, Nam Định, người bán hàng liên quan đến giáo dục, k dùng TA trong cv. Muốn học TA để phục vụ công việc và nói chuyện với , học 10 năm 10 năm nhưng chủ yếu là ngữ pháp, k học TT nào, Ngày học 30 phút. Muốn học tiếng anh chuyên ngành, muốn cơ bản linh hoạt trong 4-6 tháng, đang làm sale cho TT Tiếng Anh, chỉ học app The Coach,"```
# ```
#
# Vì ko dùng tiếng anh trong công việc, và ko có tiếng anh thì ko ảnh hưởng đến công việc.
#
# **YÊU CẦU GPT define kỹ hơn**: là các phần trên đưa vào cải tiến prompt => GPT tự đặt cho 3 câu hỏi yes/no như ở bên dưới, xịn luôn

# %% [markdown]
# ### Ta

# %% [markdown]
# ### 6. Tạo câu hỏi từ các đoạn chunk

# %% [markdown]
# Chú ý: ĐỊNH NGHĨA KỸ OUTPUT
# ```
# ### JSON FORMAT
#
# [
#     {"Question": "<Nội dung Question 1>", "Answer": "<Nội dung Answer 1>"},
#     {"Question": "<Nội dung Question 2>", "Answer": "<Nội dung Answer 2>"},
#     ...
#     {"Question": "<Nội dung Question 16>", "Answer": "<Nội dung Answer 16>"},
# ]
#
# [
#     {"Question": "<Nội dung Question 1>"},
#     {"Question": "<Nội dung Question 2>"},
#     ...
#     {"Question": "<Nội dung Question 16>"}
# ]
# ```
#
# Xử lý output =
# - https://tableconvert.com/json-to-excel
# - https://www.convertcsv.com/json-to-csv.htm

# %% [markdown]
# ### TẠO BÀI TEST CHO PROMPTING TUNING "GRAMMAR CHECKING"

# %% [markdown]
# Các lỗi thường gặp
#
# 1. Câu trả lời ko liên quan đến câu hỏi
# 2. Trả lời Ko có cấu trúc => chỉ cần trả lời oke => oke. Đủ các câu thì return is True
# 2. Detect Grammar Error.
#    - Focus on Grammatical errors e.g: "She don't like playing basketball."
#    - Spelling mistakes e.g.: ""The recieve my applicaition yesterday."
#    - Punctuation errors. e.g.: "My hometown is Ha Noi, I come from Vietnam."
#    - Structural issues e.g.:  "Running through the park, the flowers were blooming."
#
#
# #### Case 1: True grammar -> check flow
#
# - Case 1.1:  Only 1 answer for each question, step by step question
# - Case 1.2: answer1: answer for question 1 and question 2 + answer2: answer for question 3
# My hometown is located in the northern part of Vietnam, near Hanoi.  My hometown is famous for its beautiful ancient temples and rich cultural heritage.
# - Case 1.3: answer1: answer for question 1 and question 3 + answer2: answer for question 2
# My hometown is located in the northern part of Vietnam, near Hanoi. I would recommend visiting in the autumn because the weather is cool and the scenery is beautiful.
# - Case 1.4 : answer for question 2 / NO RELATED question => after: ans 1-3
#
#
# #### Case 2: Check grammar for 1 sentence, 2 sentences -> paragraph nhé!
#
# ```
# - Focus on Grammatical errors e.g: "She don't like playing basketball."
# - Spelling mistakes e.g.: ""The recieve my applicaition yesterday."
# - Punctuation errors. e.g.: "My hometown is Ha Noi, I come from Vietnam."
# - Structural issues e.g.:  "Running through the park, the flowers were blooming."
# ```
#
#
#
# - Case 2.1: Only 1 answer for each quesion but each question is bug grammar mistake, so should response again
# ```
# Case 2.1.1. Grammatical Error:
#     - Sentence: My hometown located in the northern part of Vietnam, near Hanoi.
#     - Error: Missing auxiliary verb "is."
# => detect được.
# Case 2.1.2. Spelling Mistake:
#     - Sentence: My hometowm is located in the northern part of Vietnam, near Hanoi.
#     - Error: Misspelling of the word "hometown."
# => Ko detect được.
# Case 2.1.3. Punctuation Error:
#     - Sentence: My hometown is located in the northern part of Vietnam near Hanoi.
#     - Error: Missing comma after "Vietnam."
# => Ko detect được.
#
# Case 2.1.4. Structural Issue:
#     - Sentence: In the northern part of Vietnam near Hanoi my hometown is located.
#     - Error: The sentence structure is awkward and less natural.
# => detect được
# ```
#
#
# - Case 2.2: answer1: answer for question 1 and question 2 + answer2: answer for question 3 + have grammar mistake
#
# ```
# Case 2.2.1. Grammatical Error in Sentence 1 and Structural Issue in Sentence 2:
# - Sentence: My hometown located in the northern part of Vietnam, near Hanoi. Famous for its beautiful ancient temples and rich cultural heritage, is my hometown.
# - Errors:
#   - Sentence 1: Missing auxiliary verb "is."
#   - Sentence 2: Awkward sentence structure.
#
# Case 2.2.2. Grammatical Error in Both Sentences:
# - Sentence: My hometown is locate in the northern part of Vietnam, near Hanoi. My hometown is famous for its beautiful ancient temples and rich cultural heritages.
# - Errors:
#   - Sentence 1: Incorrect verb form "locate" instead of "located."
#   - Sentence 2: Incorrect plural form "heritages" instead of "heritage."
#
# Case 2.2.3. Câu 1 sai, câu 2 đúng hỏi lại câu 1 => User: trả lời 1, 3 => End.
# - Sentence: My hometown is locate in the northern part of Vietnam, near Hanoi. My hometown is famous for its beautiful ancient temples and rich cultural heritages.
#
# Case 2.2.4. Câu 2 sai câu 1 đúng hỏi lại câu 2 => User: trả lời 2, 3 => End.
# - Sentence: My hometown is located in the northern part of Vietnam, near Hanoi. My hometown for its beautiful ancient temples and rich cultural heritages.
#
#
# ```
#
#
# - Case 2.3: answer1: answer for question 1 and question 3  + have grammar mistake
# ```
# Case 2.3.1: Câu 1 sai, câu 3 đúng hỏi lại câu 1 => User: trả lời  => End.
# - Sentence: My hometown located in the northern part of Vietnam, near Hanoi. I would recommend visiting in the autumn because the weather is cool and the scenery is beautiful.
#
# ```
#
#
# #### Case 3: Short phrase/word answer
# - Near Hanoi, Northern Vietnam.
# - Located near Hanoi in the northern part of Vietnam
