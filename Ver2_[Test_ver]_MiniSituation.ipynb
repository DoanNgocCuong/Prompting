# %%
import os
from openai import OpenAI
import json
import pandas as pd
from typing import List

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

def get_completion(prompt, model="gpt-4o", temperature=0):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message.content

def gen_situation_groups_AND_situation_SHORTVER2(job_position):
    prompt = f"""
    Bạn là chuyên gia về giao tiếp trong môi trường làm việc, đặc biệt là trong lĩnh vực bán hàng.
    
    Nhiệm vụ: Tạo ra 3 nhóm tình huống GIAO TIẾP liên quan đến vị trí công việc "{job_position}",
    bao gồm cả khía cạnh chuyên môn và cá nhân.

    Hướng dẫn:
    1. Yêu cầu bắt buộc về các tình huống 
      - Đúng thể loại: TÌNH HUỐNG GIAO TIẾP, 
      (thể hiện rõ qua TÊN CỦA NHÓM TÌNH HUỐNG GIAO TIẾP và CÁC TÌNH HUỐNG GIAO TIẾP CỤ THỂ của từng nhóm). 
    2. Các nhóm tình huống GIAO TIẾP: phải bằng tiếng Việt, ngắn gọn, và xoay quanh vị trí công việc của "{job_position}".
    3. Mỗi nhóm tình huống có 3 tình huống cụ thể hơn, nhưng vẫn ngắn gọn, và đảm bảo:
      - Tính tương tác cao: Tập trung vào các tình huống giao tiếp trực tiếp như cuộc gọi điện thoại, video call, hoặc gặp mặt trực tiếp.
      - Tính ứng dụng thực tế: Phản ánh thực tế công việc, sử dụng ngôn ngữ gần gũi và dễ hiểu , kết hợp với thuật ngữ chuyên ngành của vị trí {job_position}.
      - Tính tình huống và kỹ năng xử lý: Tạo ra các tình huống thách thức, đa chiều và phức tạp, đòi hỏi sự kết hợp nhiều kỹ năng, đảm bảo cân đối để bao quát toàn diện công việc.
      - Tính cụ thể: Thêm chi tiết cụ thể hoặc bối cảnh để làm sống động tình huống GIAO TIẾP ở vị trí {job_position}.
      - Yếu tố văn hóa: Bao gồm tình huống liên quan đến giao tiếp đa văn hóa khi làm việc với khách hàng hoặc đối tác quốc tế.
      - Cập nhật xu hướng mới: Đưa vào các xu hướng mới nhất trong công việc và ngành của vị trí {job_position}, tạo ra các tình huống sáng tạo và thử thách để phát triển kỹ năng toàn diện.

    3'. Gợi ý các nhóm tình huống (không giới hạn ở các gợi ý này):
    - Tương tác với đồng nghiệp
    - Báo cáo và đề xuất với cấp trên
    - Hỗ trợ và chăm sóc khách hàng
    - Đàm phán và thỏa thuận
    - Quản lý khủng hoảng và xử lý tình huống khó
    - Đào tạo và phát triển bản thân/đồng nghiệp
    - Tham gia hội nghị và sự kiện ngành
    - Xây dựng mạng lưới quan hệ
    - Áp dụng công nghệ mới trong bán hàng
    - Thích ứng với thay đổi thị trường
    - Đánh giá hiệu suất và đề xuất cải tiến
    - Tuyển dụng và phỏng vấn
    - Quảng bá và marketing, Đảm bảo chất lượng, Phát triển sản phẩm, Quản lý tài chính

    Trả về một đối tượng JSON có cấu trúc sau:
    {{
      "job_position": "{job_position}",
      "situation_groups": {{
        "situation_group1": {{
          "situation_group_name": "Tên nhóm tình huống 1",
          "situation1": "Tình huống 1",
          "situation2": "Tình huống 2",
          "situation3": "Tình huống 3", 

        }},
        "situation_group2": {{
          "situation_group_name": "Tên nhóm tình huống 2",
          "situation1": "Tình huống 1",
          "situation2": "Tình huống 2"
          ...
        }},
        ...
      }}
    }}

    Đảm bảo đầu ra là một đối tượng JSON hợp lệ không có bất kỳ định dạng hoặc từ khóa bổ sung nào(chẳng hạn ```json).
    """

    print(f"Generating situation groups for {job_position}...")
    response = get_completion(prompt)
    
    try:
        topics_dict = json.loads(response)
        return json.dumps(topics_dict, ensure_ascii=False, indent=2)
    except json.JSONDecodeError:
        print("Error: The generated response is not valid JSON. Please check the output.")
        return None

def gen_detail_situations_SHORTVER(job_position, situation_group_name, situation):
    prompt = f"""
    Bạn là chuyên gia về phát triển nghề nghiệp và tình huống công việc cho vị trí {job_position}.
    
    Nhiệm vụ: Tạo ra chi tiết cho tình huống GIAO TIẾP "{situation}" liên quan đến chủ đề "{situation_group_name}" cho vị trí {job_position}.
    
    Hướng dẫn:
    1. Các đặc điểm của 1 tình huống 
      - Tính tương tác cao: Tập trung vào các tình huống giao tiếp trực tiếp như cuộc gọi điện thoại, video call, hoặc gặp mặt trực tiếp.
      - Tính ứng dụng thực tế: Phản ánh thực tế công việc, sử dụng ngôn ngữ gần gũi và dễ hiểu , kết hợp với thuật ngữ chuyên ngành của vị trí {job_position}.
      - Tính tình huống và kỹ năng xử lý: Tạo ra các tình huống thách thức, đa chiều và phức tạp, đòi hỏi sự kết hợp nhiều kỹ năng, đảm bảo cân đối để bao quát toàn diện công việc.
      - Tính cụ thể: Thêm chi tiết cụ thể hoặc bối cảnh để làm sống động tình huống GIAO TIẾP ở vị trí {job_position}.
      - Yếu tố văn hóa: Bao gồm tình huống liên quan đến giao tiếp đa văn hóa khi làm việc với khách hàng hoặc đối tác quốc tế.
      - Cập nhật xu hướng mới: Đưa vào các xu hướng mới nhất trong công việc và ngành của vị trí {job_position}, tạo ra các tình huống sáng tạo và thử thách để phát triển kỹ năng toàn diện.

    2. Chi tiết tình huống phải bao gồm:
       - Tên tình huống (tiếng Việt): {situation}
       - Chi tiết tình huống GIAO TIẾP (tiếng Việt): Mô tả chi tiết bối cảnh, các bên liên quan, và vấn đề cụ thể cần giải quyết. Đảm bảo tình huống đủ phức tạp để tạo ra thử thách thực tế cho vị trí {job_position}. 
       - Nhân vật của tôi (character_me) (tiếng Việt): Mô tả ngắn gọn trong 25 ký tự hoặc ít hơn, phản ánh vị trí {job_position}.
       - Nhân vật AI (character_ai) (tiếng Việt): Mô tả ngắn gọn trong 25 ký tự hoặc ít hơn, phù hợp với tình huống và vị trí {job_position}.
       - Giới tính của AI: Giới tính của AI: Chọn ngẫu nhiên "Nam" hoặc "Nữ". Hãy đảm bảo rằng bạn duy trì sự cân bằng giữa Nam và Nữ trong toàn bộ các tình huống bạn tạo ra. Nếu bạn đã chọn Nam nhiều lần gần đây, hãy ưu tiên chọn Nữ, và ngược lại.
       - Danh sách 3 câu hỏi liên quan đến tình huống (bằng tiếng Anh): Đảm bảo các câu hỏi đa dạng, từ cơ bản đến phức tạp, và bao quát nhiều khía cạnh của tình huống liên quan đến vị trí {job_position}.
       - Lời chào của AI (bằng tiếng Anh): Bao gồm thông tin cá nhân, chào hỏi cơ bản, và nêu rõ bối cảnh tình huống và hỏi luôn câu hỏi đầu tiên ("Câu hỏi 1" từ danh sách 7 câu hỏi bên trên).

    Trả về một đối tượng JSON với cấu trúc sau:
    {{
      "job_position": "{job_position}",
      "situation_group_name": "{situation_group_name}",
      "situation": {{
        "situation_name": "{situation}",
        "situation_details": "Chi tiết tình huống",
        "character_me": "Vai trò của người dùng",
        "character_ai": "Vai trò của AI",
        "ai_gender": "Giới tính của AI",
        "AI_greeting": "Lời chào của AI bằng tiếng Anh",
        "questions_list": [
          "Câu hỏi 1",
          "Câu hỏi 2",
          "Câu hỏi 3",

        ]
      }}
    }}
    
    Đảm bảo đầu ra là một đối tượng JSON hợp lệ không có bất kỳ định dạng hoặc từ khóa bổ sung nào.
    """

    print(f"Generating details for situation: {situation}")
    response = get_completion(prompt)
    
    try:
        situation_dict = json.loads(response)
        return json.dumps(situation_dict, ensure_ascii=False, indent=2)
    except json.JSONDecodeError:
        print("Error: The generated response is not valid JSON. Please check the output.")
        return None

# %%
import json
import pandas as pd

def gen_situation_group_AND_detail_situation(job_position: str) -> pd.DataFrame:
    """
    - (1 tham số duy nhất)
    - Output: Trả về Output 1 file excel với các cột 
        CÔNG VIỆC	TOPIC	TÊN TÌNH HUỐNG	CHI TIẾT TÌNH HUỐNG	NHÂN VẬT TÔI	NHÂN VẬT AI	Giới tính AI 	Câu mở đầu của AI	"LIST CÂU HỎI do AI hỏi"
    - Thêm các print để kiểm tra tiến độ và fix được lỗi (các print quan trọng, vừa đủ, không quá thừa)

    Output: Vừa có print ra console vừa có output là file excel, return nên là định dạng dễ sử dụng về sau (ĐÓ LÀ: DUYỆT TỪNG job_position ở đâu đó, sử dụng cái hàm gen_situation_group_AND_detail_situation(job_position) để tạo hàng loạt cho job_position, sau đó output gộp lại được thành 1 file với mỗi job_position là 1 sheet)
    - Sau khi tạo các nhóm tình huống, hãy in ra các nhóm tình huống đó trước đã nhé 
    - Tức là thêm các index ở đầu lúc lưu data từng câu hỏi ở cột "LIST CÂU HỎI do AI hỏi"
    - Làm sao để check được data in ra đúng chưa, thay vì phải đợi chạy xong toàn bộ => In ra dữ liệu từng tình huống để kiểm tra
    """
    # Bắt đầu quá trình với vị trí công việc được cung cấp
    print(f"Starting process for job position: {job_position}")
    
    # Bước 1: Tạo nhóm tình huống
    situation_groups_json = gen_situation_groups_AND_situation_SHORTVER2(job_position)
    print(situation_groups_json) # In các nhóm tình huống tạo được
    situation_groups = json.loads(situation_groups_json)
    
    # Sau khi tạo các nhóm tình huống, hãy in ra các nhóm tình huống đó trước đã nhé 
    
    print("\nGenerated Situation Groups:")
    for group_key, group in situation_groups["situation_groups"].items():
        print(f"Group: {group['situation_group_name']}")
        for situation_key, situation_value in group.items():
            if situation_key.startswith("situation") and situation_key != "situation_group_name":
                print(f"  - Situation: {situation_value}")

    # Bước 2: Tạo chi tiết tình huống cho từng nhóm và tình huống
    data = []
    processed_situations = set()  # Để theo dõi các tình huống đã xử lý

    # Duyệt qua các nhóm tình huống
    for group_key, group in situation_groups["situation_groups"].items():
        print(f"Processing group: {group['situation_group_name']}")
        # Duyệt qua từng tình huống trong nhóm
        for situation_key, situation_value in group.items():
            # Kiểm tra nếu key bắt đầu với "situation" và tình huống chưa được xử lý
            if situation_key.startswith("situation") and situation_key != "situation_group_name" and situation_value not in processed_situations:
                print(f"Generating details for : {situation_value}")
                # Gọi hàm để tạo chi tiết tình huống
                detailed_situation_json = gen_detail_situations_SHORTVER(
                    job_position, 
                    group["situation_group_name"], 
                    situation_value
                )
                detailed_situation = json.loads(detailed_situation_json)
                
                # Lấy dữ liệu chi tiết từ tình huống
                situation_data = detailed_situation["situation"]
                
                # Thêm dữ liệu vào danh sách
                questions_list = situation_data["questions_list"]
                indexed_questions_list = [f"{i+1}. {question}" for i, question in enumerate(questions_list)]
                
                situation_dict = {
                    "CÔNG VIỆC": job_position,
                    "TOPIC": group["situation_group_name"],
                    "TÊN TÌNH HUỐNG": situation_data["situation_name"],
                    "CHI TIẾT TÌNH HUỐNG": situation_data["situation_details"],
                    "NHÂN VẬT TÔI": situation_data["character_me"],
                    "NHÂN VẬT AI": situation_data["character_ai"],
                    "Giới tính AI": situation_data["ai_gender"],
                    "Câu mở đầu của AI": situation_data["AI_greeting"],
                    "LIST CÂU HỎI do AI hỏi": "\n".join(indexed_questions_list)
                }
                
                # Làm sao để check được data in ra đúng chưa, thay vì phải đợi chạy xong toàn bộ => In ra dữ liệu từng tình huống để kiểm tra
                # In ra dữ liệu của tình huống để kiểm tra
                print("\nGenerated Detailed Situation Data:")
                for key, value in situation_dict.items():
                    print(f"{key}: {value}")
                
                data.append(situation_dict)
                
                # Đánh dấu tình huống này đã được xử lý
                processed_situations.add(situation_value)
    
    # Tạo DataFrame từ danh sách dữ liệu
    df = pd.DataFrame(data)
    print(f"Completed processing for job position: {job_position}")
    print(f"Total situations generated: {len(df)}")
    return df

# %%
def generate_multi_job_situations(job_positions: List[str]) -> str:
    print("Starting multi-job situation generation process...")
    
    # Create a Pandas Excel writer using XlsxWriter as the engine
    excel_filename = "multi_job_situations.xlsx"
    with pd.ExcelWriter(excel_filename, engine='xlsxwriter') as writer:
        for job_position in job_positions:
            print(f"\nProcessing job position: {job_position}")
            df = gen_situation_group_AND_detail_situation(job_position)
            
            # Write each DataFrame to a different worksheet
            sheet_name = job_position[:31]  # Excel sheet names have a 31 character limit
            df.to_excel(writer, sheet_name=sheet_name, index=False)
            print(f"Sheet '{sheet_name}' added to Excel file")

    print(f"\nExcel file generated: {excel_filename}")
    return excel_filename

# Example usage
if __name__ == "__main__":
    job_positions = [
        "Đại diện bán hàng (sales representative)",
        "Trưởng phòng Marketing",
        "Chuyên viên hỗ trợ kỹ thuật phần mềm quốc tế (International Software Support Specialist)",
    ]
    excel_file = generate_multi_job_situations(job_positions)
    print(f"Final Excel file: {excel_file}")
# Out:
# Starting multi-job situation generation process...
#
# Processing job position: Đại diện bán hàng (sales representative)
# Starting process for job position: Đại diện bán hàng (sales representative)
# Generating situation groups for Đại diện bán hàng (sales representative)...
# {
#   "job_position": "Đại diện bán hàng (sales representative)",
#   "situation_groups": {
#     "situation_group1": {
#       "situation_group_name": "Hỗ trợ và chăm sóc khách hàng",
#       "situation1": "Khách hàng gọi điện phàn nàn về sản phẩm bị lỗi. Bạn cần lắng nghe, xin lỗi và đề xuất giải pháp thay thế hoặc hoàn tiền.",
#       "situation2": "Trong cuộc gặp mặt trực tiếp, khách hàng tiềm năng yêu cầu thêm thông tin chi tiết về sản phẩm. Bạn cần trình bày rõ ràng và thuyết phục về các tính năng và lợi ích của sản phẩm.",
#       "situation3": "Khách hàng quốc tế gửi email yêu cầu hỗ trợ kỹ thuật. Bạn cần trả lời bằng tiếng Anh, giải thích chi tiết và cung cấp hướng dẫn cụ thể."
#     },
#     "situation_group2": {
#       "situation_group_name": "Đàm phán và thỏa thuận",
#       "situation1": "Trong cuộc họp video call với đối tác, bạn cần đàm phán giá cả và điều khoản hợp đồng. Bạn phải chuẩn bị kỹ lưỡng và sử dụng kỹ năng thuyết phục để đạt được thỏa thuận có lợi.",
#       "situation2": "Khách hàng yêu cầu giảm giá đặc biệt cho đơn hàng lớn. Bạn cần thảo luận với cấp trên và đưa ra đề xuất hợp lý, đồng thời giữ vững mối quan hệ tốt đẹp với khách hàng.",
#       "situation3": "Trong buổi gặp mặt trực tiếp, bạn cần thuyết phục khách hàng ký hợp đồng dài hạn. Bạn phải trình bày rõ ràng về lợi ích của hợp đồng và giải đáp mọi thắc mắc của khách hàng."
#     },
#     "situation_group3": {
#       "situation_group_name": "Áp dụng công nghệ mới trong bán hàng",
#       "situation1": "Bạn cần giới thiệu và hướng dẫn khách hàng sử dụng ứng dụng di động mới của công ty để đặt hàng. Bạn phải làm rõ các tính năng và lợi ích của ứng dụng.",
#       "situation2": "Trong cuộc họp nội bộ, bạn cần trình bày về việc áp dụng CRM mới để quản lý khách hàng hiệu quả hơn. Bạn phải giải thích cách sử dụng và lợi ích của hệ thống này.",
#       "situation3": "Bạn cần tổ chức một buổi webinar để giới thiệu sản phẩm mới và cách sử dụng công nghệ liên quan. Bạn phải chuẩn bị nội dung hấp dẫn và tương tác với người tham gia."
#     }
#   }
# }
#
# Generated Situation Groups:
# Group: Hỗ trợ và chăm sóc khách hàng
#   - Situation: Khách hàng gọi điện phàn nàn về sản phẩm bị lỗi. Bạn cần lắng nghe, xin lỗi và đề xuất giải pháp thay thế hoặc hoàn tiền.
#   - Situation: Trong cuộc gặp mặt trực tiếp, khách hàng tiềm năng yêu cầu thêm thông tin chi tiết về sản phẩm. Bạn cần trình bày rõ ràng và thuyết phục về các tính năng và lợi ích của sản phẩm.
#   - Situation: Khách hàng quốc tế gửi email yêu cầu hỗ trợ kỹ thuật. Bạn cần trả lời bằng tiếng Anh, giải thích chi tiết và cung cấp hướng dẫn cụ thể.
# Group: Đàm phán và thỏa thuận
#   - Situation: Trong cuộc họp video call với đối tác, bạn cần đàm phán giá cả và điều khoản hợp đồng. Bạn phải chuẩn bị kỹ lưỡng và sử dụng kỹ năng thuyết phục để đạt được thỏa thuận có lợi.
#   - Situation: Khách hàng yêu cầu giảm giá đặc biệt cho đơn hàng lớn. Bạn cần thảo luận với cấp trên và đưa ra đề xuất hợp lý, đồng thời giữ vững mối quan hệ tốt đẹp với khách hàng.
#   - Situation: Trong buổi gặp mặt trực tiếp, bạn cần thuyết phục khách hàng ký hợp đồng dài hạn. Bạn phải trình bày rõ ràng về lợi ích của hợp đồng và giải đáp mọi thắc mắc của khách hàng.
# Group: Áp dụng công nghệ mới trong bán hàng
#   - Situation: Bạn cần giới thiệu và hướng dẫn khách hàng sử dụng ứng dụng di động mới của công ty để đặt hàng. Bạn phải làm rõ các tính năng và lợi ích của ứng dụng.
#   - Situation: Trong cuộc họp nội bộ, bạn cần trình bày về việc áp dụng CRM mới để quản lý khách hàng hiệu quả hơn. Bạn phải giải thích cách sử dụng và lợi ích của hệ thống này.
#   - Situation: Bạn cần tổ chức một buổi webinar để giới thiệu sản phẩm mới và cách sử dụng công nghệ liên quan. Bạn phải chuẩn bị nội dung hấp dẫn và tương tác với người tham gia.
# Processing group: Hỗ trợ và chăm sóc khách hàng
# Generating details for : Khách hàng gọi điện phàn nàn về sản phẩm bị lỗi. Bạn cần lắng nghe, xin lỗi và đề xuất giải pháp thay thế hoặc hoàn tiền.
# Generating details for situation: Khách hàng gọi điện phàn nàn về sản phẩm bị lỗi. Bạn cần lắng nghe, xin lỗi và đề xuất giải pháp thay thế hoặc hoàn tiền.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Đại diện bán hàng (sales representative)
# TOPIC: Hỗ trợ và chăm sóc khách hàng
# TÊN TÌNH HUỐNG: Khách hàng gọi điện phàn nàn về sản phẩm bị lỗi. Bạn cần lắng nghe, xin lỗi và đề xuất giải pháp thay thế hoặc hoàn tiền.
# CHI TIẾT TÌNH HUỐNG: Bạn là một đại diện bán hàng tại một công ty điện tử. Một khách hàng gọi điện phàn nàn về sản phẩm điện thoại thông minh mà họ mới mua bị lỗi. Khách hàng rất bực bội vì sản phẩm không hoạt động như mong đợi và họ đã thử nhiều cách nhưng không khắc phục được. Bạn cần lắng nghe khách hàng, xin lỗi về sự cố và đề xuất giải pháp thay thế hoặc hoàn tiền. Khách hàng này là một người nước ngoài, vì vậy bạn cần chú ý đến yếu tố văn hóa và ngôn ngữ trong giao tiếp.
# NHÂN VẬT TÔI: Đại diện bán hàng
# NHÂN VẬT AI: Khách hàng bực bội
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, my name is Sarah. I recently bought a smartphone from your company, and it's not working properly. I've tried everything, but it still doesn't work. Can you help me with this?
# LIST CÂU HỎI do AI hỏi: 1. Can you describe the issue you're experiencing with the smartphone?
# 2. Have you tried any troubleshooting steps so far?
# 3. Would you prefer a replacement or a refund for the faulty product?
# Generating details for : Trong cuộc gặp mặt trực tiếp, khách hàng tiềm năng yêu cầu thêm thông tin chi tiết về sản phẩm. Bạn cần trình bày rõ ràng và thuyết phục về các tính năng và lợi ích của sản phẩm.
# Generating details for situation: Trong cuộc gặp mặt trực tiếp, khách hàng tiềm năng yêu cầu thêm thông tin chi tiết về sản phẩm. Bạn cần trình bày rõ ràng và thuyết phục về các tính năng và lợi ích của sản phẩm.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Đại diện bán hàng (sales representative)
# TOPIC: Hỗ trợ và chăm sóc khách hàng
# TÊN TÌNH HUỐNG: Trong cuộc gặp mặt trực tiếp, khách hàng tiềm năng yêu cầu thêm thông tin chi tiết về sản phẩm. Bạn cần trình bày rõ ràng và thuyết phục về các tính năng và lợi ích của sản phẩm.
# CHI TIẾT TÌNH HUỐNG: Bạn đang gặp mặt trực tiếp với một khách hàng tiềm năng tại văn phòng của họ. Khách hàng này đã bày tỏ sự quan tâm đến sản phẩm của công ty bạn nhưng cần thêm thông tin chi tiết để đưa ra quyết định. Họ muốn biết rõ hơn về các tính năng, lợi ích và cách sản phẩm có thể giải quyết vấn đề cụ thể của họ. Bạn cần trình bày một cách rõ ràng, thuyết phục và chuyên nghiệp để đảm bảo khách hàng hiểu rõ và tin tưởng vào sản phẩm của bạn.
# NHÂN VẬT TÔI: Đại diện bán hàng
# NHÂN VẬT AI: Khách hàng tiềm năng
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, my name is Anna. I'm very interested in your product, but I need more detailed information before making a decision. Could you please explain the main features of your product?
# LIST CÂU HỎI do AI hỏi: 1. Could you please explain the main features of your product?
# 2. How does your product compare to competitors in the market?
# 3. Can you provide examples of how your product has helped other clients?
# Generating details for : Khách hàng quốc tế gửi email yêu cầu hỗ trợ kỹ thuật. Bạn cần trả lời bằng tiếng Anh, giải thích chi tiết và cung cấp hướng dẫn cụ thể.
# Generating details for situation: Khách hàng quốc tế gửi email yêu cầu hỗ trợ kỹ thuật. Bạn cần trả lời bằng tiếng Anh, giải thích chi tiết và cung cấp hướng dẫn cụ thể.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Đại diện bán hàng (sales representative)
# TOPIC: Hỗ trợ và chăm sóc khách hàng
# TÊN TÌNH HUỐNG: Khách hàng quốc tế gửi email yêu cầu hỗ trợ kỹ thuật. Bạn cần trả lời bằng tiếng Anh, giải thích chi tiết và cung cấp hướng dẫn cụ thể.
# CHI TIẾT TÌNH HUỐNG: Bạn là một Đại diện bán hàng tại một công ty công nghệ quốc tế. Một khách hàng từ Đức đã gửi email yêu cầu hỗ trợ kỹ thuật về sản phẩm phần mềm của công ty. Khách hàng gặp vấn đề khi cài đặt phần mềm và cần hướng dẫn chi tiết. Bạn cần trả lời email bằng tiếng Anh, giải thích chi tiết các bước cần thực hiện và cung cấp hướng dẫn cụ thể để giải quyết vấn đề của khách hàng. Bạn cũng cần đảm bảo rằng khách hàng cảm thấy được hỗ trợ và hài lòng với dịch vụ của công ty.
# NHÂN VẬT TÔI: Đại diện bán hàng
# NHÂN VẬT AI: Khách hàng từ Đức
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, my name is Anna from Germany. I recently purchased your software and I'm having trouble with the installation process. Could you please provide detailed instructions on how to resolve this issue? Thank you!
# LIST CÂU HỎI do AI hỏi: 1. Could you describe the specific issue you are encountering during the installation?
# 2. Have you tried any troubleshooting steps so far? If so, what were they?
# 3. Are you receiving any error messages? If yes, could you please share the exact wording of the error?
# Processing group: Đàm phán và thỏa thuận
# Generating details for : Trong cuộc họp video call với đối tác, bạn cần đàm phán giá cả và điều khoản hợp đồng. Bạn phải chuẩn bị kỹ lưỡng và sử dụng kỹ năng thuyết phục để đạt được thỏa thuận có lợi.
# Generating details for situation: Trong cuộc họp video call với đối tác, bạn cần đàm phán giá cả và điều khoản hợp đồng. Bạn phải chuẩn bị kỹ lưỡng và sử dụng kỹ năng thuyết phục để đạt được thỏa thuận có lợi.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Đại diện bán hàng (sales representative)
# TOPIC: Đàm phán và thỏa thuận
# TÊN TÌNH HUỐNG: Trong cuộc họp video call với đối tác, bạn cần đàm phán giá cả và điều khoản hợp đồng. Bạn phải chuẩn bị kỹ lưỡng và sử dụng kỹ năng thuyết phục để đạt được thỏa thuận có lợi.
# CHI TIẾT TÌNH HUỐNG: Bạn là đại diện bán hàng của công ty ABC, chuyên cung cấp các giải pháp phần mềm quản lý doanh nghiệp. Hôm nay, bạn có cuộc họp video call với đối tác từ công ty XYZ, một công ty quốc tế đang quan tâm đến sản phẩm của bạn. Mục tiêu của bạn là đàm phán giá cả và các điều khoản hợp đồng để đạt được thỏa thuận có lợi nhất cho công ty. Đối tác của bạn là một người có kinh nghiệm trong đàm phán và rất quan tâm đến giá cả và các điều khoản thanh toán. Bạn cần chuẩn bị kỹ lưỡng, nắm rõ các thông tin về sản phẩm, giá cả, và các điều khoản hợp đồng để thuyết phục đối tác.
# NHÂN VẬT TÔI: Đại diện bán hàng
# NHÂN VẬT AI: Đối tác từ công ty XYZ
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, I'm Jane from XYZ. I'm looking forward to discussing the terms and pricing of your software solutions. To start, could you please provide an overview of the pricing structure?
# LIST CÂU HỎI do AI hỏi: 1. Could you please provide an overview of the pricing structure?
# 2. What are the payment terms you are offering?
# 3. How flexible are you with the pricing for long-term contracts?
# Generating details for : Khách hàng yêu cầu giảm giá đặc biệt cho đơn hàng lớn. Bạn cần thảo luận với cấp trên và đưa ra đề xuất hợp lý, đồng thời giữ vững mối quan hệ tốt đẹp với khách hàng.
# Generating details for situation: Khách hàng yêu cầu giảm giá đặc biệt cho đơn hàng lớn. Bạn cần thảo luận với cấp trên và đưa ra đề xuất hợp lý, đồng thời giữ vững mối quan hệ tốt đẹp với khách hàng.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Đại diện bán hàng (sales representative)
# TOPIC: Đàm phán và thỏa thuận
# TÊN TÌNH HUỐNG: Khách hàng yêu cầu giảm giá đặc biệt cho đơn hàng lớn. Bạn cần thảo luận với cấp trên và đưa ra đề xuất hợp lý, đồng thời giữ vững mối quan hệ tốt đẹp với khách hàng.
# CHI TIẾT TÌNH HUỐNG: Bạn là một Đại diện bán hàng tại công ty ABC, chuyên cung cấp các sản phẩm công nghệ cao. Một khách hàng lớn, Công ty XYZ, đã liên hệ với bạn qua video call để yêu cầu một mức giảm giá đặc biệt cho đơn hàng lớn sắp tới. Họ cho biết rằng nếu không được giảm giá, họ sẽ xem xét các nhà cung cấp khác. Bạn cần thảo luận với cấp trên của mình để đưa ra một đề xuất hợp lý, đồng thời giữ vững mối quan hệ tốt đẹp với khách hàng. Bạn sẽ phải cân nhắc các yếu tố như lợi nhuận, khả năng cung cấp, và mối quan hệ lâu dài với khách hàng.
# NHÂN VẬT TÔI: Đại diện bán hàng
# NHÂN VẬT AI: Khách hàng XYZ
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, I'm Jane from XYZ Company. We are considering placing a large order with your company, but we need a special discount to proceed. Can you discuss this with your management and get back to us? What kind of discount can you offer?
# LIST CÂU HỎI do AI hỏi: 1. What kind of discount can you offer for a large order?
# 2. How can we ensure a long-term partnership with your company?
# 3. What are the terms and conditions for the discount?
# Generating details for : Trong buổi gặp mặt trực tiếp, bạn cần thuyết phục khách hàng ký hợp đồng dài hạn. Bạn phải trình bày rõ ràng về lợi ích của hợp đồng và giải đáp mọi thắc mắc của khách hàng.
# Generating details for situation: Trong buổi gặp mặt trực tiếp, bạn cần thuyết phục khách hàng ký hợp đồng dài hạn. Bạn phải trình bày rõ ràng về lợi ích của hợp đồng và giải đáp mọi thắc mắc của khách hàng.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Đại diện bán hàng (sales representative)
# TOPIC: Đàm phán và thỏa thuận
# TÊN TÌNH HUỐNG: Trong buổi gặp mặt trực tiếp, bạn cần thuyết phục khách hàng ký hợp đồng dài hạn. Bạn phải trình bày rõ ràng về lợi ích của hợp đồng và giải đáp mọi thắc mắc của khách hàng.
# CHI TIẾT TÌNH HUỐNG: Bạn là đại diện bán hàng của một công ty cung cấp dịch vụ phần mềm quản lý doanh nghiệp. Hôm nay, bạn có cuộc gặp mặt trực tiếp với ông Nguyễn Văn A, giám đốc của một công ty vừa và nhỏ đang tìm kiếm giải pháp quản lý hiệu quả hơn. Nhiệm vụ của bạn là thuyết phục ông A ký hợp đồng dài hạn với công ty bạn. Bạn cần trình bày rõ ràng về các lợi ích của hợp đồng dài hạn, như tiết kiệm chi phí, hỗ trợ kỹ thuật 24/7, và các tính năng nâng cao của phần mềm. Ông A có một số thắc mắc về chi phí và tính bảo mật của hệ thống, bạn cần giải đáp một cách thuyết phục.
# NHÂN VẬT TÔI: Đại diện bán hàng
# NHÂN VẬT AI: Giám đốc công ty
# Giới tính AI: Nam
# Câu mở đầu của AI: Hello, I'm Nguyễn Văn A, the director of the company. I'm interested in your software management solution, but I have some concerns. Can you explain how a long-term contract with your company would benefit us?
# LIST CÂU HỎI do AI hỏi: 1. Can you explain how a long-term contract with your company would benefit us?
# 2. What are the cost savings associated with a long-term contract?
# 3. How does your system ensure data security and privacy?
# Processing group: Áp dụng công nghệ mới trong bán hàng
# Generating details for : Bạn cần giới thiệu và hướng dẫn khách hàng sử dụng ứng dụng di động mới của công ty để đặt hàng. Bạn phải làm rõ các tính năng và lợi ích của ứng dụng.
# Generating details for situation: Bạn cần giới thiệu và hướng dẫn khách hàng sử dụng ứng dụng di động mới của công ty để đặt hàng. Bạn phải làm rõ các tính năng và lợi ích của ứng dụng.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Đại diện bán hàng (sales representative)
# TOPIC: Áp dụng công nghệ mới trong bán hàng
# TÊN TÌNH HUỐNG: Bạn cần giới thiệu và hướng dẫn khách hàng sử dụng ứng dụng di động mới của công ty để đặt hàng. Bạn phải làm rõ các tính năng và lợi ích của ứng dụng.
# CHI TIẾT TÌNH HUỐNG: Bạn là một đại diện bán hàng của công ty XYZ, và bạn đang có một cuộc gặp mặt trực tiếp với một khách hàng tiềm năng, ông Nguyễn Văn A. Công ty của bạn vừa ra mắt một ứng dụng di động mới giúp khách hàng dễ dàng đặt hàng và theo dõi đơn hàng của họ. Nhiệm vụ của bạn là giới thiệu và hướng dẫn ông A sử dụng ứng dụng này, làm rõ các tính năng và lợi ích của nó. Ông A không quen thuộc với công nghệ và có một số lo ngại về việc sử dụng ứng dụng di động.
# NHÂN VẬT TÔI: Đại diện bán hàng
# NHÂN VẬT AI: Khách hàng tiềm năng
# Giới tính AI: Nam
# Câu mở đầu của AI: Hello, my name is Nguyen Van A. I understand that you have a new mobile application for placing orders. Can you explain how it works and what benefits it offers?
# LIST CÂU HỎI do AI hỏi: 1. Can you explain how to place an order using the app?
# 2. What are the main features of the app?
# 3. How secure is the app for making transactions?
# Generating details for : Trong cuộc họp nội bộ, bạn cần trình bày về việc áp dụng CRM mới để quản lý khách hàng hiệu quả hơn. Bạn phải giải thích cách sử dụng và lợi ích của hệ thống này.
# Generating details for situation: Trong cuộc họp nội bộ, bạn cần trình bày về việc áp dụng CRM mới để quản lý khách hàng hiệu quả hơn. Bạn phải giải thích cách sử dụng và lợi ích của hệ thống này.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Đại diện bán hàng (sales representative)
# TOPIC: Áp dụng công nghệ mới trong bán hàng
# TÊN TÌNH HUỐNG: Trong cuộc họp nội bộ, bạn cần trình bày về việc áp dụng CRM mới để quản lý khách hàng hiệu quả hơn. Bạn phải giải thích cách sử dụng và lợi ích của hệ thống này.
# CHI TIẾT TÌNH HUỐNG: Trong cuộc họp nội bộ của công ty, bạn - một Đại diện bán hàng - được giao nhiệm vụ trình bày về việc áp dụng hệ thống CRM mới để quản lý khách hàng hiệu quả hơn. Cuộc họp có sự tham gia của các thành viên trong đội ngũ bán hàng, quản lý và một số bộ phận liên quan khác. Bạn cần giải thích chi tiết cách sử dụng hệ thống CRM mới, các tính năng nổi bật, và lợi ích mà nó mang lại cho công việc bán hàng. Bạn cũng cần trả lời các câu hỏi và giải quyết các mối quan tâm của đồng nghiệp về việc chuyển đổi sang hệ thống mới.
# NHÂN VẬT TÔI: Đại diện bán hàng
# NHÂN VẬT AI: Quản lý bán hàng
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello everyone, I'm excited to discuss the new CRM system that we will be implementing to enhance our customer management. To start, can you explain how the new CRM system will improve our sales processes?
# LIST CÂU HỎI do AI hỏi: 1. How will the new CRM system improve our sales processes?
# 2. What are the key features of the new CRM system?
# 3. How will the transition to the new CRM system be managed?
# Generating details for : Bạn cần tổ chức một buổi webinar để giới thiệu sản phẩm mới và cách sử dụng công nghệ liên quan. Bạn phải chuẩn bị nội dung hấp dẫn và tương tác với người tham gia.
# Generating details for situation: Bạn cần tổ chức một buổi webinar để giới thiệu sản phẩm mới và cách sử dụng công nghệ liên quan. Bạn phải chuẩn bị nội dung hấp dẫn và tương tác với người tham gia.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Đại diện bán hàng (sales representative)
# TOPIC: Áp dụng công nghệ mới trong bán hàng
# TÊN TÌNH HUỐNG: Bạn cần tổ chức một buổi webinar để giới thiệu sản phẩm mới và cách sử dụng công nghệ liên quan. Bạn phải chuẩn bị nội dung hấp dẫn và tương tác với người tham gia.
# CHI TIẾT TÌNH HUỐNG: Bạn là một Đại diện bán hàng của công ty XYZ, chuyên cung cấp các giải pháp công nghệ cho doanh nghiệp. Công ty vừa ra mắt một sản phẩm mới, một phần mềm quản lý bán hàng tích hợp AI. Bạn được giao nhiệm vụ tổ chức một buổi webinar để giới thiệu sản phẩm này và cách sử dụng công nghệ liên quan. Buổi webinar sẽ có sự tham gia của các khách hàng tiềm năng từ nhiều quốc gia khác nhau. Bạn cần chuẩn bị nội dung hấp dẫn, bao gồm các tính năng nổi bật của sản phẩm, lợi ích khi sử dụng, và các ví dụ thực tế. Ngoài ra, bạn cần tương tác với người tham gia qua phần hỏi đáp trực tiếp và giải đáp các thắc mắc của họ.
# NHÂN VẬT TÔI: Đại diện bán hàng
# NHÂN VẬT AI: Khách hàng tiềm năng
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, my name is Sarah. I'm a potential customer interested in your new sales management software. Could you please explain the main features of this product?
# LIST CÂU HỎI do AI hỏi: 1. Could you please explain the main features of this product?
# 2. How does the AI integration improve sales management?
# 3. Can you provide an example of how this software has benefited other companies?
# Completed processing for job position: Đại diện bán hàng (sales representative)
# Total situations generated: 9
# Sheet 'Đại diện bán hàng (sales repres' added to Excel file
#
# Processing job position: Trưởng phòng Marketing
# Starting process for job position: Trưởng phòng Marketing
# Generating situation groups for Trưởng phòng Marketing...
# {
#   "job_position": "Trưởng phòng Marketing",
#   "situation_groups": {
#     "situation_group1": {
#       "situation_group_name": "Tương tác với đồng nghiệp",
#       "situation1": "Cuộc họp nhóm để thảo luận về chiến lược marketing mới cho sản phẩm sắp ra mắt. Trưởng phòng Marketing cần lắng nghe ý kiến của từng thành viên và đưa ra quyết định cuối cùng.",
#       "situation2": "Gặp mặt trực tiếp với bộ phận thiết kế để điều chỉnh các yếu tố hình ảnh trong chiến dịch quảng cáo. Trưởng phòng Marketing cần giải thích rõ ràng yêu cầu và đảm bảo sự đồng thuận.",
#       "situation3": "Video call với đội ngũ marketing quốc tế để cập nhật và điều chỉnh chiến lược phù hợp với từng thị trường. Trưởng phòng Marketing cần hiểu rõ văn hóa và ngôn ngữ của từng quốc gia để giao tiếp hiệu quả."
#     },
#     "situation_group2": {
#       "situation_group_name": "Báo cáo và đề xuất với cấp trên",
#       "situation1": "Trình bày báo cáo kết quả chiến dịch marketing quý trước với Ban Giám đốc. Trưởng phòng Marketing cần chuẩn bị số liệu cụ thể và giải thích rõ ràng các chỉ số.",
#       "situation2": "Đề xuất ngân sách cho chiến dịch marketing mới trong cuộc họp với Giám đốc Tài chính. Trưởng phòng Marketing cần thuyết phục bằng cách trình bày lợi ích và dự đoán hiệu quả.",
#       "situation3": "Gửi email báo cáo tình hình tiến độ dự án marketing hàng tuần cho CEO. Trưởng phòng Marketing cần viết ngắn gọn, súc tích và đầy đủ thông tin cần thiết."
#     },
#     "situation_group3": {
#       "situation_group_name": "Quản lý khủng hoảng và xử lý tình huống khó",
#       "situation1": "Xử lý phản hồi tiêu cực từ khách hàng trên mạng xã hội về một chiến dịch quảng cáo. Trưởng phòng Marketing cần nhanh chóng đưa ra phản hồi chính thức và giải quyết vấn đề.",
#       "situation2": "Cuộc họp khẩn cấp với đội ngũ PR để đối phó với tin đồn không chính xác về sản phẩm. Trưởng phòng Marketing cần chỉ đạo và phối hợp để đưa ra thông báo chính thức.",
#       "situation3": "Gặp mặt trực tiếp với đối tác để giải quyết mâu thuẫn về hợp đồng quảng cáo. Trưởng phòng Marketing cần lắng nghe, thương lượng và tìm ra giải pháp hợp lý cho cả hai bên."
#     }
#   }
# }
#
# Generated Situation Groups:
# Group: Tương tác với đồng nghiệp
#   - Situation: Cuộc họp nhóm để thảo luận về chiến lược marketing mới cho sản phẩm sắp ra mắt. Trưởng phòng Marketing cần lắng nghe ý kiến của từng thành viên và đưa ra quyết định cuối cùng.
#   - Situation: Gặp mặt trực tiếp với bộ phận thiết kế để điều chỉnh các yếu tố hình ảnh trong chiến dịch quảng cáo. Trưởng phòng Marketing cần giải thích rõ ràng yêu cầu và đảm bảo sự đồng thuận.
#   - Situation: Video call với đội ngũ marketing quốc tế để cập nhật và điều chỉnh chiến lược phù hợp với từng thị trường. Trưởng phòng Marketing cần hiểu rõ văn hóa và ngôn ngữ của từng quốc gia để giao tiếp hiệu quả.
# Group: Báo cáo và đề xuất với cấp trên
#   - Situation: Trình bày báo cáo kết quả chiến dịch marketing quý trước với Ban Giám đốc. Trưởng phòng Marketing cần chuẩn bị số liệu cụ thể và giải thích rõ ràng các chỉ số.
#   - Situation: Đề xuất ngân sách cho chiến dịch marketing mới trong cuộc họp với Giám đốc Tài chính. Trưởng phòng Marketing cần thuyết phục bằng cách trình bày lợi ích và dự đoán hiệu quả.
#   - Situation: Gửi email báo cáo tình hình tiến độ dự án marketing hàng tuần cho CEO. Trưởng phòng Marketing cần viết ngắn gọn, súc tích và đầy đủ thông tin cần thiết.
# Group: Quản lý khủng hoảng và xử lý tình huống khó
#   - Situation: Xử lý phản hồi tiêu cực từ khách hàng trên mạng xã hội về một chiến dịch quảng cáo. Trưởng phòng Marketing cần nhanh chóng đưa ra phản hồi chính thức và giải quyết vấn đề.
#   - Situation: Cuộc họp khẩn cấp với đội ngũ PR để đối phó với tin đồn không chính xác về sản phẩm. Trưởng phòng Marketing cần chỉ đạo và phối hợp để đưa ra thông báo chính thức.
#   - Situation: Gặp mặt trực tiếp với đối tác để giải quyết mâu thuẫn về hợp đồng quảng cáo. Trưởng phòng Marketing cần lắng nghe, thương lượng và tìm ra giải pháp hợp lý cho cả hai bên.
# Processing group: Tương tác với đồng nghiệp
# Generating details for : Cuộc họp nhóm để thảo luận về chiến lược marketing mới cho sản phẩm sắp ra mắt. Trưởng phòng Marketing cần lắng nghe ý kiến của từng thành viên và đưa ra quyết định cuối cùng.
# Generating details for situation: Cuộc họp nhóm để thảo luận về chiến lược marketing mới cho sản phẩm sắp ra mắt. Trưởng phòng Marketing cần lắng nghe ý kiến của từng thành viên và đưa ra quyết định cuối cùng.
