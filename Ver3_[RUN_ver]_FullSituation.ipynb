# %% [markdown]
# ```markdown
# # Summary TASKS - README
#
# ## Overview
# This Jupyter Notebook is designed to generate detailed communication scenarios for various job positions. The scenarios are created using OpenAI's GPT model and are structured to reflect real-world communication challenges in different professional roles.
#
# ## Workflow
# 1. **Import Necessary Libraries**: Import essential libraries such as `os`, `openai`, `json`, `pandas`, and `typing.List`.
# 2. **Define Functions**:
#     - `get_completion(prompt, model="gpt-4o", temperature=0)`: Generates a response from the GPT model based on the provided prompt.
#     - `gen_situation_groups_AND_situation_SHORTVER2(job_position)`: Creates communication situation groups for a given job position.
#     - `gen_detail_situations_SHORTVER_aigender(job_position, situation_group_name, situation, ai_gender)`: Generates detailed communication scenarios for a specific situation within a group.
#     - `gen_situation_group_AND_detail_situation(job_position: str) -> pd.DataFrame`: Combines the above functions to generate detailed scenarios and returns a DataFrame.
#     - `generate_multi_job_situations(job_positions: List[str], filename_output: str) -> str`: Generates scenarios for multiple job positions and saves them to an Excel file.
#
# 3. **Job Positions**: A list of job positions is defined, including roles such as Student, Accountant, Software Engineer, Sales Manager, Teacher, etc.
#
# 4. **Execution**: The notebook is designed to generate scenarios for subsets of job positions, allowing for parallel processing and easier verification of outputs.
#
# ## Usage
# - **Single Job Position**: Use the function `gen_situation_group_AND_detail_situation(job_position)` to generate scenarios for a single job position.
# - **Multiple Job Positions**: Use the function `generate_multi_job_situations(job_positions, filename_output)` to generate scenarios for multiple job positions and save them to an Excel file.
#
# ## Output
# - The output is an Excel file with each job position having its own sheet. Each sheet contains detailed communication scenarios, including the situation name, details, characters involved, AI gender, AI greeting, and a list of questions asked by the AI.
#
# ## Notes
# - The notebook includes print statements to monitor progress and verify the correctness of the generated data.
# - The job positions are processed in smaller subsets to facilitate parallel processing and easier verification of outputs.
#
# ## Example
# To generate scenarios for the job position "Teacher Assistant, Teaching Related (Trợ giảng, Giáo vụ)" and save them to an Excel file:
#
# ```python
# job_positions = ["Teacher Assistant, Teaching Rel"]
# excel_file = generate_multi_job_situations(job_positions, "Teacher_Assistant.xlsx")
# print(f"Final Excel file: {excel_file}")
# ```
# ```

# %%
import os
from openai import OpenAI
import json
import pandas as pd
from typing import List

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

def get_completion(prompt, model="gpt-4o", temperature=0):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message.content

def gen_situation_groups_AND_situation_SHORTVER2(job_position):
    prompt = f"""
    Bạn là chuyên gia về giao tiếp trong môi trường làm việc, đặc biệt là trong lĩnh vực bán hàng.
    
    Nhiệm vụ: Tạo ra 7 nhóm tình huống GIAO TIẾP liên quan đến vị trí công việc "{job_position}",
    bao gồm cả khía cạnh chuyên môn và cá nhân.

    Hướng dẫn:
    1. Yêu cầu bắt buộc về các tình huống 
      - Đúng thể loại: TÌNH HUỐNG GIAO TIẾP 
    2. Các nhóm tình huống GIAO TIẾP: phải bằng tiếng Việt, ngắn gọn, và xoay quanh vị trí công việc của "{job_position}".
    3. Mỗi nhóm tình huống có 7 tình huống cụ thể hơn, nhưng vẫn ngắn gọn, và đảm bảo:
      - Tính tương tác cao: Tập trung vào các tình huống GIAO TIẾP TRỰC TIẾP: gặp mặt trực tiếp, cuộc gọi thoại, video call, <<Tuyệt đối không gồm tình huống "GIAO TIẾP QUA EMAIL">>
      - Tính ứng dụng thực tế: Phản ánh thực tế công việc, sử dụng ngôn ngữ gần gũi và dễ hiểu , kết hợp với thuật ngữ chuyên ngành của vị trí {job_position}.
      - Tính tình huống và kỹ năng xử lý: Tạo ra các tình huống thách thức, đa chiều và phức tạp, đòi hỏi sự kết hợp nhiều kỹ năng, đảm bảo cân đối để bao quát toàn diện công việc.
      - Tính cụ thể: Thêm chi tiết cụ thể hoặc bối cảnh để làm sống động tình huống GIAO TIẾP ở vị trí {job_position}.
      - Yếu tố văn hóa: Bao gồm tình huống liên quan đến giao tiếp đa văn hóa khi làm việc với khách hàng hoặc đối tác quốc tế.
      - Cập nhật xu hướng mới: Đưa vào các xu hướng mới nhất trong công việc và ngành của vị trí {job_position}, tạo ra các tình huống sáng tạo và thử thách để phát triển kỹ năng toàn diện.

    3'. Gợi ý các nhóm tình huống (không giới hạn ở các gợi ý này): <<Tuyệt đối không gồm tình huống "GIAO TIẾP QUA EMAIL">>
    - Tương tác với đồng nghiệp
    - Báo cáo và đề xuất với cấp trên
    - Hỗ trợ và chăm sóc khách hàng
    - Đàm phán và thỏa thuận
    - Quản lý khủng hoảng và xử lý tình huống khó
    - Đào tạo và phát triển bản thân/đồng nghiệp
    - Tham gia hội nghị và sự kiện ngành
    - Xây dựng mạng lưới quan hệ
    - Áp dụng công nghệ mới trong bán hàng
    - Thích ứng với thay đổi thị trường
    - Đánh giá hiệu suất và đề xuất cải tiến
    - Tuyển dụng và phỏng vấn
    - Quảng bá và marketing, Đảm bảo chất lượng, Phát triển sản phẩm, Quản lý tài chính

    Trả về một đối tượng JSON có cấu trúc sau:
    {{
      "job_position": "{job_position}",
      "situation_groups": {{
        "situation_group1": {{
          "situation_group_name": "Tên nhóm tình huống 1",
          "situation1": "Tình huống 1",
          "situation2": "Tình huống 2",
          "situation3": "Tình huống 3", 
          "situation4": "Tình huống 4", 
          "situation5": "Tình huống 5", 
          "situation6": "Tình huống 6", 
          "situation7": "Tình huống 7"
          ...
        }},
        "situation_group2": {{
          "situation_group_name": "Tên nhóm tình huống 2",
          "situation1": "Tình huống 1",
          "situation2": "Tình huống 2"
          ...
          <5-7 situation>
        }},
        ...
      }}
    }}


    Example 
      {{
        "job_position": "Đại diện bán hàng (sales representative)",
        "situation_groups": [
          {{
            "situation_group_name": "Hỗ trợ khách hàng",
            "situation1": "Giải đáp thắc mắc của khách hàng về sản phẩm.",
            "situation2": "Xử lý khiếu nại của khách hàng một cách chuyên nghiệp.",
            "situation3": "Hướng dẫn khách hàng sử dụng sản phẩm mới.",
            "situation4": "Theo dõi và đảm bảo khách hàng hài lòng sau khi mua hàng.",
            "situation5": "Đề xuất giải pháp phù hợp với nhu cầu của khách hàng.",
            "situation6": "Gửi thông tin khuyến mãi và ưu đãi đặc biệt cho khách hàng.",
            "situation7": "Tạo mối quan hệ lâu dài với khách hàng qua các cuộc gọi chăm sóc định kỳ."
          }},
          {{
            "situation_group_name": "Kỹ năng bán hàng",
            "situation1": "Thuyết phục khách hàng mua sản phẩm.",
            "situation2": "Giới thiệu sản phẩm một cách hấp dẫn và thuyết phục.",
            "situation3": "Đàm phán giá cả và điều kiện bán hàng.",
            "situation4": "Xây dựng chiến lược bán hàng hiệu quả.",
            "situation5": "Nắm bắt và phân tích nhu cầu của khách hàng.",
            "situation6": "Đưa ra các giải pháp sáng tạo để tăng doanh số.",
            "situation7": "Theo dõi và đánh giá kết quả bán hàng."
          }}
        ]
      }}

    Đảm bảo đầu ra là một đối tượng JSON hợp lệ không có bất kỳ định dạng hoặc từ khóa bổ sung nào(chẳng hạn ```json).
    """

    # Assuming you have a function called get_completion to generate the response
    response = get_completion(prompt)
    
    # Parse the JSON response
    try:
        topics_dict = json.loads(response)
        return json.dumps(topics_dict, ensure_ascii=False, indent=2)
    except json.JSONDecodeError:
        print("Error: The generated response is not valid JSON. Please check the output.")
        return None



def gen_detail_situations_SHORTVER_aigender(job_position, situation_group_name, situation, ai_gender):
    """
    
    Truyền trực tiếp giới tính AI 
    """
    prompt = f"""
    Bạn là chuyên gia về phát triển nghề nghiệp và tình huống công việc cho vị trí {job_position}.
    
    Nhiệm vụ: Tạo ra chi tiết cho tình huống GIAO TIẾP "{situation}" liên quan đến chủ đề "{situation_group_name}" cho vị trí {job_position}.
    
    Hướng dẫn:
    1. Các đặc điểm của 1 tình huống 
      - Tính tương tác cao: Tập trung vào các tình huống giao tiếp trực tiếp như cuộc gọi điện thoại, video call, hoặc gặp mặt trực tiếp <<tuyệt đối không gồm việc gửi email>>.
      - Tính ứng dụng thực tế: Phản ánh thực tế công việc, sử dụng ngôn ngữ gần gũi và dễ hiểu , kết hợp với thuật ngữ chuyên ngành của vị trí {job_position}.
      - Tính tình huống và kỹ năng xử lý: Tạo ra các tình huống thách thức, đa chiều và phức tạp, đòi hỏi sự kết hợp nhiều kỹ năng, đảm bảo cân đối để bao quát toàn diện công việc.
      - Tính cụ thể: Thêm chi tiết cụ thể hoặc bối cảnh để làm sống động tình huống GIAO TIẾP ở vị trí {job_position}.
      - Yếu tố văn hóa: Bao gồm tình huống liên quan đến giao tiếp đa văn hóa khi làm việc với khách hàng hoặc đối tác quốc tế.
      - Cập nhật xu hướng mới: Đưa vào các xu hướng mới nhất trong công việc và ngành của vị trí {job_position}, tạo ra các tình huống sáng tạo và thử thách để phát triển kỹ năng toàn diện.

    2. Chi tiết tình huống phải bao gồm:
       - Tên tình huống (tiếng Việt): {situation}
       - Chi tiết tình huống GIAO TIẾP (tiếng Việt): Mô tả chi tiết bối cảnh, các bên liên quan, và vấn đề cụ thể cần giải quyết. Đảm bảo tình huống đủ phức tạp để tạo ra thử thách thực tế cho vị trí {job_position}. 
       - Nhân vật của tôi (character_me) (tiếng Việt): Mô tả ngắn gọn trong 25 ký tự hoặc ít hơn, phản ánh vị trí {job_position}.
       - Nhân vật AI (character_ai) (tiếng Việt): Mô tả ngắn gọn trong 25 ký tự hoặc ít hơn, phù hợp với tình huống và vị trí {job_position}.
       - Giới tính của AI: {ai_gender}
       - Danh sách 7 câu hỏi DO NHÂN VẬT AI HỎI liên quan đến tình huống (bằng tiếng Anh): Đảm bảo các câu hỏi đa dạng, từ cơ bản đến phức tạp, và bao quát nhiều khía cạnh của tình huống liên quan đến vị trí {job_position}.
       - Lời chào của AI (bằng tiếng Anh): Bao gồm thông tin cá nhân, chào hỏi cơ bản, nêu rõ bối cảnh tình huống và BẮT BUỘC SẼ HỎI LUÔN "Câu hỏi 1" từ danh sách 7 câu hỏi bên trên <bắt buộc có câu hỏi 1 nhé>.

    Trả về một đối tượng JSON với cấu trúc sau:
    {{
      "job_position": "{job_position}",
      "situation_group_name": "{situation_group_name}",
      "situation": {{
        "situation_name": "{situation}",
        "situation_details": "Chi tiết tình huống",
        "character_me": "Vai trò của người dùng",
        "character_ai": "Vai trò của AI",
        "ai_gender": "{ai_gender}",
        "AI_greeting": "Lời chào của AI bằng tiếng Anh",
        "questions_list": [
          "Câu hỏi 1",
          "Câu hỏi 2",
          "Câu hỏi 3",
          "Câu hỏi 4",
          "Câu hỏi 5",
          "Câu hỏi 6",
          "Câu hỏi 7"
        ]
      }}
    }}
    
    Đảm bảo đầu ra là một đối tượng JSON hợp lệ không có bất kỳ định dạng hoặc từ khóa bổ sung nào.

    

    """

    print(f"Generating details for situation: {situation}")
    response = get_completion(prompt)
    
    try:
        situation_dict = json.loads(response)
        return json.dumps(situation_dict, ensure_ascii=False, indent=2)
    except json.JSONDecodeError:
        print("Error: The generated response is not valid JSON. Please check the output.")
        return None

# %%
import json
import pandas as pd

def gen_situation_group_AND_detail_situation(job_position: str) -> pd.DataFrame:
    """
    - (1 tham số duy nhất)
    - Output: Trả về Output 1 file excel với các cột 
        CÔNG VIỆC	TOPIC	TÊN TÌNH HUỐNG	CHI TIẾT TÌNH HUỐNG	NHÂN VẬT TÔI	NHÂN VẬT AI	Giới tính AI 	Câu mở đầu của AI	"LIST CÂU HỎI do AI hỏi"
    - Thêm các print để kiểm tra tiến độ và fix được lỗi (các print quan trọng, vừa đủ, không quá thừa)

    Output: Vừa có print ra console vừa có output là file excel, return nên là định dạng dễ sử dụng về sau (ĐÓ LÀ: DUYỆT TỪNG job_position ở đâu đó, sử dụng cái hàm gen_situation_group_AND_detail_situation(job_position) để tạo hàng loạt cho job_position, sau đó output gộp lại được thành 1 file với mỗi job_position là 1 sheet)
    - Sau khi tạo các nhóm tình huống, hãy in ra các nhóm tình huống đó trước đã nhé 
    - Tức là thêm các index ở đầu lúc lưu data từng câu hỏi ở cột "LIST CÂU HỎI do AI hỏi"
    - Làm sao để check được data in ra đúng chưa, thay vì phải đợi chạy xong toàn bộ => In ra dữ liệu từng tình huống để kiểm tra
    """
    # Bắt đầu quá trình với vị trí công việc được cung cấp
    print(f"Starting process for job position: {job_position}")
    
    # Bước 1: Tạo nhóm tình huống
    situation_groups_json = gen_situation_groups_AND_situation_SHORTVER2(job_position)
    print(situation_groups_json) # In các nhóm tình huống tạo được
    situation_groups = json.loads(situation_groups_json)
    
    # Sau khi tạo các nhóm tình huống, hãy in ra các nhóm tình huống đó trước đã nhé 
    
    print("\nGenerated Situation Groups:")
    for group_key, group in situation_groups["situation_groups"].items():
        print(f"Group: {group['situation_group_name']}")
        for situation_key, situation_value in group.items():
            if situation_key.startswith("situation") and situation_key != "situation_group_name":
                print(f"  - Situation: {situation_value}")

    # Bước 2: Tạo chi tiết tình huống cho từng nhóm và tình huống
    data = []
    processed_situations = set()  # Để theo dõi các tình huống đã xử lý
    situation_number = 1  # Thêm biến đếm này ĐỂ GEN GIỚI TÍNH
    print(f"Tạo tình huống số {situation_number}")

    # Duyệt qua các nhóm tình huống
    for group_key, group in situation_groups["situation_groups"].items():
        print(f"Processing group: {group['situation_group_name']}")
        # Duyệt qua từng tình huống trong nhóm
        for situation_key, situation_value in group.items():
            # Kiểm tra nếu key bắt đầu với "situation" và tình huống chưa được xử lý
            if situation_key.startswith("situation") and situation_key != "situation_group_name" and situation_value not in processed_situations:
                print(f"Generating details for : {situation_value}")
                # Gọi hàm để tạo chi tiết tình huống
                ai_gender = 'Nữ' if situation_number % 2 != 0 else 'Nam' # Tạo giới tính AI FIX CỨNG NHƯ NÀY ĐỂ TẠO CÂN BẰNG GIỚI

                detailed_situation_json = gen_detail_situations_SHORTVER_aigender(
                    job_position, 
                    group["situation_group_name"], 
                    situation_value, 
                    ai_gender
                )
                detailed_situation = json.loads(detailed_situation_json)
                
                # Lấy dữ liệu chi tiết từ tình huống
                situation_data = detailed_situation["situation"]
                
                # Thêm dữ liệu vào danh sách
                questions_list = situation_data["questions_list"]
                indexed_questions_list = [f"{i+1}. {question}" for i, question in enumerate(questions_list)]
                
                situation_dict = {
                    "CÔNG VIỆC": job_position,
                    "TOPIC": group["situation_group_name"],
                    "TÊN TÌNH HUỐNG": situation_data["situation_name"],
                    "CHI TIẾT TÌNH HUỐNG": situation_data["situation_details"],
                    "NHÂN VẬT TÔI": situation_data["character_me"],
                    "NHÂN VẬT AI": situation_data["character_ai"],
                    "Giới tính AI": situation_data["ai_gender"],
                    "Câu mở đầu của AI": situation_data["AI_greeting"],
                    "LIST CÂU HỎI do AI hỏi": "\n".join(indexed_questions_list)
                }
                
                # Làm sao để check được data in ra đúng chưa, thay vì phải đợi chạy xong toàn bộ => In ra dữ liệu từng tình huống để kiểm tra
                # In ra dữ liệu của tình huống để kiểm tra
                print("\nGenerated Detailed Situation Data:")
                for key, value in situation_dict.items():
                    print(f"{key}: {value}")
                
                data.append(situation_dict)
                
                # Đánh dấu tình huống này đã được xử lý
                processed_situations.add(situation_value)
                situation_number += 1  # Tăng số thứ tự lên sau mỗi tình huống, CHỈ ĐỂ KIỂM SOÁT GIỚI TÍNH AI
                

    # Tạo DataFrame từ danh sách dữ liệu
    df = pd.DataFrame(data)
    print(f"Completed processing for job position: {job_position}")
    print(f"Total situations generated: {len(df)}")
    return df

# %% [markdown]
# ```
# các nhóm công việc sau
# Student/Sinh viên: 9.23%
# Accountant/Kế toán: 8.46%
# IT/Developer/Software Engineer/Engineer/Kỹ sư: 14.62%
# Construction/Contruction Engineer: 1.54%"
# Sales/Sale Manager: 6.92%
# Marketing: 3.08%
# "Teacher/Giáo viên: 6.15%
# Teacher Assistant/Teaching Related: 2.31%"
# Manager/Quản lý: 5.38%
# Logistics: 4.62%
# "Doctor/Bác sĩ: 3.08%
# Pharmacist/Dược sĩ: 2.31%"
# Freelancer: 3.08%
# HR/Human Resources: 3.08%
# Project Manager: 2.31%
# Business: 2.31%
# Customer Service: 1.54%
# Designer: 1.54%
# Business Analyst: 1.54%
# ```

# %% [markdown]
# - 5-6 phút/1 job_position => 120 phút.
# - Thay vì 1 phát 20 jobs => Chia nhỏ.
# 1. Chia nhỏ để chạy song song nhiều nơi
# 2. Chia nhỏ để check được output từng phần trong quá trình đợi gen tiếp các mẻ. <Thay vì xong hết rồi mới check 20 sheet>, thì có thể gen 3 sheet 1 lần, trong lúc đang gen 3 sheet thì check 3 sheet khác.

# %%
def generate_multi_job_situations(job_positions: List[str], filename_output: str) -> str:
    print("Starting multi-job situation generation process...")
    
    # Create a Pandas Excel writer using XlsxWriter as the engine
    with pd.ExcelWriter(filename_output, engine='xlsxwriter') as writer:
        for job_position in job_positions:
            print(f"\nProcessing job position: {job_position}")
            df = gen_situation_group_AND_detail_situation(job_position)
            
            # Write each DataFrame to a different worksheet
            sheet_name = job_position[:31]  # Excel sheet names have a 31 character limit
            df.to_excel(writer, sheet_name=sheet_name, index=False)
            print(f"Sheet '{sheet_name}' added to Excel file")

    print(f"\nExcel file generated: {filename_output}")
    return filename_output



job_list = [
    "Student (Sinh viên)",
    "Accountant (Kế toán)",
    "Software Engineer Engineer (Kỹ sư)",
    "Construction Engineer (Kỹ sư xây dựng)",
    "Sales Manager (Đại diện bán hàng)",
    "Marketing (Marketing)",
    "Teacher (Giáo viên)",
    "Teacher Assistant, Teaching Related (Trợ giảng, Giáo vụ)",
    "Manager (Quản lý)",
    "Logistics (Logistics)",
    "Doctor (Bác sĩ)",
    "Pharmacist (Dược sĩ)",
    "Freelancer (Freelancer)",
    "HR Human Resources (Nhân sự)",
    "Project Manager (Quản lý dự án)",
    "Business (Kinh doanh)",
    "Customer Service (Chăm sóc khách hàng)",
    "Designer (Thiết kế)",
    "Business Analyst (Phân tích kinh doanh)"
]

sublist_1 = job_list[:3]
sublist_2 = job_list[3:6]
sublist_3 = job_list[6:9]
sublist_4 = job_list[9:12]
sublist_5 = job_list[12:15]
sublist_6 = job_list[15:18]
sublist_7 = job_list[18:]

sublist_1, sublist_2, sublist_3, sublist_4, sublist_5, sublist_6, sublist_7


# Example usage
print(sublist_1)
if __name__ == "__main__":
    job_positions = ["Teacher Assistant, Teaching Rel"]
    excel_file = generate_multi_job_situations(job_positions, "Teacher_Assistant.xlsx")
    print(f"Final Excel file: {excel_file}")
# Out:
# ['Student (Sinh viên)', 'Accountant (Kế toán)', 'Software Engineer Engineer (Kỹ sư)']
# Starting multi-job situation generation process...
#
# Processing job position: Teacher Assistant, Teaching Rel
# Starting process for job position: Teacher Assistant, Teaching Rel
# {
#   "job_position": "Teacher Assistant, Teaching Rel",
#   "situation_groups": {
#     "situation_group1": {
#       "situation_group_name": "Tương tác với đồng nghiệp",
#       "situation1": "Thảo luận với giáo viên chính về kế hoạch giảng dạy hàng tuần.",
#       "situation2": "Hỗ trợ đồng nghiệp trong việc chuẩn bị tài liệu giảng dạy.",
#       "situation3": "Tham gia cuộc họp nhóm để chia sẻ kinh nghiệm và ý tưởng giảng dạy.",
#       "situation4": "Giải quyết mâu thuẫn với đồng nghiệp về phương pháp giảng dạy.",
#       "situation5": "Hỗ trợ đồng nghiệp mới trong việc làm quen với môi trường làm việc.",
#       "situation6": "Thảo luận với đồng nghiệp về cách cải thiện chất lượng giảng dạy.",
#       "situation7": "Phối hợp với đồng nghiệp để tổ chức các hoạt động ngoại khóa cho học sinh."
#     },
#     "situation_group2": {
#       "situation_group_name": "Báo cáo và đề xuất với cấp trên",
#       "situation1": "Báo cáo tiến độ học tập của học sinh cho giáo viên chính.",
#       "situation2": "Đề xuất phương pháp giảng dạy mới để cải thiện hiệu quả học tập.",
#       "situation3": "Thảo luận với cấp trên về các vấn đề phát sinh trong lớp học.",
#       "situation4": "Báo cáo về tình hình kỷ luật của học sinh trong lớp.",
#       "situation5": "Đề xuất các hoạt động ngoại khóa để phát triển kỹ năng mềm cho học sinh.",
#       "situation6": "Thảo luận với cấp trên về việc sử dụng công nghệ trong giảng dạy.",
#       "situation7": "Báo cáo kết quả đánh giá học sinh sau mỗi kỳ thi."
#     },
#     "situation_group3": {
#       "situation_group_name": "Hỗ trợ và chăm sóc học sinh",
#       "situation1": "Giải đáp thắc mắc của học sinh về bài học.",
#       "situation2": "Hỗ trợ học sinh gặp khó khăn trong việc học tập.",
#       "situation3": "Tư vấn cho học sinh về phương pháp học tập hiệu quả.",
#       "situation4": "Giải quyết mâu thuẫn giữa các học sinh trong lớp.",
#       "situation5": "Hỗ trợ học sinh trong việc chuẩn bị cho các kỳ thi.",
#       "situation6": "Tổ chức các buổi học bổ trợ cho học sinh yếu kém.",
#       "situation7": "Theo dõi và đánh giá tiến bộ của học sinh."
#     },
#     "situation_group4": {
#       "situation_group_name": "Đàm phán và thỏa thuận",
#       "situation1": "Thảo luận với giáo viên chính về việc phân chia công việc.",
#       "situation2": "Đàm phán với nhà cung cấp về việc mua sắm thiết bị giảng dạy.",
#       "situation3": "Thỏa thuận với phụ huynh về việc hỗ trợ học sinh tại nhà.",
#       "situation4": "Thảo luận với đồng nghiệp về việc tổ chức các hoạt động ngoại khóa.",
#       "situation5": "Đàm phán với ban giám hiệu về việc sử dụng phòng học.",
#       "situation6": "Thỏa thuận với học sinh về việc tuân thủ nội quy lớp học.",
#       "situation7": "Thảo luận với cấp trên về việc điều chỉnh lịch giảng dạy."
#     },
#     "situation_group5": {
#       "situation_group_name": "Quản lý khủng hoảng và xử lý tình huống khó",
#       "situation1": "Xử lý tình huống học sinh gây rối trong lớp học.",
#       "situation2": "Giải quyết mâu thuẫn giữa học sinh và giáo viên.",
#       "situation3": "Hỗ trợ học sinh gặp vấn đề tâm lý.",
#       "situation4": "Xử lý tình huống học sinh bị tai nạn trong giờ học.",
#       "situation5": "Giải quyết khiếu nại của phụ huynh về chất lượng giảng dạy.",
#       "situation6": "Xử lý tình huống học sinh vi phạm nội quy trường học.",
#       "situation7": "Giải quyết tình huống học sinh bị bắt nạt."
#     },
#     "situation_group6": {
#       "situation_group_name": "Đào tạo và phát triển bản thân/đồng nghiệp",
#       "situation1": "Tham gia các khóa đào tạo nâng cao kỹ năng giảng dạy.",
#       "situation2": "Chia sẻ kinh nghiệm giảng dạy với đồng nghiệp mới.",
#       "situation3": "Tham gia các buổi hội thảo chuyên đề về giáo dục.",
#       "situation4": "Hỗ trợ đồng nghiệp trong việc áp dụng phương pháp giảng dạy mới.",
#       "situation5": "Tham gia các buổi họp nhóm để trao đổi kinh nghiệm giảng dạy.",
#       "situation6": "Đề xuất các khóa đào tạo nâng cao kỹ năng cho đồng nghiệp.",
#       "situation7": "Tham gia các hoạt động ngoại khóa để phát triển kỹ năng mềm."
#     },
#     "situation_group7": {
#       "situation_group_name": "Tham gia hội nghị và sự kiện ngành",
#       "situation1": "Tham gia hội nghị giáo dục quốc tế để cập nhật xu hướng mới.",
#       "situation2": "Tham gia các buổi hội thảo chuyên đề về phương pháp giảng dạy.",
#       "situation3": "Tham gia các sự kiện giao lưu với các trường học khác.",
#       "situation4": "Tham gia các buổi triển lãm công nghệ giáo dục.",
#       "situation5": "Tham gia các buổi hội thảo về phát triển kỹ năng mềm cho học sinh.",
#       "situation6": "Tham gia các buổi hội thảo về quản lý lớp học hiệu quả.",
#       "situation7": "Tham gia các buổi hội thảo về giáo dục đa văn hóa."
#     }
#   }
# }
#
# Generated Situation Groups:
# Group: Tương tác với đồng nghiệp
#   - Situation: Thảo luận với giáo viên chính về kế hoạch giảng dạy hàng tuần.
#   - Situation: Hỗ trợ đồng nghiệp trong việc chuẩn bị tài liệu giảng dạy.
#   - Situation: Tham gia cuộc họp nhóm để chia sẻ kinh nghiệm và ý tưởng giảng dạy.
#   - Situation: Giải quyết mâu thuẫn với đồng nghiệp về phương pháp giảng dạy.
#   - Situation: Hỗ trợ đồng nghiệp mới trong việc làm quen với môi trường làm việc.
#   - Situation: Thảo luận với đồng nghiệp về cách cải thiện chất lượng giảng dạy.
#   - Situation: Phối hợp với đồng nghiệp để tổ chức các hoạt động ngoại khóa cho học sinh.
# Group: Báo cáo và đề xuất với cấp trên
#   - Situation: Báo cáo tiến độ học tập của học sinh cho giáo viên chính.
#   - Situation: Đề xuất phương pháp giảng dạy mới để cải thiện hiệu quả học tập.
#   - Situation: Thảo luận với cấp trên về các vấn đề phát sinh trong lớp học.
#   - Situation: Báo cáo về tình hình kỷ luật của học sinh trong lớp.
#   - Situation: Đề xuất các hoạt động ngoại khóa để phát triển kỹ năng mềm cho học sinh.
#   - Situation: Thảo luận với cấp trên về việc sử dụng công nghệ trong giảng dạy.
#   - Situation: Báo cáo kết quả đánh giá học sinh sau mỗi kỳ thi.
# Group: Hỗ trợ và chăm sóc học sinh
#   - Situation: Giải đáp thắc mắc của học sinh về bài học.
#   - Situation: Hỗ trợ học sinh gặp khó khăn trong việc học tập.
#   - Situation: Tư vấn cho học sinh về phương pháp học tập hiệu quả.
#   - Situation: Giải quyết mâu thuẫn giữa các học sinh trong lớp.
#   - Situation: Hỗ trợ học sinh trong việc chuẩn bị cho các kỳ thi.
#   - Situation: Tổ chức các buổi học bổ trợ cho học sinh yếu kém.
#   - Situation: Theo dõi và đánh giá tiến bộ của học sinh.
# Group: Đàm phán và thỏa thuận
#   - Situation: Thảo luận với giáo viên chính về việc phân chia công việc.
#   - Situation: Đàm phán với nhà cung cấp về việc mua sắm thiết bị giảng dạy.
#   - Situation: Thỏa thuận với phụ huynh về việc hỗ trợ học sinh tại nhà.
#   - Situation: Thảo luận với đồng nghiệp về việc tổ chức các hoạt động ngoại khóa.
#   - Situation: Đàm phán với ban giám hiệu về việc sử dụng phòng học.
#   - Situation: Thỏa thuận với học sinh về việc tuân thủ nội quy lớp học.
#   - Situation: Thảo luận với cấp trên về việc điều chỉnh lịch giảng dạy.
# Group: Quản lý khủng hoảng và xử lý tình huống khó
#   - Situation: Xử lý tình huống học sinh gây rối trong lớp học.
#   - Situation: Giải quyết mâu thuẫn giữa học sinh và giáo viên.
#   - Situation: Hỗ trợ học sinh gặp vấn đề tâm lý.
#   - Situation: Xử lý tình huống học sinh bị tai nạn trong giờ học.
#   - Situation: Giải quyết khiếu nại của phụ huynh về chất lượng giảng dạy.
#   - Situation: Xử lý tình huống học sinh vi phạm nội quy trường học.
#   - Situation: Giải quyết tình huống học sinh bị bắt nạt.
# Group: Đào tạo và phát triển bản thân/đồng nghiệp
#   - Situation: Tham gia các khóa đào tạo nâng cao kỹ năng giảng dạy.
#   - Situation: Chia sẻ kinh nghiệm giảng dạy với đồng nghiệp mới.
#   - Situation: Tham gia các buổi hội thảo chuyên đề về giáo dục.
#   - Situation: Hỗ trợ đồng nghiệp trong việc áp dụng phương pháp giảng dạy mới.
#   - Situation: Tham gia các buổi họp nhóm để trao đổi kinh nghiệm giảng dạy.
#   - Situation: Đề xuất các khóa đào tạo nâng cao kỹ năng cho đồng nghiệp.
#   - Situation: Tham gia các hoạt động ngoại khóa để phát triển kỹ năng mềm.
# Group: Tham gia hội nghị và sự kiện ngành
#   - Situation: Tham gia hội nghị giáo dục quốc tế để cập nhật xu hướng mới.
#   - Situation: Tham gia các buổi hội thảo chuyên đề về phương pháp giảng dạy.
#   - Situation: Tham gia các sự kiện giao lưu với các trường học khác.
#   - Situation: Tham gia các buổi triển lãm công nghệ giáo dục.
#   - Situation: Tham gia các buổi hội thảo về phát triển kỹ năng mềm cho học sinh.
#   - Situation: Tham gia các buổi hội thảo về quản lý lớp học hiệu quả.
#   - Situation: Tham gia các buổi hội thảo về giáo dục đa văn hóa.
# Tạo tình huống số 1
# Processing group: Tương tác với đồng nghiệp
# Generating details for : Thảo luận với giáo viên chính về kế hoạch giảng dạy hàng tuần.
# Generating details for situation: Thảo luận với giáo viên chính về kế hoạch giảng dạy hàng tuần.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Tương tác với đồng nghiệp
# TÊN TÌNH HUỐNG: Thảo luận với giáo viên chính về kế hoạch giảng dạy hàng tuần.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường trung học quốc tế. Mỗi tuần, bạn cần thảo luận với giáo viên chính về kế hoạch giảng dạy để đảm bảo rằng bạn hiểu rõ các mục tiêu học tập, phương pháp giảng dạy và các hoạt động lớp học. Trong cuộc họp này, bạn cần làm rõ các nhiệm vụ của mình, đề xuất ý tưởng mới và giải quyết bất kỳ vấn đề nào phát sinh từ tuần trước. Giáo viên chính là một người có kinh nghiệm lâu năm và đến từ một nền văn hóa khác, do đó, bạn cần phải giao tiếp một cách hiệu quả và tôn trọng sự khác biệt văn hóa.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Giáo viên chính
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, I'm Ms. Smith, the lead teacher for this class. Let's discuss our teaching plan for the upcoming week. To start, can you tell me how the students responded to last week's activities?
# LIST CÂU HỎI do AI hỏi: 1. Can you tell me how the students responded to last week's activities?
# 2. Do you have any suggestions for improving our lesson plans?
# 3. Are there any specific students who need additional support?
# 4. How do you feel about incorporating more interactive activities?
# 5. What challenges did you face last week?
# 6. Do you have any ideas for integrating technology into our lessons?
# 7. How can we better address the diverse cultural backgrounds of our students?
# Generating details for : Hỗ trợ đồng nghiệp trong việc chuẩn bị tài liệu giảng dạy.
# Generating details for situation: Hỗ trợ đồng nghiệp trong việc chuẩn bị tài liệu giảng dạy.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Tương tác với đồng nghiệp
# TÊN TÌNH HUỐNG: Hỗ trợ đồng nghiệp trong việc chuẩn bị tài liệu giảng dạy.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường đại học quốc tế. Một giảng viên mới, thầy John, đang gặp khó khăn trong việc chuẩn bị tài liệu giảng dạy cho khóa học sắp tới về Khoa học Máy tính. Thầy John đến từ một quốc gia khác và chưa quen với hệ thống giáo dục và phong cách giảng dạy tại đây. Bạn được yêu cầu hỗ trợ thầy John trong việc chuẩn bị tài liệu giảng dạy, bao gồm việc tạo slide bài giảng, bài tập và tài liệu tham khảo. Cuộc gặp mặt trực tiếp diễn ra tại văn phòng của thầy John, nơi bạn cần phải lắng nghe, hiểu rõ yêu cầu của thầy và đưa ra các đề xuất hữu ích.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Giảng viên mới
# Giới tính AI: Nam
# Câu mở đầu của AI: Hello, I'm John, the new lecturer here. I understand you are here to help me with preparing the teaching materials for my upcoming Computer Science course. Can you tell me what specific resources are available for creating lecture slides?
# LIST CÂU HỎI do AI hỏi: 1. Can you tell me what specific resources are available for creating lecture slides?
# 2. What are the key topics that should be covered in the first few lectures?
# 3. How do students here typically respond to interactive elements in lectures?
# 4. Are there any specific guidelines or templates we need to follow for the course materials?
# 5. What kind of assignments and assessments are most effective for this course?
# 6. How can we incorporate multicultural perspectives into the course content?
# 7. What are some common challenges students face in this course, and how can we address them?
# Generating details for : Tham gia cuộc họp nhóm để chia sẻ kinh nghiệm và ý tưởng giảng dạy.
# Generating details for situation: Tham gia cuộc họp nhóm để chia sẻ kinh nghiệm và ý tưởng giảng dạy.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Tương tác với đồng nghiệp
# TÊN TÌNH HUỐNG: Tham gia cuộc họp nhóm để chia sẻ kinh nghiệm và ý tưởng giảng dạy.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường trung học quốc tế. Hôm nay, bạn tham gia một cuộc họp nhóm với các giáo viên và trợ giảng khác để chia sẻ kinh nghiệm và ý tưởng giảng dạy. Cuộc họp diễn ra trực tiếp tại phòng họp của trường. Trong cuộc họp, bạn cần trình bày một ý tưởng mới về phương pháp giảng dạy mà bạn đã thử nghiệm và thấy hiệu quả. Bạn cũng cần lắng nghe và phản hồi ý kiến của các đồng nghiệp về ý tưởng của mình, cũng như đóng góp ý kiến cho các ý tưởng khác. Cuộc họp có sự tham gia của các giáo viên từ nhiều quốc gia khác nhau, do đó, bạn cần chú ý đến yếu tố văn hóa và ngôn ngữ trong giao tiếp.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Giáo viên
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, I'm Ms. Johnson, one of the senior teachers here. I'm excited to hear about your new teaching method. Could you please start by explaining the main idea behind your method?
# LIST CÂU HỎI do AI hỏi: 1. Could you please start by explaining the main idea behind your method?
# 2. What inspired you to develop this teaching method?
# 3. How have your students responded to this new method?
# 4. What challenges did you face while implementing this method?
# 5. How do you think this method can be adapted for different subjects or age groups?
# 6. Have you noticed any improvements in student engagement or performance?
# 7. What resources or support do you need to further develop this method?
# Generating details for : Giải quyết mâu thuẫn với đồng nghiệp về phương pháp giảng dạy.
# Generating details for situation: Giải quyết mâu thuẫn với đồng nghiệp về phương pháp giảng dạy.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Tương tác với đồng nghiệp
# TÊN TÌNH HUỐNG: Giải quyết mâu thuẫn với đồng nghiệp về phương pháp giảng dạy.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường quốc tế, và bạn đang làm việc cùng với một giáo viên chính tên là Mr. John. Gần đây, bạn và Mr. John đã có một số mâu thuẫn về phương pháp giảng dạy. Bạn ủng hộ việc sử dụng công nghệ và phương pháp học tập tích cực, trong khi Mr. John lại tin rằng phương pháp truyền thống là hiệu quả nhất. Mâu thuẫn này đã ảnh hưởng đến không khí làm việc và hiệu quả giảng dạy. Bạn quyết định gặp Mr. John để thảo luận và tìm ra giải pháp hợp lý.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Mr. John
# Giới tính AI: Nam
# Câu mở đầu của AI: Hello, I'm Mr. John, the main teacher you're assisting. I understand we have some differences in our teaching methods. Let's discuss this to find a common ground. What specific concerns do you have about my traditional teaching methods?
# LIST CÂU HỎI do AI hỏi: 1. What specific concerns do you have about my traditional teaching methods?
# 2. How do you think technology can enhance our students' learning experience?
# 3. Can you provide examples of how active learning has benefited our students?
# 4. What challenges do you foresee if we integrate more technology into our lessons?
# 5. How do you propose we balance traditional and modern teaching methods?
# 6. Have you received any feedback from students regarding our current teaching methods?
# 7. What support or resources do you think we need to effectively implement these changes?
# Generating details for : Hỗ trợ đồng nghiệp mới trong việc làm quen với môi trường làm việc.
# Generating details for situation: Hỗ trợ đồng nghiệp mới trong việc làm quen với môi trường làm việc.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Tương tác với đồng nghiệp
# TÊN TÌNH HUỐNG: Hỗ trợ đồng nghiệp mới trong việc làm quen với môi trường làm việc.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng có kinh nghiệm tại một trường quốc tế. Một đồng nghiệp mới, cô Lan, vừa gia nhập đội ngũ và cần sự hỗ trợ để làm quen với môi trường làm việc. Bạn được giao nhiệm vụ giúp cô Lan hiểu rõ các quy trình, văn hóa làm việc, và cách tương tác với học sinh và đồng nghiệp. Trong buổi gặp mặt trực tiếp, bạn sẽ hướng dẫn cô Lan về các quy định của trường, cách sử dụng các công cụ giảng dạy, và cách xử lý các tình huống thường gặp trong lớp học. Đồng thời, bạn cũng cần giúp cô Lan làm quen với các đồng nghiệp khác và tạo mối quan hệ tốt đẹp trong môi trường làm việc đa văn hóa.
# NHÂN VẬT TÔI: Trợ giảng kinh nghiệm
# NHÂN VẬT AI: Đồng nghiệp mới
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hi, I'm Lan, the new teaching assistant. I'm excited to be here and learn from you. Could you please tell me about the school's main policies and procedures?
# LIST CÂU HỎI do AI hỏi: 1. Could you please tell me about the school's main policies and procedures?
# 2. How do we usually interact with students during class?
# 3. What are the key tools and resources we use for teaching here?
# 4. Can you explain how we handle classroom management and discipline?
# 5. How do we collaborate with other teachers and staff members?
# 6. Are there any cultural norms or practices I should be aware of in this school?
# 7. What are some common challenges new teaching assistants face here, and how can I overcome them?
# Generating details for : Thảo luận với đồng nghiệp về cách cải thiện chất lượng giảng dạy.
# Generating details for situation: Thảo luận với đồng nghiệp về cách cải thiện chất lượng giảng dạy.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Tương tác với đồng nghiệp
# TÊN TÌNH HUỐNG: Thảo luận với đồng nghiệp về cách cải thiện chất lượng giảng dạy.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường trung học quốc tế. Gần đây, bạn nhận thấy rằng học sinh trong lớp học của bạn không đạt được kết quả tốt như mong đợi. Bạn quyết định thảo luận với một đồng nghiệp, người cũng là một trợ giảng, để tìm ra các phương pháp cải thiện chất lượng giảng dạy. Cuộc thảo luận diễn ra trong một cuộc họp trực tiếp tại phòng giáo viên. Bạn cần phải đưa ra các ý kiến và lắng nghe quan điểm của đồng nghiệp để cùng nhau tìm ra giải pháp hiệu quả.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Đồng nghiệp
# Giới tính AI: Nam
# Câu mở đầu của AI: Hi, I'm John, your fellow Teacher Assistant. I heard you wanted to discuss ways to improve our teaching quality. What specific issues have you noticed in our current teaching methods?
# LIST CÂU HỎI do AI hỏi: 1. What specific issues have you noticed in our current teaching methods?
# 2. How do you think we can better engage our students during lessons?
# 3. Have you tried any new teaching techniques recently that worked well?
# 4. What feedback have you received from students about our classes?
# 5. Do you think incorporating more technology in our lessons would help?
# 6. How can we better support students who are struggling?
# 7. What role do you think classroom environment plays in student learning?
# Generating details for : Phối hợp với đồng nghiệp để tổ chức các hoạt động ngoại khóa cho học sinh.
# Generating details for situation: Phối hợp với đồng nghiệp để tổ chức các hoạt động ngoại khóa cho học sinh.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Tương tác với đồng nghiệp
# TÊN TÌNH HUỐNG: Phối hợp với đồng nghiệp để tổ chức các hoạt động ngoại khóa cho học sinh.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường trung học quốc tế. Trường đang lên kế hoạch tổ chức một chuỗi các hoạt động ngoại khóa nhằm phát triển kỹ năng mềm cho học sinh. Bạn được giao nhiệm vụ phối hợp với một giáo viên khác để lên kế hoạch và tổ chức các hoạt động này. Trong cuộc họp trực tiếp, bạn và đồng nghiệp cần thảo luận về các ý tưởng, phân công nhiệm vụ, và giải quyết các vấn đề phát sinh như ngân sách, thời gian, và sự tham gia của học sinh. Đồng nghiệp của bạn là một giáo viên có kinh nghiệm nhưng có phong cách làm việc khá khác biệt so với bạn. Bạn cần tìm cách để hợp tác hiệu quả và đảm bảo các hoạt động diễn ra suôn sẻ.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Giáo viên
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hi, I'm Ms. Nguyen, the lead teacher for this extracurricular project. I'm excited to work with you on this. To start, what are your initial ideas for the activities?
# LIST CÂU HỎI do AI hỏi: 1. What are your initial ideas for the activities?
# 2. How do you think we should divide the tasks?
# 3. What is your experience with managing budgets for such events?
# 4. How can we ensure maximum student participation?
# 5. What challenges do you foresee, and how can we address them?
# 6. How do you prefer to communicate and coordinate our efforts?
# 7. Do you have any suggestions for involving parents or the community?
# Processing group: Báo cáo và đề xuất với cấp trên
# Generating details for : Báo cáo tiến độ học tập của học sinh cho giáo viên chính.
# Generating details for situation: Báo cáo tiến độ học tập của học sinh cho giáo viên chính.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Báo cáo và đề xuất với cấp trên
# TÊN TÌNH HUỐNG: Báo cáo tiến độ học tập của học sinh cho giáo viên chính.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường quốc tế và được giao nhiệm vụ báo cáo tiến độ học tập của học sinh cho giáo viên chính. Học sinh trong lớp có nhiều quốc tịch khác nhau, và bạn cần phải trình bày rõ ràng, chi tiết về từng học sinh, bao gồm cả những khó khăn và thành tựu của họ. Cuộc họp diễn ra trực tiếp tại văn phòng của giáo viên chính. Bạn cần chuẩn bị kỹ lưỡng và sẵn sàng trả lời các câu hỏi chi tiết từ giáo viên chính về từng học sinh.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Giáo viên chính
# Giới tính AI: Nam
# Câu mở đầu của AI: Hello, I'm Mr. Smith, the lead teacher. I understand you have the progress reports for our students. Let's start with the first student. How has their performance been in the last month?
# LIST CÂU HỎI do AI hỏi: 1. How has their performance been in the last month?
# 2. What specific challenges has this student faced?
# 3. Have there been any notable improvements?
# 4. How is this student interacting with their peers?
# 5. Are there any particular subjects where they excel or struggle?
# 6. What strategies have you implemented to support this student?
# 7. Do you have any recommendations for further support or resources?
# Generating details for : Đề xuất phương pháp giảng dạy mới để cải thiện hiệu quả học tập.
# Generating details for situation: Đề xuất phương pháp giảng dạy mới để cải thiện hiệu quả học tập.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Báo cáo và đề xuất với cấp trên
# TÊN TÌNH HUỐNG: Đề xuất phương pháp giảng dạy mới để cải thiện hiệu quả học tập.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường đại học quốc tế. Gần đây, bạn nhận thấy rằng phương pháp giảng dạy hiện tại không còn hiệu quả với sinh viên. Bạn đã nghiên cứu và phát triển một phương pháp giảng dạy mới, kết hợp công nghệ và các phương pháp học tập hiện đại. Bạn muốn trình bày đề xuất này với trưởng khoa để nhận được sự chấp thuận và hỗ trợ triển khai. Cuộc họp diễn ra trực tiếp tại văn phòng của trưởng khoa, và bạn cần thuyết phục bà ấy về tính khả thi và lợi ích của phương pháp mới này.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Trưởng khoa
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, I'm Dr. Nguyen, the head of the department. I understand you have a new teaching method proposal to discuss. Could you start by explaining the main issues you've identified with our current teaching methods?
# LIST CÂU HỎI do AI hỏi: 1. Could you start by explaining the main issues you've identified with our current teaching methods?
# 2. What specific improvements do you expect from this new teaching method?
# 3. How do you plan to integrate technology into your proposed method?
# 4. Have you conducted any preliminary tests or pilot programs to support your proposal?
# 5. What kind of support or resources will you need from the department to implement this new method?
# 6. How do you plan to measure the effectiveness of this new teaching method?
# 7. Are there any potential challenges or risks associated with this new method, and how do you plan to address them?
# Generating details for : Thảo luận với cấp trên về các vấn đề phát sinh trong lớp học.
# Generating details for situation: Thảo luận với cấp trên về các vấn đề phát sinh trong lớp học.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Báo cáo và đề xuất với cấp trên
# TÊN TÌNH HUỐNG: Thảo luận với cấp trên về các vấn đề phát sinh trong lớp học.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng trong một lớp học quốc tế với học sinh đến từ nhiều nền văn hóa khác nhau. Gần đây, bạn nhận thấy một số vấn đề phát sinh trong lớp học như học sinh không tập trung, xung đột văn hóa giữa các học sinh, và một số học sinh gặp khó khăn trong việc theo kịp bài giảng. Bạn quyết định gặp trực tiếp giáo viên chính để thảo luận về những vấn đề này và đề xuất các giải pháp. Cuộc gặp diễn ra trong phòng họp của trường, và bạn cần trình bày rõ ràng, cụ thể các vấn đề và đề xuất của mình.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Giáo viên chính
# Giới tính AI: Nam
# Câu mở đầu của AI: Hello, I'm Mr. Smith, the lead teacher for this class. I understand you wanted to discuss some issues that have arisen in the classroom. Could you please start by explaining what specific problems you've noticed?
# LIST CÂU HỎI do AI hỏi: 1. Could you please start by explaining what specific problems you've noticed?
# 2. How have these issues affected the students' learning experience?
# 3. Have you observed any particular patterns or recurring incidents?
# 4. What strategies have you already tried to address these issues?
# 5. Do you have any specific suggestions or solutions in mind?
# 6. How do you think we can better support the students who are struggling?
# 7. Is there any additional support or resources you think we need to implement these solutions?
# Generating details for : Báo cáo về tình hình kỷ luật của học sinh trong lớp.
# Generating details for situation: Báo cáo về tình hình kỷ luật của học sinh trong lớp.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Báo cáo và đề xuất với cấp trên
# TÊN TÌNH HUỐNG: Báo cáo về tình hình kỷ luật của học sinh trong lớp.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng trong lớp học của cô giáo Linh. Gần đây, lớp học có một số vấn đề về kỷ luật, bao gồm việc học sinh không tuân thủ nội quy lớp học, gây ồn ào và không hoàn thành bài tập. Bạn đã quan sát và ghi nhận các vấn đề này trong suốt tuần qua. Hôm nay, bạn có cuộc họp trực tiếp với cô giáo Linh để báo cáo về tình hình kỷ luật của học sinh và đề xuất các biện pháp cải thiện.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Cô giáo Linh
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, I'm Ms. Linh, the class teacher. I understand you have some concerns about the students' discipline in our class. Can you please start by telling me what specific issues you've observed?
# LIST CÂU HỎI do AI hỏi: 1. Can you please start by telling me what specific issues you've observed?
# 2. How frequently are these disciplinary issues occurring?
# 3. Are there particular students who are more frequently involved in these issues?
# 4. What steps have you already taken to address these problems?
# 5. How have the students responded to your initial interventions?
# 6. Do you have any specific suggestions for improving the situation?
# 7. Is there any additional support you think we might need from the school administration?
# Generating details for : Đề xuất các hoạt động ngoại khóa để phát triển kỹ năng mềm cho học sinh.
# Generating details for situation: Đề xuất các hoạt động ngoại khóa để phát triển kỹ năng mềm cho học sinh.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Báo cáo và đề xuất với cấp trên
# TÊN TÌNH HUỐNG: Đề xuất các hoạt động ngoại khóa để phát triển kỹ năng mềm cho học sinh.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường quốc tế và nhận thấy rằng học sinh cần phát triển thêm các kỹ năng mềm như giao tiếp, làm việc nhóm, và quản lý thời gian. Bạn đã nghiên cứu và lên kế hoạch cho một số hoạt động ngoại khóa nhằm phát triển những kỹ năng này. Hôm nay, bạn có cuộc gặp trực tiếp với thầy John, trưởng bộ phận học thuật, để trình bày và thuyết phục ông ấy chấp thuận kế hoạch của bạn. Cuộc gặp diễn ra tại văn phòng của thầy John, và bạn cần phải chuẩn bị kỹ lưỡng để trả lời các câu hỏi và giải thích rõ ràng về lợi ích của các hoạt động này.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Trưởng bộ phận học thuật
# Giới tính AI: Nam
# Câu mở đầu của AI: Hello, I'm John, the Head of the Academic Department. I understand you have some extracurricular activity proposals to discuss. Let's start with the first one. What specific skills are you aiming to develop through these activities?
# LIST CÂU HỎI do AI hỏi: 1. What specific skills are you aiming to develop through these activities?
# 2. How do you plan to measure the effectiveness of these activities?
# 3. Can you provide examples of similar activities that have been successful in other schools?
# 4. What resources or support will you need from the school to implement these activities?
# 5. How will you ensure that all students are engaged and benefit from these activities?
# 6. What is the timeline for implementing these activities?
# 7. How do you plan to address any potential challenges or obstacles in executing these activities?
# Generating details for : Thảo luận với cấp trên về việc sử dụng công nghệ trong giảng dạy.
# Generating details for situation: Thảo luận với cấp trên về việc sử dụng công nghệ trong giảng dạy.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Báo cáo và đề xuất với cấp trên
# TÊN TÌNH HUỐNG: Thảo luận với cấp trên về việc sử dụng công nghệ trong giảng dạy.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường đại học quốc tế. Bạn đã nhận thấy rằng việc sử dụng công nghệ trong giảng dạy có thể cải thiện hiệu quả học tập của sinh viên. Bạn đã chuẩn bị một báo cáo chi tiết về các công cụ công nghệ có thể áp dụng và muốn thảo luận với cấp trên của mình, cô Nguyễn, về việc triển khai các công cụ này. Cuộc thảo luận diễn ra trong một cuộc họp trực tiếp tại văn phòng của cô Nguyễn. Bạn cần thuyết phục cô Nguyễn về lợi ích của việc sử dụng công nghệ và đề xuất một kế hoạch triển khai cụ thể.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Cấp trên
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, I'm Ms. Nguyen, your supervisor. I understand you have some ideas about integrating technology into our teaching methods. Can you start by explaining the main benefits you see in using technology in our classrooms?
# LIST CÂU HỎI do AI hỏi: 1. Can you start by explaining the main benefits you see in using technology in our classrooms?
# 2. What specific tools or software do you recommend we use?
# 3. How do you propose we train our staff to use these technologies effectively?
# 4. What are the potential challenges we might face in implementing these technologies?
# 5. How do you think students will respond to these changes?
# 6. Can you provide examples of other institutions that have successfully implemented similar technologies?
# 7. What is your proposed timeline for rolling out these technologies?
# Generating details for : Báo cáo kết quả đánh giá học sinh sau mỗi kỳ thi.
# Generating details for situation: Báo cáo kết quả đánh giá học sinh sau mỗi kỳ thi.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Báo cáo và đề xuất với cấp trên
# TÊN TÌNH HUỐNG: Báo cáo kết quả đánh giá học sinh sau mỗi kỳ thi.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường quốc tế. Sau mỗi kỳ thi, bạn có nhiệm vụ báo cáo kết quả đánh giá học sinh cho giáo viên chính và ban giám hiệu. Trong buổi họp trực tiếp với giáo viên chính và hiệu trưởng, bạn cần trình bày chi tiết về kết quả học tập của học sinh, những điểm mạnh và yếu, và đề xuất các biện pháp cải thiện. Buổi họp này còn có sự tham gia của một giáo viên nước ngoài, người không nói tiếng Việt, nên bạn cần sử dụng tiếng Anh để giao tiếp.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Hiệu trưởng
# Giới tính AI: Nam
# Câu mở đầu của AI: Hello, I am Mr. Smith, the principal. I understand you have the results of the recent exams. Can you start by giving us an overview of the students' performance?
# LIST CÂU HỎI do AI hỏi: 1. Can you start by giving us an overview of the students' performance?
# 2. What are the main strengths and weaknesses you observed in the students' results?
# 3. How do you think we can address the weaknesses identified?
# 4. Are there any particular students who need special attention or support?
# 5. How do the results compare to the previous term?
# 6. What strategies do you suggest to improve the overall performance?
# 7. Do you have any feedback on the exam format or content that could help us in future assessments?
# Processing group: Hỗ trợ và chăm sóc học sinh
# Generating details for : Giải đáp thắc mắc của học sinh về bài học.
# Generating details for situation: Giải đáp thắc mắc của học sinh về bài học.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Hỗ trợ và chăm sóc học sinh
# TÊN TÌNH HUỐNG: Giải đáp thắc mắc của học sinh về bài học.
# CHI TIẾT TÌNH HUỐNG: Trong một buổi học trực tiếp, một học sinh gặp khó khăn trong việc hiểu bài giảng về chủ đề 'Phân số và số thập phân'. Học sinh này đã giơ tay và yêu cầu sự giúp đỡ từ bạn, người đang giữ vai trò trợ giảng. Bạn cần phải giải thích lại bài học một cách dễ hiểu, sử dụng các ví dụ cụ thể và kiểm tra xem học sinh đã hiểu chưa. Ngoài ra, bạn cũng cần phải khuyến khích học sinh đặt thêm câu hỏi nếu còn thắc mắc và đảm bảo rằng học sinh cảm thấy thoải mái và tự tin hơn sau khi được giải đáp.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Học sinh
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hi, I'm struggling to understand the lesson on fractions and decimals. Can you explain it to me again? What exactly is a fraction?
# LIST CÂU HỎI do AI hỏi: 1. What exactly is a fraction?
# 2. How do you convert a fraction to a decimal?
# 3. Can you give me an example of a mixed number?
# 4. Why do we need to learn about fractions and decimals?
# 5. How do you add and subtract fractions?
# 6. What is the difference between a proper fraction and an improper fraction?
# 7. Can you show me how to solve a problem involving fractions and decimals?
# Generating details for : Hỗ trợ học sinh gặp khó khăn trong việc học tập.
# Generating details for situation: Hỗ trợ học sinh gặp khó khăn trong việc học tập.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Hỗ trợ và chăm sóc học sinh
# TÊN TÌNH HUỐNG: Hỗ trợ học sinh gặp khó khăn trong việc học tập.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường trung học quốc tế. Một học sinh tên là Minh, mới chuyển đến từ một quốc gia khác, đang gặp khó khăn trong việc theo kịp bài học do rào cản ngôn ngữ và phương pháp giảng dạy khác biệt. Minh thường xuyên không hoàn thành bài tập và có dấu hiệu mất tự tin. Bạn đã được giáo viên chủ nhiệm yêu cầu hỗ trợ Minh. Bạn sẽ gặp Minh trực tiếp sau giờ học để thảo luận về các khó khăn mà em đang gặp phải và tìm cách giúp đỡ em.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Học sinh Minh
# Giới tính AI: Nam
# Câu mở đầu của AI: Hi, I'm Minh. I understand you are here to help me with my studies. Can you tell me what specific areas you think I need to improve in?
# LIST CÂU HỎI do AI hỏi: 1. Can you tell me what specific areas you think I need to improve in?
# 2. How do you think my language barrier is affecting my learning?
# 3. What strategies do you suggest for me to better understand the lessons?
# 4. Can you help me with my homework assignments?
# 5. How can I improve my confidence in class?
# 6. Are there any resources or tools that can help me learn more effectively?
# 7. How often should we meet to discuss my progress?
# Generating details for : Tư vấn cho học sinh về phương pháp học tập hiệu quả.
# Generating details for situation: Tư vấn cho học sinh về phương pháp học tập hiệu quả.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Hỗ trợ và chăm sóc học sinh
# TÊN TÌNH HUỐNG: Tư vấn cho học sinh về phương pháp học tập hiệu quả.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường trung học quốc tế. Một học sinh lớp 10, tên là Linh, đang gặp khó khăn trong việc quản lý thời gian và phương pháp học tập. Linh thường xuyên cảm thấy căng thẳng và không biết làm thế nào để học hiệu quả hơn. Bạn được giao nhiệm vụ tư vấn cho Linh về các phương pháp học tập hiệu quả trong một buổi gặp mặt trực tiếp tại phòng tư vấn của trường. Linh là một học sinh quốc tế, mới chuyển đến từ Việt Nam và đang cố gắng thích nghi với môi trường học tập mới.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Học sinh Linh
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hi, I'm Linh. I'm really struggling with my studies and I feel overwhelmed. Can you help me figure out how to study more effectively? What are some good strategies for managing my time better?
# LIST CÂU HỎI do AI hỏi: 1. What are some good strategies for managing my time better?
# 2. How can I stay focused during my study sessions?
# 3. What should I do if I don't understand the material?
# 4. How can I balance my schoolwork with extracurricular activities?
# 5. Are there any specific study techniques that work well for subjects like math and science?
# 6. How can I reduce my stress levels while studying?
# 7. What resources are available at school to help me with my studies?
# Generating details for : Giải quyết mâu thuẫn giữa các học sinh trong lớp.
# Generating details for situation: Giải quyết mâu thuẫn giữa các học sinh trong lớp.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Hỗ trợ và chăm sóc học sinh
# TÊN TÌNH HUỐNG: Giải quyết mâu thuẫn giữa các học sinh trong lớp.
# CHI TIẾT TÌNH HUỐNG: Trong một lớp học, hai học sinh, Minh và An, đã xảy ra mâu thuẫn về việc chia sẻ tài liệu học tập. Minh cảm thấy An không công bằng khi không chia sẻ tài liệu mà cả hai đã cùng làm việc. An thì cho rằng Minh không đóng góp đủ công sức. Mâu thuẫn này đã dẫn đến việc cả hai không muốn làm việc nhóm cùng nhau và ảnh hưởng đến không khí học tập của lớp. Bạn, với vai trò là Teacher Assistant, cần phải can thiệp để giải quyết mâu thuẫn này. Bạn sẽ gặp trực tiếp cả hai học sinh để lắng nghe và tìm ra giải pháp hòa giải.
# NHÂN VẬT TÔI: Teacher Assistant
# NHÂN VẬT AI: Học sinh Minh
# Giới tính AI: Nam
# Câu mở đầu của AI: Hi, I'm Minh. I understand you want to talk about the issue between An and me. Can you tell me what you think happened?
# LIST CÂU HỎI do AI hỏi: 1. Can you tell me what you think happened?
# 2. How do you feel about the situation?
# 3. What do you think An's perspective might be?
# 4. Have you tried talking to An about this directly?
# 5. What do you think would be a fair solution?
# 6. How do you think this conflict is affecting the rest of the class?
# 7. What can I do to help you and An resolve this issue?
# Generating details for : Hỗ trợ học sinh trong việc chuẩn bị cho các kỳ thi.
# Generating details for situation: Hỗ trợ học sinh trong việc chuẩn bị cho các kỳ thi.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Hỗ trợ và chăm sóc học sinh
# TÊN TÌNH HUỐNG: Hỗ trợ học sinh trong việc chuẩn bị cho các kỳ thi.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường trung học quốc tế. Kỳ thi cuối kỳ đang đến gần và nhiều học sinh đang gặp khó khăn trong việc ôn tập. Bạn được giao nhiệm vụ hỗ trợ một nhóm học sinh đa văn hóa trong việc chuẩn bị cho kỳ thi. Trong buổi gặp mặt trực tiếp, bạn cần lắng nghe các vấn đề của học sinh, cung cấp tài liệu học tập, và hướng dẫn cách ôn tập hiệu quả. Bạn cũng cần phải động viên và tạo động lực cho các em, đồng thời giải quyết các vấn đề cá nhân mà các em có thể gặp phải.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Học sinh
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hi, I'm Linh, one of the students in your group. I'm really struggling with my exam preparation. Can you help me understand how to organize my study schedule?
# LIST CÂU HỎI do AI hỏi: 1. Can you help me understand how to organize my study schedule?
# 2. What are the most important topics I should focus on for the exam?
# 3. How can I manage my time effectively during the exam?
# 4. Do you have any tips for reducing stress and anxiety before the exam?
# 5. Can you explain this particular concept that I'm having trouble with?
# 6. How can I improve my writing skills for the essay part of the exam?
# 7. Are there any additional resources or materials you recommend for studying?
# Generating details for : Tổ chức các buổi học bổ trợ cho học sinh yếu kém.
# Generating details for situation: Tổ chức các buổi học bổ trợ cho học sinh yếu kém.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Hỗ trợ và chăm sóc học sinh
# TÊN TÌNH HUỐNG: Tổ chức các buổi học bổ trợ cho học sinh yếu kém.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường trung học quốc tế. Gần đây, bạn nhận thấy một số học sinh trong lớp gặp khó khăn trong việc theo kịp bài học. Giáo viên chính đã yêu cầu bạn tổ chức các buổi học bổ trợ để giúp các em này cải thiện kết quả học tập. Bạn cần gặp gỡ và thảo luận với giáo viên chính để lên kế hoạch chi tiết cho các buổi học bổ trợ này. Trong cuộc gặp, bạn sẽ phải thảo luận về lịch trình, nội dung giảng dạy, phương pháp giảng dạy, và cách theo dõi tiến độ của học sinh. Ngoài ra, bạn cũng cần phải cân nhắc đến các yếu tố văn hóa và ngôn ngữ của học sinh quốc tế để đảm bảo các buổi học bổ trợ hiệu quả.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Giáo viên chính
# Giới tính AI: Nam
# Câu mở đầu của AI: Hello, I'm Mr. Johnson, the main teacher for the class. I understand you are here to discuss organizing supplementary lessons for our struggling students. Can you tell me what specific challenges these students are facing?
# LIST CÂU HỎI do AI hỏi: 1. Can you tell me what specific challenges these students are facing?
# 2. What times and days do you think would be best for these supplementary lessons?
# 3. How do you plan to structure the content of these lessons?
# 4. What teaching methods do you think will be most effective for these students?
# 5. How will you track and measure the progress of the students?
# 6. Are there any cultural or language considerations we need to keep in mind?
# 7. How can we involve the parents in supporting their children's learning?
# Generating details for : Theo dõi và đánh giá tiến bộ của học sinh.
# Generating details for situation: Theo dõi và đánh giá tiến bộ của học sinh.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Hỗ trợ và chăm sóc học sinh
# TÊN TÌNH HUỐNG: Theo dõi và đánh giá tiến bộ của học sinh.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường quốc tế. Hôm nay, bạn có một cuộc họp trực tiếp với cô giáo chủ nhiệm lớp 5A, cô Anna, để thảo luận về tiến bộ học tập của một học sinh tên là Minh. Minh là một học sinh quốc tế mới chuyển đến từ Việt Nam và đang gặp khó khăn trong việc thích nghi với môi trường học tập mới. Bạn cần cung cấp thông tin chi tiết về tiến bộ của Minh, những khó khăn mà em đang gặp phải, và đề xuất các biện pháp hỗ trợ để giúp Minh cải thiện. Cuộc họp này đòi hỏi bạn phải sử dụng kỹ năng giao tiếp, phân tích và đề xuất giải pháp một cách hiệu quả.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Cô giáo chủ nhiệm
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, I'm Anna, the homeroom teacher for class 5A. I understand that you have been closely monitoring Minh's progress. Can you please share your observations so far?
# LIST CÂU HỎI do AI hỏi: 1. Can you please share your observations so far?
# 2. What specific challenges has Minh been facing?
# 3. How has Minh's performance been in different subjects?
# 4. Have you noticed any changes in Minh's behavior or attitude?
# 5. What strategies have you already tried to support Minh?
# 6. Do you have any suggestions for additional support or resources?
# 7. How can we involve Minh's parents in this process?
# Processing group: Đàm phán và thỏa thuận
# Generating details for : Thảo luận với giáo viên chính về việc phân chia công việc.
# Generating details for situation: Thảo luận với giáo viên chính về việc phân chia công việc.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Đàm phán và thỏa thuận
# TÊN TÌNH HUỐNG: Thảo luận với giáo viên chính về việc phân chia công việc.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng mới tại một trường quốc tế, và bạn cần thảo luận với giáo viên chính về việc phân chia công việc trong lớp học. Bạn muốn đảm bảo rằng công việc được phân chia công bằng và phù hợp với khả năng của bạn. Giáo viên chính là người có kinh nghiệm lâu năm và có phong cách làm việc rất cụ thể. Bạn cần thuyết phục giáo viên chính rằng bạn có thể đảm nhận một số nhiệm vụ nhất định để giảm bớt gánh nặng cho họ, đồng thời đảm bảo rằng bạn có cơ hội học hỏi và phát triển kỹ năng.
# NHÂN VẬT TÔI: Trợ giảng mới
# NHÂN VẬT AI: Giáo viên chính
# Giới tính AI: Nam
# Câu mở đầu của AI: Hello, I'm Mr. Smith, the lead teacher for this class. I understand you wanted to discuss the division of tasks. To start, could you tell me which specific tasks you feel most confident handling?
# LIST CÂU HỎI do AI hỏi: 1. Could you tell me which specific tasks you feel most confident handling?
# 2. How do you think your previous experience can contribute to our classroom?
# 3. Are there any particular areas where you feel you need more support or training?
# 4. How do you propose we handle the grading and feedback process?
# 5. What strategies do you suggest for managing classroom behavior?
# 6. How do you envision our collaboration benefiting the students?
# 7. Do you have any ideas for new activities or projects we could introduce?
# Generating details for : Đàm phán với nhà cung cấp về việc mua sắm thiết bị giảng dạy.
# Generating details for situation: Đàm phán với nhà cung cấp về việc mua sắm thiết bị giảng dạy.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Đàm phán và thỏa thuận
# TÊN TÌNH HUỐNG: Đàm phán với nhà cung cấp về việc mua sắm thiết bị giảng dạy.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường đại học quốc tế và được giao nhiệm vụ đàm phán với nhà cung cấp về việc mua sắm thiết bị giảng dạy mới cho khoa. Nhà cung cấp là một công ty quốc tế có trụ sở tại nước ngoài. Bạn cần phải thảo luận về giá cả, chất lượng sản phẩm, thời gian giao hàng và các điều khoản thanh toán. Cuộc đàm phán diễn ra qua video call và bạn cần phải thể hiện kỹ năng giao tiếp, đàm phán và hiểu biết về các thiết bị giảng dạy để đạt được thỏa thuận tốt nhất cho trường.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Nhà cung cấp
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, my name is Anna, and I am the sales representative for our educational equipment company. I understand you are looking to purchase new teaching equipment for your university. Could you please tell me more about your specific requirements?
# LIST CÂU HỎI do AI hỏi: 1. Could you please tell me more about your specific requirements?
# 2. What is your budget for this purchase?
# 3. Are there any particular brands or models you are interested in?
# 4. What is the expected delivery timeline for these items?
# 5. Do you have any specific quality standards or certifications that the equipment must meet?
# 6. How do you plan to handle the payment terms?
# 7. Are there any additional services you require, such as installation or training?
# ...
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Trưởng bộ phận đào tạo
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, I'm Lan, the head of the training department. I understand you have some suggestions for training courses to enhance our colleagues' skills. Could you please start by explaining the specific skills you think need improvement?
# LIST CÂU HỎI do AI hỏi: 1. Could you please start by explaining the specific skills you think need improvement?
# 2. What are the main challenges our colleagues are facing that these courses would address?
# 3. How do you think these training courses will benefit our teaching staff in the long run?
# 4. Do you have any specific courses or training providers in mind?
# 5. How do you propose we measure the effectiveness of these training courses?
# 6. What kind of support or resources will be needed to implement these training programs?
# 7. Have you discussed these training needs with any of the colleagues who would be participating?
# Generating details for : Tham gia các hoạt động ngoại khóa để phát triển kỹ năng mềm.
# Generating details for situation: Tham gia các hoạt động ngoại khóa để phát triển kỹ năng mềm.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Đào tạo và phát triển bản thân/đồng nghiệp
# TÊN TÌNH HUỐNG: Tham gia các hoạt động ngoại khóa để phát triển kỹ năng mềm.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường quốc tế và được giao nhiệm vụ tổ chức một buổi hoạt động ngoại khóa nhằm phát triển kỹ năng mềm cho học sinh. Bạn cần phối hợp với một giáo viên nước ngoài để lên kế hoạch và thực hiện buổi hoạt động này. Trong quá trình chuẩn bị, bạn sẽ gặp gỡ và thảo luận trực tiếp với giáo viên này để thống nhất các nội dung và phương pháp giảng dạy. Bạn cần phải thể hiện khả năng giao tiếp, quản lý thời gian, và giải quyết vấn đề một cách hiệu quả.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Giáo viên nước ngoài
# Giới tính AI: Nam
# Câu mở đầu của AI: Hello, my name is John, and I am the foreign teacher you will be working with for the extracurricular activity. I understand we need to develop a plan to enhance the students' soft skills. What specific skills do you think we should focus on?
# LIST CÂU HỎI do AI hỏi: 1. What specific skills do you think we should focus on?
# 2. How do you propose we structure the activities to engage the students effectively?
# 3. What resources or materials do you think we will need for this activity?
# 4. How do you plan to handle any potential language barriers during the activity?
# 5. What methods do you suggest for evaluating the effectiveness of the activity?
# 6. How can we ensure that all students, regardless of their skill levels, benefit from this activity?
# 7. Do you have any previous experience with similar activities that we can learn from?
# Processing group: Tham gia hội nghị và sự kiện ngành
# Generating details for : Tham gia hội nghị giáo dục quốc tế để cập nhật xu hướng mới.
# Generating details for situation: Tham gia hội nghị giáo dục quốc tế để cập nhật xu hướng mới.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Tham gia hội nghị và sự kiện ngành
# TÊN TÌNH HUỐNG: Tham gia hội nghị giáo dục quốc tế để cập nhật xu hướng mới.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường đại học và được giao nhiệm vụ tham gia một hội nghị giáo dục quốc tế để cập nhật các xu hướng mới nhất trong ngành. Tại hội nghị, bạn gặp gỡ và trao đổi với nhiều chuyên gia giáo dục từ khắp nơi trên thế giới. Bạn cần phải giao tiếp hiệu quả để thu thập thông tin, học hỏi kinh nghiệm và xây dựng mạng lưới quan hệ. Trong quá trình này, bạn gặp một chuyên gia giáo dục từ một quốc gia khác và bắt đầu cuộc trò chuyện để tìm hiểu thêm về các xu hướng giáo dục mới nhất mà họ đang áp dụng.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Chuyên gia giáo dục
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, my name is Dr. Emily Johnson, an education specialist from the United States. It's great to meet you at this international education conference. What specific trends in education are you most interested in learning about?
# LIST CÂU HỎI do AI hỏi: 1. What specific trends in education are you most interested in learning about?
# 2. How do you think these trends can be applied in your current teaching environment?
# 3. What challenges do you face in implementing new educational trends?
# 4. Can you share any successful strategies you've used to integrate new trends into your teaching?
# 5. How do you stay updated with the latest developments in education?
# 6. What role do you think technology plays in modern education trends?
# 7. How do you collaborate with other educators to share and implement new ideas?
# Generating details for : Tham gia các buổi hội thảo chuyên đề về phương pháp giảng dạy.
# Generating details for situation: Tham gia các buổi hội thảo chuyên đề về phương pháp giảng dạy.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Tham gia hội nghị và sự kiện ngành
# TÊN TÌNH HUỐNG: Tham gia các buổi hội thảo chuyên đề về phương pháp giảng dạy.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường đại học và được giao nhiệm vụ tham gia một buổi hội thảo chuyên đề về phương pháp giảng dạy hiện đại. Buổi hội thảo này có sự tham gia của nhiều chuyên gia giáo dục từ các quốc gia khác nhau. Trong buổi hội thảo, bạn cần phải giao tiếp và trao đổi với các chuyên gia, đặt câu hỏi và thảo luận về các phương pháp giảng dạy mới nhất. Bạn cũng cần phải ghi chép lại các thông tin quan trọng để báo cáo lại cho giảng viên chính của bạn. Một trong những thách thức là bạn phải làm quen và giao tiếp hiệu quả với các chuyên gia đến từ nhiều nền văn hóa khác nhau, đồng thời nắm bắt và hiểu rõ các xu hướng mới trong giảng dạy để áp dụng vào công việc của mình.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Chuyên gia giáo dục
# Giới tính AI: Nam
# Câu mở đầu của AI: Hello, my name is Dr. John Smith, and I am a specialist in modern teaching methodologies. I understand you are here to learn and discuss new teaching methods. To start, could you tell me what specific teaching challenges you are currently facing?
# LIST CÂU HỎI do AI hỏi: 1. Could you tell me what specific teaching challenges you are currently facing?
# 2. How do you currently incorporate technology into your teaching?
# 3. What are your thoughts on student-centered learning?
# 4. Have you had any experience with flipped classroom models?
# 5. How do you handle diverse learning needs in your classroom?
# 6. What are some of the most effective assessment methods you have used?
# 7. How do you stay updated with the latest trends in education?
# Generating details for : Tham gia các sự kiện giao lưu với các trường học khác.
# Generating details for situation: Tham gia các sự kiện giao lưu với các trường học khác.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Tham gia hội nghị và sự kiện ngành
# TÊN TÌNH HUỐNG: Tham gia các sự kiện giao lưu với các trường học khác.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường trung học và được giao nhiệm vụ tham gia một sự kiện giao lưu với các trường học khác trong khu vực. Sự kiện này nhằm mục đích chia sẻ kinh nghiệm giảng dạy, phương pháp học tập và tạo cơ hội hợp tác giữa các trường. Bạn sẽ gặp gỡ và trao đổi với các giáo viên và trợ giảng từ các trường khác. Trong quá trình giao lưu, bạn cần phải thể hiện kỹ năng giao tiếp, lắng nghe và chia sẻ thông tin một cách hiệu quả. Bạn cũng cần phải xử lý các tình huống bất ngờ, như câu hỏi khó từ đồng nghiệp hoặc sự khác biệt văn hóa trong cách tiếp cận giáo dục.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Trợ giảng từ trường khác
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, my name is Anna, and I am a Teacher Assistant from another school. It's great to meet you at this event. How do you usually engage students in your classroom?
# LIST CÂU HỎI do AI hỏi: 1. How do you usually engage students in your classroom?
# 2. What are some challenges you face in your role as a Teacher Assistant?
# 3. Can you share a successful teaching strategy you've used?
# 4. How do you handle cultural differences in your classroom?
# 5. What tools or technologies do you find most effective in teaching?
# 6. How do you collaborate with teachers and other staff members?
# 7. What are your thoughts on the latest trends in education?
# Generating details for : Tham gia các buổi triển lãm công nghệ giáo dục.
# Generating details for situation: Tham gia các buổi triển lãm công nghệ giáo dục.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Tham gia hội nghị và sự kiện ngành
# TÊN TÌNH HUỐNG: Tham gia các buổi triển lãm công nghệ giáo dục.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường đại học và được giao nhiệm vụ tham gia một buổi triển lãm công nghệ giáo dục quốc tế. Tại đây, bạn sẽ gặp gỡ các nhà cung cấp công nghệ giáo dục, các chuyên gia trong ngành và các đồng nghiệp từ các trường khác. Nhiệm vụ của bạn là tìm hiểu về các công nghệ mới nhất, thu thập thông tin và đánh giá xem những công nghệ nào có thể áp dụng vào giảng dạy tại trường của bạn. Bạn cũng cần phải giao tiếp hiệu quả với các đối tác quốc tế, thể hiện sự chuyên nghiệp và khả năng ngoại ngữ của mình.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Nhà cung cấp công nghệ
# Giới tính AI: Nam
# Câu mở đầu của AI: Hello, my name is John, and I represent EduTech Solutions. We specialize in innovative educational technologies. Could you please tell me what specific technologies or solutions you are looking for at this exhibition?
# LIST CÂU HỎI do AI hỏi: 1. Could you please tell me what specific technologies or solutions you are looking for at this exhibition?
# 2. How do you currently integrate technology into your teaching methods?
# 3. What challenges are you facing with your current educational technologies?
# 4. Are you looking for solutions that cater to a specific subject or grade level?
# 5. How important is data security and privacy for your institution?
# 6. Would you be interested in a demonstration of our latest product?
# 7. How do you measure the effectiveness of new technologies in your teaching environment?
# Generating details for : Tham gia các buổi hội thảo về phát triển kỹ năng mềm cho học sinh.
# Generating details for situation: Tham gia các buổi hội thảo về phát triển kỹ năng mềm cho học sinh.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Tham gia hội nghị và sự kiện ngành
# TÊN TÌNH HUỐNG: Tham gia các buổi hội thảo về phát triển kỹ năng mềm cho học sinh.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường trung học quốc tế và được giao nhiệm vụ tham gia một buổi hội thảo về phát triển kỹ năng mềm cho học sinh. Buổi hội thảo này có sự tham gia của nhiều chuyên gia giáo dục từ các quốc gia khác nhau. Nhiệm vụ của bạn là lắng nghe, ghi chép và sau đó trình bày lại những điểm quan trọng cho giáo viên chính và học sinh. Trong quá trình tham gia, bạn cần giao tiếp với các chuyên gia, đặt câu hỏi và thảo luận về các phương pháp giảng dạy mới nhất. Bạn cũng cần phải xử lý các tình huống giao tiếp đa văn hóa và đảm bảo rằng thông tin được truyền đạt một cách chính xác và hiệu quả.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Chuyên gia giáo dục
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, my name is Dr. Emily Nguyen, and I am a specialist in educational development. I understand you are here to learn about soft skills development for students. Can you tell me what specific areas you are most interested in?
# LIST CÂU HỎI do AI hỏi: 1. Can you tell me what specific areas you are most interested in?
# 2. How do you currently incorporate soft skills training in your curriculum?
# 3. What challenges have you faced in teaching soft skills to students?
# 4. How do you measure the effectiveness of soft skills training in your school?
# 5. Are there any particular soft skills that you find students struggle with the most?
# 6. How do you engage students who are less interested in developing their soft skills?
# 7. What are some innovative methods you have seen or used to teach soft skills?
# Generating details for : Tham gia các buổi hội thảo về quản lý lớp học hiệu quả.
# Generating details for situation: Tham gia các buổi hội thảo về quản lý lớp học hiệu quả.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Tham gia hội nghị và sự kiện ngành
# TÊN TÌNH HUỐNG: Tham gia các buổi hội thảo về quản lý lớp học hiệu quả.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường trung học quốc tế và được giao nhiệm vụ tham gia một buổi hội thảo về quản lý lớp học hiệu quả. Buổi hội thảo này có sự tham gia của nhiều giáo viên và chuyên gia giáo dục từ các quốc gia khác nhau. Trong buổi hội thảo, bạn sẽ gặp gỡ và trao đổi với các đồng nghiệp quốc tế, học hỏi các phương pháp quản lý lớp học mới nhất và thảo luận về các thách thức trong việc duy trì kỷ luật và tạo môi trường học tập tích cực. Bạn cần phải giao tiếp hiệu quả, đặt câu hỏi thông minh và chia sẻ kinh nghiệm của mình để tận dụng tối đa cơ hội học hỏi này.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Chuyên gia giáo dục
# Giới tính AI: Nam
# Câu mở đầu của AI: Hello, my name is John, and I am a specialist in classroom management. I understand you are here to learn about effective classroom management techniques. What specific challenges have you faced in managing your classroom?
# LIST CÂU HỎI do AI hỏi: 1. What specific challenges have you faced in managing your classroom?
# 2. How do you currently handle disruptive behavior in your classroom?
# 3. What strategies have you found effective in maintaining student engagement?
# 4. Can you share an example of a difficult situation you managed successfully?
# 5. How do you adapt your classroom management techniques for different age groups?
# 6. What role do you think technology plays in classroom management?
# 7. How do you involve parents in the classroom management process?
# Generating details for : Tham gia các buổi hội thảo về giáo dục đa văn hóa.
# Generating details for situation: Tham gia các buổi hội thảo về giáo dục đa văn hóa.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Teacher Assistant, Teaching Rel
# TOPIC: Tham gia hội nghị và sự kiện ngành
# TÊN TÌNH HUỐNG: Tham gia các buổi hội thảo về giáo dục đa văn hóa.
# CHI TIẾT TÌNH HUỐNG: Bạn là một trợ giảng tại một trường đại học quốc tế và được giao nhiệm vụ tham gia một buổi hội thảo về giáo dục đa văn hóa. Tại buổi hội thảo, bạn sẽ gặp gỡ và trao đổi với các giáo viên, nhà nghiên cứu và chuyên gia từ nhiều quốc gia khác nhau. Nhiệm vụ của bạn là thu thập thông tin, học hỏi các phương pháp giảng dạy mới và xây dựng mối quan hệ hợp tác. Trong quá trình tham gia, bạn gặp một chuyên gia giáo dục từ một quốc gia khác và bắt đầu cuộc trò chuyện để tìm hiểu thêm về các phương pháp giảng dạy đa văn hóa mà họ đang áp dụng.
# NHÂN VẬT TÔI: Trợ giảng
# NHÂN VẬT AI: Chuyên gia giáo dục
# Giới tính AI: Nữ
# Câu mở đầu của AI: Hello, my name is Dr. Emily Nguyen, a specialist in multicultural education. It's great to meet you at this workshop. Can you tell me about your experience with multicultural education in your current role?
# LIST CÂU HỎI do AI hỏi: 1. Can you tell me about your experience with multicultural education in your current role?
# 2. What challenges have you faced when implementing multicultural education strategies?
# 3. How do you engage students from diverse cultural backgrounds in your classroom?
# 4. What are some effective methods you've found for promoting cultural awareness among students?
# 5. How do you handle conflicts or misunderstandings that arise from cultural differences?
# 6. Can you share any successful projects or initiatives you've been involved in related to multicultural education?
# 7. What advice would you give to educators who are new to teaching in a multicultural environment?
# Completed processing for job position: Teacher Assistant, Teaching Rel
# Total situations generated: 49
# Sheet 'Teacher Assistant, Teaching Rel' added to Excel file
#
# Excel file generated: Teacher_Assistant.xlsx
# Final Excel file: Teacher_Assistant.xlsx
