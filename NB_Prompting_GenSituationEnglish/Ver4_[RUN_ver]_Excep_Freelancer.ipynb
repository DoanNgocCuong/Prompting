# %%
import os
from openai import OpenAI
import json
import pandas as pd
from typing import List

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

def get_completion(prompt, model="gpt-4o", temperature=0):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message.content

def gen_situation_groups_AND_situation_SHORTVER2(job_position):
    prompt = f"""
    Bạn là chuyên gia về giao tiếp trong lĩnh vực làm việc tự do (freelance).
    
    Nhiệm vụ: Tạo ra 7 nhóm tình huống GIAO TIẾP liên quan đến vị trí "{job_position}",
    bao gồm cả khía cạnh chuyên môn và cá nhân.

    Hướng dẫn:
    1. Yêu cầu bắt buộc về các tình huống 
      - Đúng thể loại: TÌNH HUỐNG GIAO TIẾP 
    2. Các nhóm tình huống GIAO TIẾP: phải bằng tiếng Việt, ngắn gọn, và xoay quanh vị trí công việc của "{job_position}".
    3. Mỗi nhóm tình huống có 7 tình huống cụ thể hơn, nhưng vẫn ngắn gọn, và đảm bảo:
      - Tính tương tác cao: Tập trung vào các tình huống GIAO TIẾP TRỰC TIẾP: gặp mặt trực tiếp, cuộc gọi thoại, video call, <<Tuyệt đối không gồm tình huống "GIAO TIẾP QUA EMAIL">>
      - Tính ứng dụng thực tế: Phản ánh thực tế công việc freelance, sử dụng ngôn ngữ gần gũi và dễ hiểu, kết hợp với thuật ngữ chuyên ngành của freelancer.
      - Tính tình huống và kỹ năng xử lý: Tạo ra các tình huống thách thức, đa chiều và phức tạp, đòi hỏi sự kết hợp nhiều kỹ năng, đảm bảo cân đối để bao quát toàn diện công việc freelance.
      - Tính cụ thể: Thêm chi tiết cụ thể hoặc bối cảnh để làm sống động tình huống GIAO TIẾP ở vị trí {job_position}.
      - Yếu tố văn hóa: Bao gồm tình huống liên quan đến giao tiếp đa văn hóa khi làm việc với khách hàng hoặc đối tác quốc tế.
      - Cập nhật xu hướng mới: Đưa vào các xu hướng mới nhất trong công việc freelance, tạo ra các tình huống sáng tạo và thử thách để phát triển kỹ năng toàn diện.

    3'. Gợi ý các nhóm tình huống (không giới hạn ở các gợi ý này): <<Tuyệt đối không gồm tình huống "GIAO TIẾP QUA EMAIL">>
    - Tìm kiếm và tiếp cận khách hàng mới
    - Đàm phán hợp đồng và thỏa thuận giá cả
    - Quản lý dự án và thời hạn
    - Xử lý phản hồi và yêu cầu sửa đổi từ khách hàng
    - Networking và xây dựng mối quan hệ nghề nghiệp
    - Quản lý tài chính và thanh toán
    - Xử lý xung đột và bất đồng với khách hàng
    - Cân bằng nhiều dự án cùng lúc
    - Phát triển kỹ năng và cập nhật xu hướng ngành
    - Xây dựng thương hiệu cá nhân
    - Giao tiếp trong các dự án hợp tác với freelancer khác
    - Tham gia các cộng đồng và diễn đàn freelance
    - Đối phó với thời kỳ không có dự án

    Trả về một đối tượng JSON có cấu trúc sau:
    {{
      "job_position": "{job_position}",
      "situation_groups": {{
        "situation_group1": {{
          "situation_group_name": "Tên nhóm tình huống 1",
          "situation1": "Tình huống 1",
          "situation2": "Tình huống 2",
          "situation3": "Tình huống 3", 
          "situation4": "Tình huống 4", 
          "situation5": "Tình huống 5", 
          "situation6": "Tình huống 6", 
          "situation7": "Tình huống 7"
          ...
        }},
        "situation_group2": {{
          "situation_group_name": "Tên nhóm tình huống 2",
          "situation1": "Tình huống 1",
          "situation2": "Tình huống 2"
          ...
          <5-7 situation>
      }},
        ...
      }}
    }}


    Example 
      {{
        "job_position": "FREELANCER",
        "situation_groups": [
          {{
            "situation_group_name": "Đàm phán hợp đồng và thỏa thuận giá cả",
            "situation1": "Thảo luận về phạm vi công việc với khách hàng tiềm năng.",
            "situation2": "Đề xuất mức giá cho một dự án phức tạp.",
            "situation3": "Giải thích chính sách thanh toán của bạn cho khách hàng mới.",
            "situation4": "Thương lượng về thời hạn dự án với khách hàng gấp rút.",
            "situation5": "Xử lý yêu cầu giảm giá từ khách hàng lâu năm.",
            "situation6": "Thảo luận về các điều khoản bảo mật trong hợp đồng.",
            "situation7": "Đàm phán về quyền sở hữu trí tuệ của sản phẩm cuối cùng."
          }},
          {{
            "situation_group_name": "Xử lý phản hồi và yêu cầu sửa đổi",
            "situation1": "Tiếp nhận phản hồi không tích cực về sản phẩm đầu tiên.",
            "situation2": "Thảo luận về yêu cầu thay đổi lớn giữa dự án.",
            "situation3": "Giải thích lý do cho việc không thể đáp ứng một yêu cầu cụ thể.",
            "situation4": "Đề xuất giải pháp thay thế cho yêu cầu không khả thi.",
            "situation5": "Xin thêm thông tin chi tiết về phản hồi mơ hồ.",
            "situation6": "Thương lượng về phí phát sinh cho yêu cầu sửa đổi ngoài phạm vi.",
            "situation7": "Xử lý tình huống khách hàng liên tục thay đổi ý kiến."
          }}
        ]
      }}

    Đảm bảo đầu ra là một đối tượng JSON hợp lệ không có bất kỳ định dạng hoặc từ khóa bổ sung nào(chẳng hạn ```json).
    """

    # Assuming you have a function called get_completion to generate the response
    response = get_completion(prompt)
    
    # Parse the JSON response
    try:
        topics_dict = json.loads(response)
        return json.dumps(topics_dict, ensure_ascii=False, indent=2)
    except json.JSONDecodeError:
        print("Error: The generated response is not valid JSON. Please check the output.")
        return None

def gen_detail_situations_SHORTVER_aigender(job_position, situation_group_name, situation, ai_gender):
    """
    
    Truyền trực tiếp giới tính AI 
    """
    prompt = f"""
    Bạn là chuyên gia về phát triển nghề nghiệp và tình huống công việc cho vị trí {job_position}.
    
    Nhiệm vụ: Tạo ra chi tiết cho tình huống GIAO TIẾP "{situation}" liên quan đến chủ đề "{situation_group_name}" cho vị trí {job_position}.
    
    Hướng dẫn:
    1. Các đặc điểm của 1 tình huống 
      - Tính tương tác cao: Tập trung vào các tình huống giao tiếp trực tiếp như cuộc gọi điện thoại, video call, hoặc gặp mặt trực tiếp <<tuyệt đối không gồm việc gửi email>>.
      - Tính ứng dụng thực tế: Phản ánh thực tế công việc, sử dụng ngôn ngữ gần gũi và dễ hiểu , kết hợp với thuật ngữ chuyên ngành của vị trí {job_position}.
      - Tính tình huống và kỹ năng xử lý: Tạo ra các tình huống thách thức, đa chiều và phức tạp, đòi hỏi sự kết hợp nhiều kỹ năng, đảm bảo cân đối để bao quát toàn diện công việc.
      - Tính cụ thể: Thêm chi tiết cụ thể hoặc bối cảnh để làm sống động tình huống GIAO TIẾP ở vị trí {job_position}.
      - Yếu tố văn hóa: Bao gồm tình huống liên quan đến giao tiếp đa văn hóa khi làm việc với khách hàng hoặc đối tác quốc tế.
      - Cập nhật xu hướng mới: Đưa vào các xu hướng mới nhất trong công việc và ngành của vị trí {job_position}, tạo ra các tình huống sáng tạo và thử thách để phát triển kỹ năng toàn diện.

    2. Chi tiết tình huống phải bao gồm:
       - Tên tình huống (tiếng Việt): {situation}
       - Chi tiết tình huống GIAO TIẾP (tiếng Việt): Tạo tình huống 
       - Nhân vật của tôi (character_me) (tiếng Việt): Mô tả ngắn gọn trong 25 ký tự hoặc ít hơn, phản ánh vị trí {job_position}.
       - Nhân vật AI (character_ai) (tiếng Việt): Mô tả ngắn gọn trong 25 ký tự hoặc ít hơn, phù hợp với tình huống và vị trí {job_position}.
       - Giới tính của AI: {ai_gender}
       - Chi tiết tình huống GIAO TIẾP (tiếng Việt): 
          - Bắt đầu với "Tôi" + `situation` (Tức là: Ta sẽ CỤ THỂ HƠN về vai của AI trong TÊN TÌNH HUỐNG{situation} bằng cách thay bằng đúng vai của AI là: `character_ai` thay vì tên gọi chung chung)
          - Ngoài ra: KHÔNG THÊM GÌ NỮA vì sẽ bị vượt quá 90 ký tự.  
          - Chẳng hạn: 
              - Tên tình huống là: "Thảo luận chiến lược bán hàng với đội ngũ bán hàng trong cuộc họp hàng tuần."
              - Nhân vật AI: "Trưởng nhóm bán hàng" 
              => Thì chi tiết tình huống GIAO TIẾP sẽ là: "Tôi thảo luận với Trưởng nhóm bán hàng về chiến lược bán hàng trong cuộc họp hàng tuần."



    Trả về một đối tượng JSON với cấu trúc sau:
    {{
      "job_position": "{job_position}",
      "situation_group_name": "{situation_group_name}",
      "situation": {{
        "situation_name": "{situation}",
        "character_me": "Vai trò của người dùng",
        "character_ai": "Vai trò của AI",
        "ai_gender": "{ai_gender}",
        "situation_details": "Chi tiết tình huống giao tiếp"
      }}
    }}

    Example 

    {{
  "job_position": "Accountant (Kế Toán)",
  "situation_group_name": "Tương tác với đồng nghiệp",
  "situation": {{
    "situation_name": "Thảo luận với bộ phận bán hàng về việc cập nhật hóa đơn",
    "character_me": "Kế toán viên",
    "character_ai": "Trưởng bộ phận bán hàng",
    "ai_gender": "Nữ",
    "situation_details": "Tôi thảo luận với Trưởng bộ phận bán hàng về việc cập nhật hoá đơn."
      }}
    }}

    
    Đảm bảo đầu ra là một đối tượng JSON hợp lệ không có bất kỳ định dạng hoặc từ khóa bổ sung nào.

    

    """

    response = get_completion(prompt)
    
    try:
        situation_dict = json.loads(response)
        return json.dumps(situation_dict, ensure_ascii=False, indent=2)
    except json.JSONDecodeError:
        print("Error: The generated response is not valid JSON. Please check the output.")
        return None

# %%
import json
import pandas as pd

def gen_situation_group_AND_detail_situation(job_position: str) -> pd.DataFrame:
    """
    - (1 tham số duy nhất)
    - Output: Trả về Output 1 file excel với các cột 
        CÔNG VIỆC	TOPIC	TÊN TÌNH HUỐNG	CHI TIẾT TÌNH HUỐNG	NHÂN VẬT TÔI	NHÂN VẬT AI	Giới tính AI 	Câu mở đầu của AI	"LIST CÂU HỎI do AI hỏi"
    - Thêm các print để kiểm tra tiến độ và fix được lỗi (các print quan trọng, vừa đủ, không quá thừa)

    Output: Vừa có print ra console vừa có output là file excel, return nên là định dạng dễ sử dụng về sau (ĐÓ LÀ: DUYỆT TỪNG job_position ở đâu đó, sử dụng cái hàm gen_situation_group_AND_detail_situation(job_position) để tạo hàng loạt cho job_position, sau đó output gộp lại được thành 1 file với mỗi job_position là 1 sheet)
    - Sau khi tạo các nhóm tình huống, hãy in ra các nhóm tình huống đó trước đã nhé 
    - Tức là thêm các index ở đầu lúc lưu data từng câu hỏi ở cột "LIST CÂU HỎI do AI hỏi"
    - Làm sao để check được data in ra đúng chưa, thay vì phải đợi chạy xong toàn bộ => In ra dữ liệu từng tình huống để kiểm tra
    """
    # Bắt đầu quá trình với vị trí công việc được cung cấp
    print(f"Starting process for job position: {job_position}")
    
    # Bước 1: Tạo nhóm tình huống
    situation_groups_json = gen_situation_groups_AND_situation_SHORTVER2(job_position)
    print(situation_groups_json) # In các nhóm tình huống tạo được
    situation_groups = json.loads(situation_groups_json)
    
    # Sau khi tạo các nhóm tình huống, hãy in ra các nhóm tình huống đó trước đã nhé 
    
    print("\nGenerated Situation Groups:")
    for group_key, group in situation_groups["situation_groups"].items():
        print(f"Group: {group['situation_group_name']}")
        for situation_key, situation_value in group.items():
            if situation_key.startswith("situation") and situation_key != "situation_group_name":
                print(f"  - Situation: {situation_value}")

    # Bước 2: Tạo chi tiết tình huống cho từng nhóm và tình huống
    data = []
    processed_situations = set()  # Để theo dõi các tình huống đã xử lý
    situation_number = 1  # Thêm biến đếm này ĐỂ GEN GIỚI TÍNH
    print(f"Tạo tình huống số {situation_number}")

    # Duyệt qua các nhóm tình huống
    for group_key, group in situation_groups["situation_groups"].items():
        print(f"Processing group: {group['situation_group_name']}")
        # Duyệt qua từng tình huống trong nhóm
        for situation_key, situation_value in group.items():
            # Kiểm tra nếu key bắt đầu với "situation" và tình huống chưa được xử lý
            if situation_key.startswith("situation") and situation_key != "situation_group_name" and situation_value not in processed_situations:
                print("--------------")
                print(f"Generating details for : {situation_value}")
                # Gọi hàm để tạo chi tiết tình huống
                ai_gender = 'Nữ' if situation_number % 2 != 0 else 'Nam' # Tạo giới tính AI FIX CỨNG NHƯ NÀY ĐỂ TẠO CÂN BẰNG GIỚI

                detailed_situation_json = gen_detail_situations_SHORTVER_aigender(
                    job_position, 
                    group["situation_group_name"], 
                    situation_value, 
                    ai_gender
                )
                detailed_situation = json.loads(detailed_situation_json)
                
                # Lấy dữ liệu chi tiết từ tình huống
                situation_data = detailed_situation["situation"]
                

                situation_dict = {
                    "CÔNG VIỆC": job_position,
                    "TOPIC": group["situation_group_name"],
                    "TÊN TÌNH HUỐNG": situation_data["situation_name"],
                    "NHÂN VẬT TÔI": situation_data["character_me"],
                    "NHÂN VẬT AI": situation_data["character_ai"],
                    "Giới tính AI": situation_data["ai_gender"],
                    "CHI TIẾT TÌNH HUỐNG": situation_data["situation_details"],

                }
                
                # Làm sao để check được data in ra đúng chưa, thay vì phải đợi chạy xong toàn bộ => In ra dữ liệu từng tình huống để kiểm tra
                # In ra dữ liệu của tình huống để kiểm tra
                print("\nGenerated Detailed Situation Data:")
                for key, value in situation_dict.items():
                    print(f"{key}: {value}")
                
                data.append(situation_dict)
                
                # Đánh dấu tình huống này đã được xử lý
                processed_situations.add(situation_value)
                print("--------------")
                print("Next situation")
                situation_number += 1  # Tăng số thứ tự lên sau mỗi tình huống, CHỈ ĐỂ KIỂM SOÁT GIỚI TÍNH AI
                

    # Tạo DataFrame từ danh sách dữ liệu
    df = pd.DataFrame(data)
    print(f"Completed processing for job position: {job_position}")
    print(f"Total situations generated: {len(df)}")
    return df

# %% [markdown]
# ```
# các nhóm công việc sau
# Student/Sinh viên: 9.23%
# Accountant/Kế toán: 8.46%
# IT/Developer/Software Engineer/Engineer/Kỹ sư: 14.62%
# Construction/Contruction Engineer: 1.54%"
# Sales/Sale Manager: 6.92%
# Marketing: 3.08%
# "Teacher/Giáo viên: 6.15%
# Teacher Assistant/Teaching Related: 2.31%"
# Manager/Quản lý: 5.38%
# Logistics: 4.62%
# "Doctor/Bác sĩ: 3.08%
# Pharmacist/Dược sĩ: 2.31%"
# Freelancer: 3.08%
# HR/Human Resources: 3.08%
# Project Manager: 2.31%
# Business: 2.31%
# Customer Service: 1.54%
# Designer: 1.54%
# Business Analyst: 1.54%
# ```

# %% [markdown]
# - 5-6 phút/1 job_position => 120 phút.
# - Thay vì 1 phát 20 jobs => Chia nhỏ.
# 1. Chia nhỏ để chạy song song nhiều nơi
# 2. Chia nhỏ để check được output từng phần trong quá trình đợi gen tiếp các mẻ. <Thay vì xong hết rồi mới check 20 sheet>, thì có thể gen 3 sheet 1 lần, trong lúc đang gen 3 sheet thì check 3 sheet khác.

# %%
def generate_multi_job_situations(job_positions: List[str], filename_output: str) -> str:
    print("Starting multi-job situation generation process...")
    
    # Create a Pandas Excel writer using XlsxWriter as the engine
    with pd.ExcelWriter(filename_output, engine='xlsxwriter') as writer:
        for job_position in job_positions:
            print(f"\nProcessing job position: {job_position}")
            df = gen_situation_group_AND_detail_situation(job_position)
            
            # Write each DataFrame to a different worksheet
            sheet_name = job_position[:31]  # Excel sheet names have a 31 character limit
            df.to_excel(writer, sheet_name=sheet_name, index=False)
            print(f"Sheet '{sheet_name}' added to Excel file")

    print(f"\nExcel file generated: {filename_output}")
    return filename_output




if __name__ == "__main__":
    job_positions = ["Freelancer"]
    excel_file = generate_multi_job_situations(job_positions, "Freelancer_Exception.xlsx")
    print(f"Final Excel file: {excel_file}")
# Out:
# Starting multi-job situation generation process...
#
# Processing job position: Freelancer
# Starting process for job position: Freelancer
# {
#   "job_position": "Freelancer",
#   "situation_groups": {
#     "situation_group1": {
#       "situation_group_name": "Tìm kiếm và tiếp cận khách hàng mới",
#       "situation1": "Gặp mặt trực tiếp với khách hàng tiềm năng tại một sự kiện networking.",
#       "situation2": "Thực hiện cuộc gọi thoại để giới thiệu dịch vụ của bạn cho một khách hàng tiềm năng.",
#       "situation3": "Tham gia video call với một khách hàng quốc tế để thảo luận về nhu cầu của họ.",
#       "situation4": "Thuyết trình trực tiếp về dự án mẫu của bạn tại một hội thảo chuyên ngành.",
#       "situation5": "Gặp gỡ khách hàng tiềm năng tại quán cà phê để thảo luận về cơ hội hợp tác.",
#       "situation6": "Tham gia buổi gặp mặt nhóm với các doanh nghiệp nhỏ để giới thiệu dịch vụ của bạn.",
#       "situation7": "Thực hiện cuộc gọi thoại để theo dõi sau khi gửi đề xuất dịch vụ."
#     },
#     "situation_group2": {
#       "situation_group_name": "Đàm phán hợp đồng và thỏa thuận giá cả",
#       "situation1": "Thảo luận về phạm vi công việc với khách hàng tiềm năng.",
#       "situation2": "Đề xuất mức giá cho một dự án phức tạp.",
#       "situation3": "Giải thích chính sách thanh toán của bạn cho khách hàng mới.",
#       "situation4": "Thương lượng về thời hạn dự án với khách hàng gấp rút.",
#       "situation5": "Xử lý yêu cầu giảm giá từ khách hàng lâu năm.",
#       "situation6": "Thảo luận về các điều khoản bảo mật trong hợp đồng.",
#       "situation7": "Đàm phán về quyền sở hữu trí tuệ của sản phẩm cuối cùng."
#     },
#     "situation_group3": {
#       "situation_group_name": "Quản lý dự án và thời hạn",
#       "situation1": "Thực hiện cuộc gọi thoại để cập nhật tiến độ dự án với khách hàng.",
#       "situation2": "Thảo luận về việc điều chỉnh thời hạn dự án trong một cuộc họp trực tiếp.",
#       "situation3": "Tham gia video call để giải quyết các vấn đề phát sinh trong dự án.",
#       "situation4": "Gặp mặt trực tiếp để lập kế hoạch chi tiết cho dự án mới.",
#       "situation5": "Thực hiện cuộc gọi thoại để xác nhận các mốc thời gian quan trọng.",
#       "situation6": "Thảo luận về việc phân chia công việc trong nhóm dự án qua video call.",
#       "situation7": "Gặp gỡ khách hàng để bàn bạc về việc gia hạn hợp đồng."
#     },
#     "situation_group4": {
#       "situation_group_name": "Xử lý phản hồi và yêu cầu sửa đổi từ khách hàng",
#       "situation1": "Tiếp nhận phản hồi không tích cực về sản phẩm đầu tiên.",
#       "situation2": "Thảo luận về yêu cầu thay đổi lớn giữa dự án.",
#       "situation3": "Giải thích lý do cho việc không thể đáp ứng một yêu cầu cụ thể.",
#       "situation4": "Đề xuất giải pháp thay thế cho yêu cầu không khả thi.",
#       "situation5": "Xin thêm thông tin chi tiết về phản hồi mơ hồ.",
#       "situation6": "Thương lượng về phí phát sinh cho yêu cầu sửa đổi ngoài phạm vi.",
#       "situation7": "Xử lý tình huống khách hàng liên tục thay đổi ý kiến."
#     },
#     "situation_group5": {
#       "situation_group_name": "Networking và xây dựng mối quan hệ nghề nghiệp",
#       "situation1": "Tham gia buổi gặp mặt của cộng đồng freelancer để mở rộng mạng lưới.",
#       "situation2": "Gặp gỡ đối tác tiềm năng tại một sự kiện chuyên ngành.",
#       "situation3": "Thực hiện cuộc gọi thoại để duy trì mối quan hệ với khách hàng cũ.",
#       "situation4": "Tham gia video call với một nhóm freelancer để thảo luận về cơ hội hợp tác.",
#       "situation5": "Gặp mặt trực tiếp với một mentor để nhận lời khuyên về phát triển sự nghiệp.",
#       "situation6": "Tham gia buổi gặp mặt của một tổ chức nghề nghiệp để tìm kiếm cơ hội mới.",
#       "situation7": "Thực hiện cuộc gọi thoại để giới thiệu một freelancer khác cho khách hàng của bạn."
#     },
#     "situation_group6": {
#       "situation_group_name": "Quản lý tài chính và thanh toán",
#       "situation1": "Thảo luận về phương thức thanh toán với khách hàng trong cuộc họp trực tiếp.",
#       "situation2": "Thực hiện cuộc gọi thoại để nhắc nhở khách hàng về việc thanh toán chậm.",
#       "situation3": "Gặp mặt trực tiếp để giải quyết các vấn đề liên quan đến hóa đơn.",
#       "situation4": "Thảo luận về việc chia nhỏ thanh toán cho dự án lớn qua video call.",
#       "situation5": "Thực hiện cuộc gọi thoại để xác nhận việc nhận thanh toán từ khách hàng.",
#       "situation6": "Gặp gỡ khách hàng để thảo luận về các điều khoản thanh toán linh hoạt.",
#       "situation7": "Tham gia video call để giải thích các khoản phí phát sinh trong dự án."
#     },
#     "situation_group7": {
#       "situation_group_name": "Xử lý xung đột và bất đồng với khách hàng",
#       "situation1": "Thảo luận trực tiếp về một vấn đề không đồng ý trong dự án.",
#       "situation2": "Thực hiện cuộc gọi thoại để giải quyết xung đột về phạm vi công việc.",
#       "situation3": "Tham gia video call để làm rõ các điều khoản hợp đồng gây tranh cãi.",
#       "situation4": "Gặp mặt trực tiếp để giải quyết mâu thuẫn về chất lượng sản phẩm.",
#       "situation5": "Thực hiện cuộc gọi thoại để thảo luận về việc chậm tiến độ dự án.",
#       "situation6": "Tham gia video call để giải quyết xung đột về quyền sở hữu trí tuệ.",
#       "situation7": "Gặp gỡ khách hàng để thảo luận về việc chấm dứt hợp đồng sớm."
#     }
#   }
# }
#
# Generated Situation Groups:
# Group: Tìm kiếm và tiếp cận khách hàng mới
#   - Situation: Gặp mặt trực tiếp với khách hàng tiềm năng tại một sự kiện networking.
#   - Situation: Thực hiện cuộc gọi thoại để giới thiệu dịch vụ của bạn cho một khách hàng tiềm năng.
#   - Situation: Tham gia video call với một khách hàng quốc tế để thảo luận về nhu cầu của họ.
#   - Situation: Thuyết trình trực tiếp về dự án mẫu của bạn tại một hội thảo chuyên ngành.
#   - Situation: Gặp gỡ khách hàng tiềm năng tại quán cà phê để thảo luận về cơ hội hợp tác.
#   - Situation: Tham gia buổi gặp mặt nhóm với các doanh nghiệp nhỏ để giới thiệu dịch vụ của bạn.
#   - Situation: Thực hiện cuộc gọi thoại để theo dõi sau khi gửi đề xuất dịch vụ.
# Group: Đàm phán hợp đồng và thỏa thuận giá cả
#   - Situation: Thảo luận về phạm vi công việc với khách hàng tiềm năng.
#   - Situation: Đề xuất mức giá cho một dự án phức tạp.
#   - Situation: Giải thích chính sách thanh toán của bạn cho khách hàng mới.
#   - Situation: Thương lượng về thời hạn dự án với khách hàng gấp rút.
#   - Situation: Xử lý yêu cầu giảm giá từ khách hàng lâu năm.
#   - Situation: Thảo luận về các điều khoản bảo mật trong hợp đồng.
#   - Situation: Đàm phán về quyền sở hữu trí tuệ của sản phẩm cuối cùng.
# Group: Quản lý dự án và thời hạn
#   - Situation: Thực hiện cuộc gọi thoại để cập nhật tiến độ dự án với khách hàng.
#   - Situation: Thảo luận về việc điều chỉnh thời hạn dự án trong một cuộc họp trực tiếp.
#   - Situation: Tham gia video call để giải quyết các vấn đề phát sinh trong dự án.
#   - Situation: Gặp mặt trực tiếp để lập kế hoạch chi tiết cho dự án mới.
#   - Situation: Thực hiện cuộc gọi thoại để xác nhận các mốc thời gian quan trọng.
#   - Situation: Thảo luận về việc phân chia công việc trong nhóm dự án qua video call.
#   - Situation: Gặp gỡ khách hàng để bàn bạc về việc gia hạn hợp đồng.
# Group: Xử lý phản hồi và yêu cầu sửa đổi từ khách hàng
#   - Situation: Tiếp nhận phản hồi không tích cực về sản phẩm đầu tiên.
#   - Situation: Thảo luận về yêu cầu thay đổi lớn giữa dự án.
#   - Situation: Giải thích lý do cho việc không thể đáp ứng một yêu cầu cụ thể.
#   - Situation: Đề xuất giải pháp thay thế cho yêu cầu không khả thi.
#   - Situation: Xin thêm thông tin chi tiết về phản hồi mơ hồ.
#   - Situation: Thương lượng về phí phát sinh cho yêu cầu sửa đổi ngoài phạm vi.
#   - Situation: Xử lý tình huống khách hàng liên tục thay đổi ý kiến.
# Group: Networking và xây dựng mối quan hệ nghề nghiệp
#   - Situation: Tham gia buổi gặp mặt của cộng đồng freelancer để mở rộng mạng lưới.
#   - Situation: Gặp gỡ đối tác tiềm năng tại một sự kiện chuyên ngành.
#   - Situation: Thực hiện cuộc gọi thoại để duy trì mối quan hệ với khách hàng cũ.
#   - Situation: Tham gia video call với một nhóm freelancer để thảo luận về cơ hội hợp tác.
#   - Situation: Gặp mặt trực tiếp với một mentor để nhận lời khuyên về phát triển sự nghiệp.
#   - Situation: Tham gia buổi gặp mặt của một tổ chức nghề nghiệp để tìm kiếm cơ hội mới.
#   - Situation: Thực hiện cuộc gọi thoại để giới thiệu một freelancer khác cho khách hàng của bạn.
# Group: Quản lý tài chính và thanh toán
#   - Situation: Thảo luận về phương thức thanh toán với khách hàng trong cuộc họp trực tiếp.
#   - Situation: Thực hiện cuộc gọi thoại để nhắc nhở khách hàng về việc thanh toán chậm.
#   - Situation: Gặp mặt trực tiếp để giải quyết các vấn đề liên quan đến hóa đơn.
#   - Situation: Thảo luận về việc chia nhỏ thanh toán cho dự án lớn qua video call.
#   - Situation: Thực hiện cuộc gọi thoại để xác nhận việc nhận thanh toán từ khách hàng.
#   - Situation: Gặp gỡ khách hàng để thảo luận về các điều khoản thanh toán linh hoạt.
#   - Situation: Tham gia video call để giải thích các khoản phí phát sinh trong dự án.
# Group: Xử lý xung đột và bất đồng với khách hàng
#   - Situation: Thảo luận trực tiếp về một vấn đề không đồng ý trong dự án.
#   - Situation: Thực hiện cuộc gọi thoại để giải quyết xung đột về phạm vi công việc.
#   - Situation: Tham gia video call để làm rõ các điều khoản hợp đồng gây tranh cãi.
#   - Situation: Gặp mặt trực tiếp để giải quyết mâu thuẫn về chất lượng sản phẩm.
#   - Situation: Thực hiện cuộc gọi thoại để thảo luận về việc chậm tiến độ dự án.
#   - Situation: Tham gia video call để giải quyết xung đột về quyền sở hữu trí tuệ.
#   - Situation: Gặp gỡ khách hàng để thảo luận về việc chấm dứt hợp đồng sớm.
# Tạo tình huống số 1
# Processing group: Tìm kiếm và tiếp cận khách hàng mới
# --------------
# Generating details for : Gặp mặt trực tiếp với khách hàng tiềm năng tại một sự kiện networking.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Tìm kiếm và tiếp cận khách hàng mới
# TÊN TÌNH HUỐNG: Gặp mặt trực tiếp với khách hàng tiềm năng tại một sự kiện networking.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng tiềm năng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi gặp mặt trực tiếp với Khách hàng tiềm năng tại một sự kiện networking.
# --------------
# Next situation
# --------------
# Generating details for : Thực hiện cuộc gọi thoại để giới thiệu dịch vụ của bạn cho một khách hàng tiềm năng.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Tìm kiếm và tiếp cận khách hàng mới
# TÊN TÌNH HUỐNG: Thực hiện cuộc gọi thoại để giới thiệu dịch vụ của bạn cho một khách hàng tiềm năng.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng tiềm năng
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi thực hiện cuộc gọi thoại để giới thiệu dịch vụ của bạn cho một khách hàng tiềm năng.
# --------------
# Next situation
# --------------
# Generating details for : Tham gia video call với một khách hàng quốc tế để thảo luận về nhu cầu của họ.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Tìm kiếm và tiếp cận khách hàng mới
# TÊN TÌNH HUỐNG: Tham gia video call với một khách hàng quốc tế để thảo luận về nhu cầu của họ.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng quốc tế
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Khách hàng quốc tế về nhu cầu của họ.
# --------------
# Next situation
# --------------
# Generating details for : Thuyết trình trực tiếp về dự án mẫu của bạn tại một hội thảo chuyên ngành.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Tìm kiếm và tiếp cận khách hàng mới
# TÊN TÌNH HUỐNG: Thuyết trình trực tiếp về dự án mẫu của bạn tại một hội thảo chuyên ngành.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Chuyên gia ngành
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi thuyết trình với Chuyên gia ngành về dự án mẫu của tôi tại một hội thảo chuyên ngành.
# --------------
# Next situation
# --------------
# Generating details for : Gặp gỡ khách hàng tiềm năng tại quán cà phê để thảo luận về cơ hội hợp tác.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Tìm kiếm và tiếp cận khách hàng mới
# TÊN TÌNH HUỐNG: Gặp gỡ khách hàng tiềm năng tại quán cà phê để thảo luận về cơ hội hợp tác.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng tiềm năng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi gặp gỡ Khách hàng tiềm năng tại quán cà phê để thảo luận về cơ hội hợp tác.
# --------------
# Next situation
# --------------
# Generating details for : Tham gia buổi gặp mặt nhóm với các doanh nghiệp nhỏ để giới thiệu dịch vụ của bạn.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Tìm kiếm và tiếp cận khách hàng mới
# TÊN TÌNH HUỐNG: Tham gia buổi gặp mặt nhóm với các doanh nghiệp nhỏ để giới thiệu dịch vụ của bạn.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Chủ doanh nghiệp nhỏ
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi giới thiệu dịch vụ của mình với Chủ doanh nghiệp nhỏ trong buổi gặp mặt nhóm.
# --------------
# Next situation
# --------------
# Generating details for : Thực hiện cuộc gọi thoại để theo dõi sau khi gửi đề xuất dịch vụ.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Tìm kiếm và tiếp cận khách hàng mới
# TÊN TÌNH HUỐNG: Thực hiện cuộc gọi thoại để theo dõi sau khi gửi đề xuất dịch vụ.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng tiềm năng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi gọi điện thoại cho Khách hàng tiềm năng để theo dõi sau khi gửi đề xuất dịch vụ.
# --------------
# Next situation
# Processing group: Đàm phán hợp đồng và thỏa thuận giá cả
# --------------
# Generating details for : Thảo luận về phạm vi công việc với khách hàng tiềm năng.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Đàm phán hợp đồng và thỏa thuận giá cả
# TÊN TÌNH HUỐNG: Thảo luận về phạm vi công việc với khách hàng tiềm năng.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng tiềm năng
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Khách hàng tiềm năng về phạm vi công việc.
# --------------
# Next situation
# --------------
# Generating details for : Đề xuất mức giá cho một dự án phức tạp.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Đàm phán hợp đồng và thỏa thuận giá cả
# TÊN TÌNH HUỐNG: Đề xuất mức giá cho một dự án phức tạp.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng quốc tế
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi đề xuất mức giá với Khách hàng quốc tế cho một dự án phức tạp.
# --------------
# Next situation
# --------------
# Generating details for : Giải thích chính sách thanh toán của bạn cho khách hàng mới.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Đàm phán hợp đồng và thỏa thuận giá cả
# TÊN TÌNH HUỐNG: Giải thích chính sách thanh toán của bạn cho khách hàng mới.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng mới
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi giải thích chính sách thanh toán của tôi cho Khách hàng mới.
# --------------
# Next situation
# --------------
# Generating details for : Thương lượng về thời hạn dự án với khách hàng gấp rút.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Đàm phán hợp đồng và thỏa thuận giá cả
# TÊN TÌNH HUỐNG: Thương lượng về thời hạn dự án với khách hàng gấp rút.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi thương lượng với Khách hàng về thời hạn dự án gấp rút.
# --------------
# Next situation
# --------------
# Generating details for : Xử lý yêu cầu giảm giá từ khách hàng lâu năm.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Đàm phán hợp đồng và thỏa thuận giá cả
# TÊN TÌNH HUỐNG: Xử lý yêu cầu giảm giá từ khách hàng lâu năm.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng lâu năm
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi xử lý yêu cầu giảm giá từ Khách hàng lâu năm.
# --------------
# Next situation
# --------------
# Generating details for : Thảo luận về các điều khoản bảo mật trong hợp đồng.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Đàm phán hợp đồng và thỏa thuận giá cả
# TÊN TÌNH HUỐNG: Thảo luận về các điều khoản bảo mật trong hợp đồng.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Khách hàng về các điều khoản bảo mật trong hợp đồng.
# --------------
# Next situation
# --------------
# Generating details for : Đàm phán về quyền sở hữu trí tuệ của sản phẩm cuối cùng.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Đàm phán hợp đồng và thỏa thuận giá cả
# TÊN TÌNH HUỐNG: Đàm phán về quyền sở hữu trí tuệ của sản phẩm cuối cùng.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi đàm phán với Khách hàng về quyền sở hữu trí tuệ của sản phẩm cuối cùng.
# --------------
# Next situation
# Processing group: Quản lý dự án và thời hạn
# --------------
# Generating details for : Thực hiện cuộc gọi thoại để cập nhật tiến độ dự án với khách hàng.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Quản lý dự án và thời hạn
# TÊN TÌNH HUỐNG: Thực hiện cuộc gọi thoại để cập nhật tiến độ dự án với khách hàng.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi thực hiện cuộc gọi thoại để cập nhật tiến độ dự án với khách hàng.
# --------------
# Next situation
# --------------
# Generating details for : Thảo luận về việc điều chỉnh thời hạn dự án trong một cuộc họp trực tiếp.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Quản lý dự án và thời hạn
# TÊN TÌNH HUỐNG: Thảo luận về việc điều chỉnh thời hạn dự án trong một cuộc họp trực tiếp.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Quản lý dự án
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Quản lý dự án về việc điều chỉnh thời hạn dự án trong một cuộc họp trực tiếp.
# --------------
# Next situation
# --------------
# Generating details for : Tham gia video call để giải quyết các vấn đề phát sinh trong dự án.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Quản lý dự án và thời hạn
# TÊN TÌNH HUỐNG: Tham gia video call để giải quyết các vấn đề phát sinh trong dự án.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Quản lý dự án
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi tham gia video call với Quản lý dự án để giải quyết các vấn đề phát sinh trong dự án.
# --------------
# Next situation
# --------------
# Generating details for : Gặp mặt trực tiếp để lập kế hoạch chi tiết cho dự án mới.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Quản lý dự án và thời hạn
# TÊN TÌNH HUỐNG: Gặp mặt trực tiếp để lập kế hoạch chi tiết cho dự án mới.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Quản lý dự án
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi gặp mặt trực tiếp với Quản lý dự án để lập kế hoạch chi tiết cho dự án mới.
# --------------
# Next situation
# --------------
# Generating details for : Thực hiện cuộc gọi thoại để xác nhận các mốc thời gian quan trọng.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Quản lý dự án và thời hạn
# TÊN TÌNH HUỐNG: Thực hiện cuộc gọi thoại để xác nhận các mốc thời gian quan trọng.
# NHÂN VẬT TÔI: Quản lý dự án tự do
# NHÂN VẬT AI: Khách hàng dự án
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi thực hiện cuộc gọi thoại với Khách hàng dự án để xác nhận các mốc thời gian quan trọng.
# --------------
# Next situation
# --------------
# Generating details for : Thảo luận về việc phân chia công việc trong nhóm dự án qua video call.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Quản lý dự án và thời hạn
# TÊN TÌNH HUỐNG: Thảo luận về việc phân chia công việc trong nhóm dự án qua video call.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Quản lý dự án
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Quản lý dự án về việc phân chia công việc trong nhóm dự án qua video call.
# --------------
# Next situation
# --------------
# Generating details for : Gặp gỡ khách hàng để bàn bạc về việc gia hạn hợp đồng.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Quản lý dự án và thời hạn
# TÊN TÌNH HUỐNG: Gặp gỡ khách hàng để bàn bạc về việc gia hạn hợp đồng.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi gặp gỡ Khách hàng để bàn bạc về việc gia hạn hợp đồng.
# --------------
# Next situation
# Processing group: Xử lý phản hồi và yêu cầu sửa đổi từ khách hàng
# --------------
# Generating details for : Tiếp nhận phản hồi không tích cực về sản phẩm đầu tiên.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Xử lý phản hồi và yêu cầu sửa đổi từ khách hàng
# TÊN TÌNH HUỐNG: Tiếp nhận phản hồi không tích cực về sản phẩm đầu tiên.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi tiếp nhận phản hồi không tích cực từ Khách hàng về sản phẩm đầu tiên.
# --------------
# Next situation
# --------------
# Generating details for : Thảo luận về yêu cầu thay đổi lớn giữa dự án.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Xử lý phản hồi và yêu cầu sửa đổi từ khách hàng
# TÊN TÌNH HUỐNG: Thảo luận về yêu cầu thay đổi lớn giữa dự án.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Khách hàng về yêu cầu thay đổi lớn giữa dự án.
# --------------
# Next situation
# --------------
# Generating details for : Giải thích lý do cho việc không thể đáp ứng một yêu cầu cụ thể.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Xử lý phản hồi và yêu cầu sửa đổi từ khách hàng
# TÊN TÌNH HUỐNG: Giải thích lý do cho việc không thể đáp ứng một yêu cầu cụ thể.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi giải thích với Khách hàng lý do cho việc không thể đáp ứng một yêu cầu cụ thể.
# --------------
# Next situation
# --------------
# Generating details for : Đề xuất giải pháp thay thế cho yêu cầu không khả thi.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Xử lý phản hồi và yêu cầu sửa đổi từ khách hàng
# TÊN TÌNH HUỐNG: Đề xuất giải pháp thay thế cho yêu cầu không khả thi.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi đề xuất giải pháp thay thế cho yêu cầu không khả thi với Khách hàng.
# --------------
# Next situation
# --------------
# Generating details for : Xin thêm thông tin chi tiết về phản hồi mơ hồ.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Xử lý phản hồi và yêu cầu sửa đổi từ khách hàng
# TÊN TÌNH HUỐNG: Xin thêm thông tin chi tiết về phản hồi mơ hồ.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi xin thêm thông tin chi tiết từ Khách hàng về phản hồi mơ hồ.
# --------------
# Next situation
# --------------
# Generating details for : Thương lượng về phí phát sinh cho yêu cầu sửa đổi ngoài phạm vi.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Xử lý phản hồi và yêu cầu sửa đổi từ khách hàng
# TÊN TÌNH HUỐNG: Thương lượng về phí phát sinh cho yêu cầu sửa đổi ngoài phạm vi.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi thương lượng với Khách hàng về phí phát sinh cho yêu cầu sửa đổi ngoài phạm vi.
# --------------
# Next situation
# --------------
# Generating details for : Xử lý tình huống khách hàng liên tục thay đổi ý kiến.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Xử lý phản hồi và yêu cầu sửa đổi từ khách hàng
# TÊN TÌNH HUỐNG: Xử lý tình huống khách hàng liên tục thay đổi ý kiến.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Khách hàng về việc thay đổi ý kiến liên tục.
# --------------
# Next situation
# Processing group: Networking và xây dựng mối quan hệ nghề nghiệp
# --------------
# Generating details for : Tham gia buổi gặp mặt của cộng đồng freelancer để mở rộng mạng lưới.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Networking và xây dựng mối quan hệ nghề nghiệp
# TÊN TÌNH HUỐNG: Tham gia buổi gặp mặt của cộng đồng freelancer để mở rộng mạng lưới.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Chủ tịch cộng đồng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Chủ tịch cộng đồng về việc mở rộng mạng lưới.
# --------------
# Next situation
# --------------
# Generating details for : Gặp gỡ đối tác tiềm năng tại một sự kiện chuyên ngành.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Networking và xây dựng mối quan hệ nghề nghiệp
# TÊN TÌNH HUỐNG: Gặp gỡ đối tác tiềm năng tại một sự kiện chuyên ngành.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Đối tác tiềm năng
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi gặp gỡ Đối tác tiềm năng tại một sự kiện chuyên ngành.
# --------------
# Next situation
# --------------
# Generating details for : Thực hiện cuộc gọi thoại để duy trì mối quan hệ với khách hàng cũ.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Networking và xây dựng mối quan hệ nghề nghiệp
# TÊN TÌNH HUỐNG: Thực hiện cuộc gọi thoại để duy trì mối quan hệ với khách hàng cũ.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng cũ
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi thực hiện cuộc gọi thoại để duy trì mối quan hệ với khách hàng cũ.
# --------------
# Next situation
# --------------
# Generating details for : Tham gia video call với một nhóm freelancer để thảo luận về cơ hội hợp tác.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Networking và xây dựng mối quan hệ nghề nghiệp
# TÊN TÌNH HUỐNG: Tham gia video call với một nhóm freelancer để thảo luận về cơ hội hợp tác.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Trưởng nhóm dự án
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Trưởng nhóm dự án về cơ hội hợp tác trong video call.
# --------------
# Next situation
# --------------
# Generating details for : Gặp mặt trực tiếp với một mentor để nhận lời khuyên về phát triển sự nghiệp.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Networking và xây dựng mối quan hệ nghề nghiệp
# TÊN TÌNH HUỐNG: Gặp mặt trực tiếp với một mentor để nhận lời khuyên về phát triển sự nghiệp.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Mentor
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi gặp mặt trực tiếp với Mentor để nhận lời khuyên về phát triển sự nghiệp.
# --------------
# Next situation
# --------------
# Generating details for : Tham gia buổi gặp mặt của một tổ chức nghề nghiệp để tìm kiếm cơ hội mới.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Networking và xây dựng mối quan hệ nghề nghiệp
# TÊN TÌNH HUỐNG: Tham gia buổi gặp mặt của một tổ chức nghề nghiệp để tìm kiếm cơ hội mới.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Chủ tịch tổ chức
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Chủ tịch tổ chức về cơ hội hợp tác mới.
# --------------
# Next situation
# --------------
# Generating details for : Thực hiện cuộc gọi thoại để giới thiệu một freelancer khác cho khách hàng của bạn.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Networking và xây dựng mối quan hệ nghề nghiệp
# TÊN TÌNH HUỐNG: Thực hiện cuộc gọi thoại để giới thiệu một freelancer khác cho khách hàng của bạn.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi thực hiện cuộc gọi thoại để giới thiệu một freelancer khác cho khách hàng.
# --------------
# Next situation
# Processing group: Quản lý tài chính và thanh toán
# --------------
# Generating details for : Thảo luận về phương thức thanh toán với khách hàng trong cuộc họp trực tiếp.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Quản lý tài chính và thanh toán
# TÊN TÌNH HUỐNG: Thảo luận về phương thức thanh toán với khách hàng trong cuộc họp trực tiếp.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Khách hàng về phương thức thanh toán trong cuộc họp trực tiếp.
# --------------
# Next situation
# --------------
# Generating details for : Thực hiện cuộc gọi thoại để nhắc nhở khách hàng về việc thanh toán chậm.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Quản lý tài chính và thanh toán
# TÊN TÌNH HUỐNG: Thực hiện cuộc gọi thoại để nhắc nhở khách hàng về việc thanh toán chậm.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi nhắc nhở Khách hàng về việc thanh toán chậm.
# --------------
# Next situation
# --------------
# Generating details for : Gặp mặt trực tiếp để giải quyết các vấn đề liên quan đến hóa đơn.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Quản lý tài chính và thanh toán
# TÊN TÌNH HUỐNG: Gặp mặt trực tiếp để giải quyết các vấn đề liên quan đến hóa đơn.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi gặp mặt trực tiếp với Khách hàng để giải quyết các vấn đề liên quan đến hóa đơn.
# --------------
# Next situation
# --------------
# Generating details for : Thảo luận về việc chia nhỏ thanh toán cho dự án lớn qua video call.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Quản lý tài chính và thanh toán
# TÊN TÌNH HUỐNG: Thảo luận về việc chia nhỏ thanh toán cho dự án lớn qua video call.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Khách hàng về việc chia nhỏ thanh toán cho dự án lớn qua video call.
# --------------
# Next situation
# --------------
# Generating details for : Thực hiện cuộc gọi thoại để xác nhận việc nhận thanh toán từ khách hàng.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Quản lý tài chính và thanh toán
# TÊN TÌNH HUỐNG: Thực hiện cuộc gọi thoại để xác nhận việc nhận thanh toán từ khách hàng.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi gọi điện thoại cho Khách hàng để xác nhận việc nhận thanh toán.
# --------------
# Next situation
# --------------
# Generating details for : Gặp gỡ khách hàng để thảo luận về các điều khoản thanh toán linh hoạt.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Quản lý tài chính và thanh toán
# TÊN TÌNH HUỐNG: Gặp gỡ khách hàng để thảo luận về các điều khoản thanh toán linh hoạt.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Khách hàng về các điều khoản thanh toán linh hoạt.
# --------------
# Next situation
# --------------
# Generating details for : Tham gia video call để giải thích các khoản phí phát sinh trong dự án.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Quản lý tài chính và thanh toán
# TÊN TÌNH HUỐNG: Tham gia video call để giải thích các khoản phí phát sinh trong dự án.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi giải thích với Khách hàng về các khoản phí phát sinh trong dự án.
# --------------
# Next situation
# Processing group: Xử lý xung đột và bất đồng với khách hàng
# --------------
# Generating details for : Thảo luận trực tiếp về một vấn đề không đồng ý trong dự án.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Xử lý xung đột và bất đồng với khách hàng
# TÊN TÌNH HUỐNG: Thảo luận trực tiếp về một vấn đề không đồng ý trong dự án.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Khách hàng về một vấn đề không đồng ý trong dự án.
# --------------
# Next situation
# --------------
# Generating details for : Thực hiện cuộc gọi thoại để giải quyết xung đột về phạm vi công việc.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Xử lý xung đột và bất đồng với khách hàng
# TÊN TÌNH HUỐNG: Thực hiện cuộc gọi thoại để giải quyết xung đột về phạm vi công việc.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Khách hàng về xung đột phạm vi công việc.
# --------------
# Next situation
# --------------
# Generating details for : Tham gia video call để làm rõ các điều khoản hợp đồng gây tranh cãi.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Xử lý xung đột và bất đồng với khách hàng
# TÊN TÌNH HUỐNG: Tham gia video call để làm rõ các điều khoản hợp đồng gây tranh cãi.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Khách hàng về các điều khoản hợp đồng gây tranh cãi.
# --------------
# Next situation
# --------------
# Generating details for : Gặp mặt trực tiếp để giải quyết mâu thuẫn về chất lượng sản phẩm.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Xử lý xung đột và bất đồng với khách hàng
# TÊN TÌNH HUỐNG: Gặp mặt trực tiếp để giải quyết mâu thuẫn về chất lượng sản phẩm.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi gặp mặt trực tiếp với Khách hàng để giải quyết mâu thuẫn về chất lượng sản phẩm.
# --------------
# Next situation
# --------------
# Generating details for : Thực hiện cuộc gọi thoại để thảo luận về việc chậm tiến độ dự án.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Xử lý xung đột và bất đồng với khách hàng
# TÊN TÌNH HUỐNG: Thực hiện cuộc gọi thoại để thảo luận về việc chậm tiến độ dự án.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Khách hàng về việc chậm tiến độ dự án.
# --------------
# Next situation
# --------------
# Generating details for : Tham gia video call để giải quyết xung đột về quyền sở hữu trí tuệ.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Xử lý xung đột và bất đồng với khách hàng
# TÊN TÌNH HUỐNG: Tham gia video call để giải quyết xung đột về quyền sở hữu trí tuệ.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nam
# CHI TIẾT TÌNH HUỐNG: Tôi tham gia video call với Khách hàng để giải quyết xung đột về quyền sở hữu trí tuệ.
# --------------
# Next situation
# --------------
# Generating details for : Gặp gỡ khách hàng để thảo luận về việc chấm dứt hợp đồng sớm.
#
# Generated Detailed Situation Data:
# CÔNG VIỆC: Freelancer
# TOPIC: Xử lý xung đột và bất đồng với khách hàng
# TÊN TÌNH HUỐNG: Gặp gỡ khách hàng để thảo luận về việc chấm dứt hợp đồng sớm.
# NHÂN VẬT TÔI: Freelancer
# NHÂN VẬT AI: Khách hàng
# Giới tính AI: Nữ
# CHI TIẾT TÌNH HUỐNG: Tôi thảo luận với Khách hàng về việc chấm dứt hợp đồng sớm.
# --------------
# Next situation
# Completed processing for job position: Freelancer
# Total situations generated: 49
# Sheet 'Freelancer' added to Excel file
#
# Excel file generated: Freelancer_Exception.xlsx
# Final Excel file: Freelancer_Exception.xlsx

# %% [markdown]
# Trong cột H, cột I.
# - H2: "Hi, I'm Maria, the international student in our group. I'm excited to work on this project with you all. To start, can you explain what specific tasks we need to divide among ourselves?"
# - I2: """
# 1. Can you explain what specific tasks we need to divide among ourselves?
# 2. What resources do you think we should use for our research?
# 3. How often should we meet to discuss our progress?
# 4. Are there any cultural considerations we should keep in mind while working together?
# 5. What is the deadline for each part of the project?
# 6. How should we handle any disagreements or conflicts that arise?
# 7. What is the best way for us to communicate outside of our scheduled meetings?
# """
#
# Muốn kiểm tra xem câu cuối của H2 " To start, can you explain what specific tasks we need to divide among ourselves?" có trùng với "1. Can you explain what specific tasks we need to divide among ourselves?" của I2 không
#
# Tương tự với H3 - I3, H4-I4, => công thức trong GOOGLE SHEET là gì?
#
# - Các đề tài cho sinh viên và bác sĩ nên cân nhắc thêm sự linh hoạt => gen tay

# %% [markdown]
# #### Sửa đổi requirements => Output đơn giản hơn

# %% [markdown]
# Output:
# 1. Gộp lại thành 1 file chung 19 sheet, hỏng đâu sửa đó hoặc sheet nào được rồi đẩy lên sheet trên Drive => trả cho a Trúc.
# 2. ***Sau khi a Cường và a Trúc duyệt output và requirements*** => MỚI ĐẨY LÊN NOTION

# %% [markdown]
# - Bác sĩ, Dược Sĩ: sửa "Hỗ trợ chăm sóc khách hàng" => "Hỗ trợ chăm sóc bệnh nhân".
# - Freelancer, Sinh Viên.
